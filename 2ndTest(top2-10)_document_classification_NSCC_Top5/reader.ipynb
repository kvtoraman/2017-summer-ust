# %%
# Author: Kamil Veli TORAMAN <kvtoraman@gmail.com>
# Seperates English words given without spaces
# infer_spaces function is from web

from __future__ import print_function
import pandas as pd
import logging
import numpy as np
from optparse import OptionParser
import sys, copy
from time import time
from random import randint
from math import log
#import matplotlib.pyplot as plt
from IPython.display import display, HTML
from sklearn.datasets import fetch_20newsgroups
from sklearn.datasets import fetch_rcv1

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import RidgeClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.svm import SVR
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.extmath import density
from sklearn import metrics

# %%
# Build a cost dictionary, assuming Zipf's law and cost = -math.log(probability).

def infer_spaces(s):
    """Uses dynamic programming to infer the location of spaces in a string
    without spaces."""

    # Find the best match for the i first characters, assuming cost has
    # been built for the i-1 first characters.
    # Returns a pair (match_cost, match_length).
    def best_match(i):
        candidates = enumerate(reversed(cost[max(0, i-maxword):i]))
        return min((c + wordcost.get(s[i-k-1:i], 9e999), k+1) for k,c in candidates)

    # Build the cost array.
    cost = [0]
    for i in range(1,len(s)+1):
        c,k = best_match(i)
        cost.append(c)

    # Backtrack to recover the minimal-cost string.
    out = []
    i = len(s)
    while i>0:
        c,k = best_match(i)
        assert c == cost[i]
        out.append(s[i-k:i])
        i -= k

    return " ".join(reversed(out))

# %%
file_name = 'kkma_data_all_1col.dat'
data = open(file_name).readlines()
out = open('rev_'+file_name,'w')
ENCODING = 'utf-8'
data_train_data = []
y_train = []
def is_ascii(s):
    return all(ord(c) < 128 for c in s)

words = open("words-by-frequency.txt").read().split()
wordcost = dict((k, log((i+1)*log(len(words)))) for i,k in enumerate(words))
maxword = max(len(x) for x in words)

for line_id,line in enumerate(data):
    items = line.split('\t')
    if len(items) == 2:
        out.write(items[0]+'\t')
        line = items[1].decode(ENCODING, 'ignore')
        ascii_mode = False
        tmp = ""
        if(line_id%100 == 0):
            print(line)
        for i,c in enumerate(line):
            if(c!=' ' and is_ascii(c) and not ascii_mode):
                ascii_mode = True
            if(not is_ascii(c) and ascii_mode):
                ascii_mode = False
             #   print(line_id,tmp)
                blocks = tmp.split(' ')
                for block in blocks:
                    block = block.lower()
                    spaced = infer_spaces(block)
                    for guess in spaced.split():
                    #    if len(guess)>2:
                            out.write(guess+' ')
                tmp=""
            if not ascii_mode:    
                out.write(c.encode('utf-8'))
            else:
                tmp += c.encode('utf-8')
            if c!=' ' and len(line)>i+1 and is_ascii(c) and not is_ascii(line[i+1]):
                #if(i%200 == 0): 
                #    print(i,c, line[i+1])
                out.write(' '.encode('utf-8'))
        out.write("\n")
    else:
        print("ERROR in train")
out.close()
# Out:
# Mobile Web/APp,Process oriented,Gateway Server,Service Platform,encryption 스마트 단말기 기반 업무 업무시스템 시스템 연동 모바일 플 플리케이션 리 케이 션 서비스 컨버전스 플랫폼 기술 개발 프로세스 프로세스중심형 중심 형 게이트웨이 게이트웨이서버 서버 서비스플랫폼 암호화 기업 연계 미들 미들웨어 웨어 프레임 프레임워크 워크 적용 공인 인증 조합 조합형 패키지 데이터 확보 체계 구축 부 부문 문 특화 시범 경제적 효과 시험 참여 자 간 신규 시장 비즈니스 모델 발굴 교육 컨설팅 등 직접적 보급 다양 채널 활용 홍보 산업 산업인력 인력 육성 최 최신 신 확산 주도 업무혁신 혁신 강화 기술적 기존 구현 기여 플랫폼간 표준 표준화 기술강화 분리 완성 완성도가 도가 사회적 보안 보안모듈 모듈 개인 개인정보 정보 지적 자산 유출 방지 비즈 니스 도메인 가속화
#
# NaturalLanguageProcessing,EnglishKoreanMachineTranslation,Preprocessing,Postprocessing,RulebasedParsing,IdiombasedTranslation,MachineLearning 영 기계 기계번역 번역 전처리 연구 자연 자연언어처리 언어 처리 후처리 규칙 규칙기반 기반 구문 구문분석 분석 숙어 숙어기반 번역방식 방식 기계학습 학습 구조 대상 양 간 상당 차이점 문제 현재 영한 시스템 실용적 측면 수 사이 존재 해결 방법 영어 문장 정확 생성 도움 다양 방안 고안 목표 차이 때문 필요 이 대표적 언어자원인 자 원인 구축 말뭉치 활용 기존 단계 포함 최근 관심 모바일 애플리케이션 개발 관련 정보 제공 사이트 예정 한국어 단어 구 수준 구분 모듈 문법 사전 지식 언어간 간 데 이용 시간 노력 뿐 복잡 개선 악영향 하나 계층 추가 독립적 다음 구성 첫째 조사 수준별 별 문법적 제대 수집 둘 어휘 등 패턴 쓰기 해결책 모색 셋째 설계 구현 성능 테스트 후 통합 향상 정도 기여 지 확인 결과물 개발중인 중인 기대 우선적 이슈 중요 상황 이 분야 공학 문서 인터넷 실시간 업무용 실생활 실용화 촉진 채팅 교육 소프트 소프트웨어 웨어 스마트 스마트폰 폰 번역기 개발등 응용
#
# fatigue index 교통사고 예방 자가 진단용 피로도 측정기 바이오 바이오센서 센서 의 기초 원천 원천기술 기술 개발 지표 운전자 정확 측정 수 스마트 스마트폰 폰 기반 측정기술 기초원천기술 타액 속 육체적 정신적 피로 관련 생체 생체물질 물질 코 코티졸 티 졸 알파 아 아밀레이즈 밀레 이즈 등 이 분비 실시간 고감도 진단 가능 연동 작동 호의 안정화 저가 휴대 스트립 형태 운전 중 구성 구성요소 요소 활용 뇌파 뇌파측정 기 측정기기 기기 신뢰성 확보 시스템 정량화 경보 알람 알람기능 기능 데이터 저장 향후 자동차 보험료 절감 절감기능 사고 사전 기대 연구 연구진의 진의 독자적 기존 음주 융합 날숨 시 가스 성분 침 호르몬 효소 전류 값 있음 음주측정기 당시 호응 호응도가 도가 초반 미 미미 현재 시장 선풍 사회적 기술적 상당 파급 파급효과 효과 예상 휴대용 자가진단용 졸음 졸음측정 형성 감안 경쟁력
#
# WiFiDirect,DevicetoDevicecommunications,Radioresourcemanagement,Energyefficiency,QualityofService,Trafficengineering,Broadcasting,Dutycyclecontrol,Offloading 기반 기 기기간 기간 통신 시스템 성능 향상 전력 절감 무선 자원 관리 직접 에너지 효율 서비스 품질 트래픽 엔지니어링 브로드캐 최근 무선랜 랜 장착 넥티드 휴대용 단말 폭발적 확산 2 클라우드 등 신규 모바일 활성화 말간 콘텐츠 공유 전송 출력 편이 표준 등장 셀룰라 통신망 단말간 간 관심 연구 목표 일차적 효율적 궁극적 협력 연동 뿐 전체 부하 감소 수 효과 효과적인 적인 메커니즘 설계 개발 기초 단계 응용 시나리오 요구 요구사항 사항 제약 지원 토 토폴로 폴로 구체화 후 컴퓨터 시뮬레이션 실험 방법론 이후 본 소모 다음 3 3가지 가지 주제 요소 기술 수행 비대칭 채널 경쟁 스트리밍 저하 원인 분석 접속 차별화 해결 방안 도출 배포 브로드 브로드캐스팅 캐스팅 릴레이 노드 결정 공간 재사 성과 속도 제어 신뢰성 수신 수신확인 확인 스케줄 스케줄링 링 지연 상반 관계 고려 최적화 문제 정의 볼륨 예측 플 우 특성 결과 최종 망 환경 근거리 링크 활용 목적 포함 상태 시그널 시그널링 최적 인터페이스 선택 간섭 회피 사용 보장 지속성 이용 범위 확장 현 시점 관련 전 세계적 가능성 검토 구체적 실현 실정 새 시도 산업 태 태동기 동기 문제점 이론적 배경 제공 기대 한 향후 마케팅 개인 방송 공공 공공안전 안전 분야 모멘텀 작용 이동 이동통신 인터넷 기여
#
# Hardware Security Module,Personal Authentication,Mobile Payment,Smart Watch,Fingerprint Authentication 온라인 전자 전자결제 결제 개인 개인인증 인증 보안 보안강화 강화 생체 생체인식 인식 의 융 융복합 복합 기술 적용 스마트 치 모바일 보안서비스 서비스 플랫폼 개발 보안토큰 토큰 모바일결제 지문 지문인증 1 시 본인 본인인증 환경 환경구축 구축 목표 보안매체 매체 융합 불법적 접근 개인정보 정보 유출 악의 사용 원천적 차단 수 나 사용자 안심 2 지문인식 기능 탑재 차세대 관련 관련시장 시장 선도 확대 대비 기존 스마트화치 화치 차별화 보안인증 제품 제공 경쟁력 확보 보안과 연계 신규 신규시장 창출 3 비 비접촉 접촉 대중교통 출입 출입통제 통제 소액 소액결제 등 편리 생활 생활밀착 밀착 활성화 기여 치의 기본 분실 분실방지 방지 생활편의 편의 교통 교통카드 카드 선 선불카드 불 결제수단 수단 신용 신용카드 체크 체크카드 오프 오프라인 라인 유통 유통결제 고객 편의서비스 효용 구현 금융 표준 이용 내의 지원 기반 범용 제어 내부 금융서비스 안전 다양 안테나 설계 개방형 자바 자바카드 을 표준코드 코드 애플릿 내장 인프라 지문정보 처리 지문모듈 모듈 대신 용도 관리 시스템 구축비용 비용 노출 위험 이 화면 문자 문자입력 입력 문제점 개선 4 저전력 4.0 저전압 회로 구성 절전 절전회로 무선 무선성능 성능 최적화 배터리 사용시간 시간 극대화 시나리오 최적 최적화한 화한 플 플리케이션 리 케이 션 4일 일 이상 5 방 방수 수 방진 기기 원활 방수기능 휴대 영향 안전성 산업 확대효과 효과 기대 타 사업자 시도 생체인증 선의 경쟁 신 생활형 활용 비접촉통신 통신 제어기술 멤버쉽 분야 인증서비스 형태 포털 포털사이트 사이트 운영 운영업체 업체 로그 로그인 인 다 글로벌 해외 해외시장 진출 기회 보안기능 지불 지불결제 발판 마련 일 일자리 자리 창출효과 분석 내외부 현황 수요 수요증가 증가 생산 생산업체 고용 인력 마케팅 광고 외부 유지 유지보수 보수 부 부품 품 소재 소재산업 확대가능성 가능성 파급 파급효과 제조 제품디자인 디자인 부품생산 디스플레이 결합 전력 디바이스 응용 웨어 웨어러 러 응용서비스 사용방법 방법 거치 추가 출시 출시기대 발달 이종 산업과 출현 컬러 액세서리 다변화 예상 업종 업종간 간 융합제품 제조업 확산 새 부가 부가서비스 형성 사업 요구 기타 결제인증 전자상거래 상거래 교통산업 선불 선불결제
#
# CyberSecurity,BigDataAnalysis,BayesianStatistics,AnomalyDetection,SmartGridSecurity,AdvancePersistentThreats 사이버 보안 빅 빅데이타 데이타 분석 분석기술 기술 이용 이상 이상신호 신호 탐지 시스템 개발 베이지 베이지안 안 추론 스마트 그리드 지능 지속 지속위협 위협 본 연구 정확 관련 대용량 시계열 데이터 이론적 응용 초점 예 국가 국가안보 안보 직결 발전소 전력량 변화 침해 침해사고 사고 분석결과 결과 신뢰도 불확실 고려 연산 연산속도 속도 정확도 동시 수 내부적 최근 상의 문제 농협 컴 컴즈 즈 개인 개인정보 정보 유출 일종 일반적 장기간 방어 공격 모델 공격모델 치부 만큼 사회적 부작용 피해 파장 각광 사이버보안 사용 이유 특징 때문 실시간 비정형 데이 과거 불가능 해결 잠재적 유용성 최고 신 신기술 축적 모든 단기간 관제 패턴 트렌드 빅데이타의 타의 기반 흔적 로그 구현 존재 사이버위협 고성능 알고리즘 고안 제안 목적 속 종류 분야 적용 가능 기업 기간 지적 재산권 보호 내부 비밀리 산업 산업스파이 스파이 범죄 발생 예상 예상지역 지역 기록 예측 방범 방범활동 활동 도로 도로망상 망상 교통 체증 교통사고 발생지역 위험
#
# Videotransmission,Videoscalability,Qualityofexperience,Subjectivequalityassessment,Objectivequalityassessment,Scalablevideocoding,Transmissionerror,Rateadaptation,Perceivedquality 비디오 스케일 스케일러빌리티 러 빌리티 전송 전송오류 오류 인지 인지기반 기반 화질 화질평가 평가 이용 적응 적응형 형 콘텐츠 경험 질 주관적 객관적 스케일러 압축 오 인 인지적 지적 기법 개발 이 바탕 다양 단말 네트워크 특성 다수 사용자 최상 제공 수 기술 목표 함 1 1차년 차년 데이터베이스 구축 옵션 메카니즘 관계 실험 연구 결과 기존 전 전기준법 기준법 성능 한계점 분석 새 2 2차년 환경 조건 악화 저하 요인 패킷 손실 등 이 영향 감소 감소기준법 3 3차년 스케쥴 스케쥴링 링 알고리즘 송 결합 최종 현재 뿐 차세대 통신 데이터 데이터량 량 효과적 활용 통신사업자 사업자 개발자 서비스 과학 분야 각종 화질저하 메커니즘 이해 활용새 강인 오류정정 정정 클라우드 추가
#
# RFID, TAG, Quality Comparison, Failure Analysis, Process Capability 무선 무선인식기술 인식 기술 제품 제품품질 품질 비교 비교분석 분석 산업화 지원 기반 기반구축 구축 태그 품질비교 고장 고장분석 성능 성능산포 산포 ㅇ 과제 국내 적용 적용제품 대역 수동형 제품별 고장유형 유형 관련 업계 기술력 향상 산업 품질제고 제고 산업과 융합 안정적 정착 목적 함 최종 목표 시장 시장수요 수요 확대 선진국 기술격차 격차 해소 수요기업 기업 고품질 저 비용 우수 우수제품 선택 선택기회 기회 제공 수요자 도입 도입효과 효과 만족도 수요확대 유도 공급 공급기업 자사 품질수준 수준 정보 적극적 품질경쟁 경쟁 품질개선 개선 글로벌 경쟁력 강화 시험 시험분석 시험분석기반 시험품 품 선정 요구 수량 적용산업특성 특성 장비 동률 맨먼스 변동 변동가능 가능 시험규격 규격 가이드 개발 업데이트 연도 적용분야 분야 현장 실태 실태조사 조사 시험절차서 절차 서 응용 응용요구기술서 기술서 주요 인프라 사항 기 보유 유관 유관기관 기관 활용 단계적 평가 시스템 운영 표준 표준규격 평가환경 환경 인식거리 거리 실 실환경 복수 복수태그 인식률 조성 수명 감 열화 외 기능 적합성 적합성시험 프로토 프로토콜 콜 성능시험 균일성 주파수 주파수특성 방향성 방향성특성 역방향 역방향평가 복수인식률 상호 상호운용 운용 성능산포시험 내환경 15 15종 종 가속 가속수명시험법 시험법 보증 보증시험 설계 설계마진시험 마진 품질경쟁력지수 지수 모델 산출 가중치 포함 고 고장품 장품 수집 현상 정리 태그고장유형 도출 기술서비스기반 서비스 기술지원 현 현장애 장애 기술상담 상담 기술지도 지도 시험데이터 데이터 기술자 기술자문 문 기술확산 확산 학술 학술대회논문 대회 논문 저널 저널논문 게재 특허 특허출원 출원 등록 연계 연계확산기반 현황 현황조사 국내외 대상 활성화 수요조사서 조사서 정보공유 공유 홍보 정책 동향 동향보고서 보고서 성과 관련기사 기사 행사 행사안내 안내 기고문 관련논문 등 월간 발행 별 품질비교보고서 보급 보급확산 전시회 컨퍼런스 설명 설명회 회 개최 참관 네트워크 활동 전문가 명단 표준활동 산업기반연구과제 연구 워크 워크샵 샵 간담회 공급자 운영자 운영자위원회 위원회 결과 방안 확산검증 검증 사업 성공적 추진 부착 물품 인지 우위 공신력 자료 열위 시 종합적 지침 성격 고려 무분별 교체 방지 정부 지자체 7 7대 대 전략 맞춤 완성도 보조 기대 파악 희망 상시 신 신제품 산업별 경제적 정량화 시험결과물 결과물 파급 의 경우 객관적 시험결과서 이용 공격적 마케팅 매출 증대 발생 신규 기존 관리 절감 기간 단축 적기 납품 기초 별도 검증비용 입장 가이드라인 수 있음
#
# Honeybee,disease,environmental monitoring,remote control,USN 기반 꿀벌 생육 생육환경관리 환경 관리 정보 정보제공서비스 제공 서비스 개발 질병 환경모니터링 모니터링 원격 원격제어 제어 센서 센서네트워크 네트워크 적용 꿀벌질병방재시스템 방재 시스템 구축 일반인 소지 휴대 휴대전화기 전화기 가정용 간편 신속 봉군 원격모니터링 질병징후 징후 수 환경요인 요인 고감도 환경변화 변화 상시 상시감시 감시 조기 조기대응 대응 가능 자동화 인력 광범위 분포 다수 상태 질병상황 상황 대응체계 체계 수립 확산 억제 질병발병요인 발병 조기제어 양봉 양봉농가 농가 실질적 도움 체계적 질병관리 개별 생산성 제고 기여 이 다음 기술 목표 융 융복합기술 복합 제어시스템 무선 스마트 기기 질병방재 전문가 진단 양봉기술 사양 사양관리기술 질병관리기술 짐 이 중 월동 후 약화 강군 육성 방법 요점 이 밀도 1 1개 개 소비 당 개체수 유지 양육 양육온도 온도 함 전체 성장 증가 을 있음 분봉 분봉열 열 발생 수준 꿀벌밀도 일명 벌 과다 급격 생산성저하 저하 야기 조절 시기 순차적 하나 정확 판단 추가 핵심 한편 감염 기생성 해충 구제 요약 병인 병인체 체 미국 미국부저병 부저 병 유럽 유럽부저병 등 세균성 6 6종 종 낭충 낭충봉아부패병 봉아 부패병 마비 마비병 바이러스 19 19종 노제 노제마병 마병 원생 원생동물성 동물성 3 3종 석고 석고병 백묵 백묵병 진균 2 2종 8 사항 장수 장수말벌 말벌 공격 집단 폐사 피해 세균 1종 원생동물 동물 15 15종 주요 진단법과 법과 방제 방제방식 방식 개별적 제시 연구 초 초개체 개체 대상 보편적 이상 검출 질병상태 포함 감지 스트레스 기대 기대효과 효과 양봉가 경험 의지 사양관리 검 확립 수십 년 의존 관찰력 대신 수신 과학적 신호 합리적 측면 벌이 해석 그 예 부족 양 양봉인 봉인 매뉴얼 숙지 투입 지 데이터 벌꿀 채밀 방 방제제 제제 처리 인지 면 침입 소문 차단 자동 자동제어 장치 만 내습 숙원 해소 일반 비용 개선 질병확산 궁극적 양봉산업 산업 사육 장착 사육환경 제어용 소형 제품 스마트 스마트기기 편리 상품화
#
# System lighting,Light source module enghine,signal space,high precison light control,context model 사용 환경 주거 오피스 적응 적응형 형 엔진 기반 시스템 시스템조명 조명 스마트 플랫폼 기술 개발 광원 광원모듈엔진 모듈 시공간 시공간신호처리 신호 처리 고정밀 고정밀조명제어 제어 상황 상황인식 인식 안정화 신뢰성 평가 미래형 기기 다종 이종 조명기기 런 런싱 싱 가중치 기법 실내 공간 개인 그룹 복합 지향성 다중 다중조명시스템 시공간신호시스템 연동 시나리오 검증 성능 테스트 상용 준비 시연 하이브리드 하이브리드형 조명기구 기구 최적 광학 광학설계 설계 변수 설정 목적 목적함수 함수 통합 테스트베드 베드 구축 프로그램 전체 최종 시작품 특성 분석 측정 소비자 소비자평가 수정 보완 구매 구매집단 집단 호응 조사 쇼 쇼룸 룸 실증 모니터링 연계 장기적 확보
#
# social,travel,service,wearable,FIT 소 소셜 셜 여행 포털 서비스 러 자유 자유개별여행 개별 여행정보 정보 등록 시스템 소요 소요시간 시간 위치 개발 일정 사진 글 입력 제공 카테고리 카테고리별 별 분류 평가 결과 추천 여행예약 예약 기능 구현 여행사 연동 수익 결제 내역 고객 발생 관리 분배 모듈 개인 페이지 현재 방문자 방문자수 수 창출 확인 여행코스 코스 사용자 사이트 여행자 코디네이터 상품 선택 상 상세화 세화 여행일정 예매 예매시스템 항공 기차 맛 맛집 집 명소 명소등 등 연 연동화 동화 종류 후 누구 기존 패키지 패키지여행 다양 경로 올림 평가시스템 경쟁 남 노력 수익분배 통 여행정보제공자 제공자 보상 주위 상점 광고 수수료
#
# ServiceOverlayNetwork,DistributeServiceModel,RealTimeVideoService,OverlayControl,OverlayManagement,OverlayTransmission,HeterogeneousEnv,ServiceQuality 서비스 오버레이 네트워크 실시간 영상 스트리밍 제공 핵심 기술 연구 분산 모델 대규모 제어 관리 본 공간적 영역 분포 다수 사용자 효과적 개발 이 기능 전송 이 알고리즘 별도 시스템 실제 상용 식별 구현 유무선 통신 정보 발달 어디 나 자신 최근 개인 방송 등 스스로 공급 욕구 증대 기 기존의 존의 클라인 서버 확장성 강 강건성 건성 유연성 저하 문제점 이용 제안 위 1 1차년도 차 년도 물리적 특성 고려 피어 선택 통 최적 구성 기법 그룹 멤버쉽 변화 품질 만족 재구성 방안 제시 2 2차년도 환경 노드 시간 가변적 수 세그먼트 측정 종단 종단간 간 예측 데이터 기반 오류 수반 정량적 보장 확률 평가 3 3차년도 단말기 종류 선호 접속 망 대역폭 신뢰도 가능 응용 계층 다 코딩 다중 경로 라 라우팅 우 팅 적용 새 통합적 동적 4 4차년도 외부 문제 필요 사항 솔류션 5 5차년도 기존 결과 토대 통합 표준 제정 구조 인터페이스 프로토 프로토콜 콜 국내 국제 유관 기관 반영 수요 지속적 증가 예상 클라이언트 경제성 인터넷 실정 수준 보급률 저가 보급 효과 효과적인 적인 상태 과제 차세대 신규 창출 활성화 견인차 역할 수행 국가 경쟁력 강화 일조 이 발전 이동 이동통신 접목 고부 가치 국제적 선도 향후 신 신성장 성장 동력
# SMART DTG,SMART DEVICE,OBD2,DTG,NAVIGATION 블랙 블랙박스 박스 기반 디지털 그린 운행 운행기록계 기록 계 개발 스마트 디바이스 연동 긴급 긴급구난서비스 구난 서비스 구축 스마트운행기록계 티 바이스 오 오비디투 비 디 투 디티지 지 네비게이션 목표 주관 주관기관 기관 유피 유피맥스 맥스 뮤 케이 케이션즈 션즈 운행기록계개발 스마트디바이스연동 관제 관제서버개발 서버 긴급구난서비스기반 연동테스트 테스트 참여 참여기관 씨 씨엠네트웍 엠 네트 웍 2 상용차 상용차모듈 모듈 영상 기능 내장 스마트디바이스 스마트폰 폰 연 연동 동 플 라 관제서버 마 시나리오 최종 바 기반구축
#
# smart glove,sign language,the deaf and dumb,motion recognition,language process 농아 농아인 인 수 스마트 장갑 개발 수화 동작 동작인식 인식 언어 언어처리 처리 다양 센서 탑재 하드웨어 소프트 소프트웨어 웨어 제품 디자인 관성 관성센서 등 기반 알고리즘 데이터 데이터베이스 베이스 텍스트 음성 기능 구현 한국 한국수화 수화동작 구축 최적화 설계 스마트장갑 시스템 사용 평가 주관 주관기관 기관 오펙 3 3축 축 가속도 속도 자이로 지자기 모듈 하나 칩 구성 초소형 센싱정보 원격 장치 사용자 스마트폰 폰 외부 서버 로 전송 무선 블루투스 통신 통신모듈 프로토 프로토콜 콜 적합 사용성과 성과 편의성 고려 연구 바탕 기구 시제품 정확 싱 싱정보 정보 신호 신호처리 과 에너지 효율적 프로 토 손가락 손 형태 추정 자세 자세측정 측정 제스처 움직임 패턴 정확도 기계 기계학습 학습 동작정보 특징 특징점 점 추출 수형 수위 수동 표현 범위 최대한 음성전달 전달 음성합성 합성 기기 플 플리케이션 리 케이 션 참여 참여기관 국민 국민대학교 대학교 1 기본 의사소통 가능 기초 기초단어 단어 선정 특수 특수상황 상황 기본적 응급 교육 2 신체적 때 모양 높이 강도 얼굴 얼굴표정 표정 의미 농아인의 인의 파악 요소 분석 연결 도출 동영상 클립 가이드라인 작성 문제 단계 행동 행동패턴 조사 정의 정의단계 관련 기술 동향 의사 의사표현 최소 선별 가능성 장갑간 간 인터 인터랙션 랙 아이디어 워크 워크샵 샵 실행 실행단계 시나리오 경 경험맵 험맵 장 장갑을 갑을 통해 변환 확인 디스플레이 와이어 와이어프레임 프레임 전문가 청각 청각장애인 장애인 대상 태스크 수행 성공 수행시간 시간 수행시 시 불편 다음 인터뷰 설문 실시 만족도
#
# biomedicalinformationretrieval,informationextraction,datamining,textmining,openresearchplatform,dataintegration 문헌 실험 빅 빅데이터 데이터 통합 통합분석 분석 탐색 시스템 개발 생명 생명의료정보검색 의료 정보 검색 정보추출 추출 데이터마이닝 마이닝 텍스트 텍스트마이닝 개방형 개방형연구플랫폼 연구 플랫폼 데이터통합 세부 목표 생명의료 객체 관계 활용 표준화 구축 본 식별 수 기술 이 구축함 기존 독립적 존재 데이터베이스 이 소프트 소프트웨어 웨어 기반 확장 연구자 자발적 참여 플러그인 공유 커뮤니티 국내 글로벌 경쟁력 제고 도모 본 공개 베이스 네트워크 수행 나 아가 각종 1 1단계 단계 직접 가능 문헌기반 이 등장 유전자 변이 약물 셀 셀라인 라인 질병 질병이름 이름 등 다양 사이 2 현존 3 네트워크기반 임상 활용가능 단위 바이오 바이오마커 마커 발굴 억제 억제경로 경로 파악 파악기술 효과적 조합 적극적 직관적 해석 4 표준 구성 세트 개방 동시 뿐 분야 창출 있음 유도 관련 가속화 기대 시작 이론 이론수준 수준 적용 촉발 세계 세계수준 확보 예상
#
# SaaS,Big Data,Personalized Engagement,Mobile,Cloud 모바일 앱 웹 통합 사용자 행동 추적 빅 빅데이터 데이터 처리 기술 멀티 채널 개인 메시 메시징 징 솔루션 서비스 소프트 소프트웨어 웨어 고객 고객응대 응대 클라우드 1 1차년도 차 년도 기본 구성 구성요소 요소 개발 기반 나 아가 프로 프로화일 화일 트랙 트랙킹 킹 분석 시스템 실시간 구매 구매내역 내역 목표 기존 보유 웹메시징 완성 아래 구현 실시 간 2 2차년 차년 동시 향후 속도 수 3 3개 개 개별 각각 구현시 시 베타 품질 높임 방향성
#
# Big Data,Digital Signage,Realtime Visualization,Platform,Smart Service 클라우드 기반 디지털 사이 사이니지 니지 플랫폼 빅 빅데이터 데이터 디지털사이 실시간 실시간시각화 시각화 스마트 스마트서비스 서비스 1 1차년도 차 년도 목표 환경 개발 범위 실제 고객 고객단 단 요구 요구사항등 사항 등 반영 명세서 바탕 과제 틀 우선 정립 주간 주간기업 기업 참여 참여업체간 업체 간 기술 파트 서로 서로간 간 접점 효율적 수행 수 역 정의 신경 역할 완료 이후 1차 차 년도 주 코어 시스템 웹 웹환경 구축 병행 진행 향후 연동 설계 특화 기능 추가 구현 독립형 가지 버전 프로세싱 제품 기획 최종 아웃 아웃라인 라인 상용 상품 구성 2 수집기 최신 오픈 오픈소스 소스 도입 소 소셜데이터 셜 문서 공공 공공데이터 오픈데이터 수집 엔진 엔진개발 3 분석 분석기능 적용 의사 의사결정나무 결정 나무 신경망 기법 인공 인공지능 지능 마이닝 통계 알고리즘 커스 커스터마이징 터 마이 징 키워드 키워드기반 4 배포 가능 대상 확정 지속적 구조 지속 지속적인 적인 라이브러리 셋 유형 자체 정형 비정형 학습 사용 연관성 패턴 파악 20 20여가지 여 가지 차트 반응 태그 웹기반 관리 관리툴 툴 구상 기존 프로그램 형태 에디터툴만 장점 단점 필수 도출 운용 운용상 상 필요 최초 시 구분 유저 유저별 별 접근 권한 설정 로 효율성 높임 타 솔루션 연동형 외부 콘텐츠 모듈 유니버셜 타입 별도 스케줄 수정 편집 추가함 함 플레이어 앞 언급 바 경우 에디터 에디터툴 설치 안 안드로이드 드로 이드 본 2년 년 이전 다양 다양항 항 안정성 작업 최적화 중 발생 발생가능 처리 성능 멀티 멀티템플릿 템플 릿 멀티채널 채널 안정화 우선적 1차년 차년 종료 종료후 후 인포 인포그래픽 그래픽 부분 응용 사이트 적용해서 해서 생성 생성간 대비 시간 절감 효과 하나 기본 파생 서브 활용 초기 부족 상황 대응 수익 모델 제안 추진 별개 통해 라이프 사이클 무제한 증가
#
# Energy saving,Integrated Control System,Efficiency Optimization,Compressor,Maintenance Decision 공기 공기압축기 압축기 통합 통합제어 제어 기반 공압 공압시스템 시스템 에너지 절감 효율 최적화 구축 통합제어시스템 유지 유지관리 유지관리의사 관리 의사 결정 1 1차년 차년 개발 목표 산 산업체 업체 유형 운전 운전패턴 패턴 분석 최적 방안 도출 사용 사용업체 단조 조선 자동차 식품 등 대표 대표업체 구성 표준 분류 경계 설정 운전효율 내역 외부 외부요인 요인 상관 상관관계 관계 처리 의사결정 모델 기술적 측면 융합 융합기술 기술 산업 활성화 서비스 제공 차별화 수 있음 축척 데이터 중심 설계 정확 전력 소비량 산출 기존 사업 연계 토탈 솔루션 산업분야 분야 관련 정책 수립 시 시설 도입 지역 온실 온실가스 가스 효과 반영 가능 제도 제도개선 개선 연구 활용 경제적 경제적산업 최종 실증 국산화 해외 수입 대체 기계 전문 전문인력 인력 육성 제조 제조기업 기업 관리자 양성 고용 고용창출 창출 기대 전략적 비즈니스 추진 고부 가치 비즈 비즈모델 대규모 사업장 확산 확산기여 기여 한 신규 적용 효과적 그 이익 도모 수요 수요기업 공급 공급업체 국가적 현장 제시 개발업체 수익 확대 강화 촉진 고용창출효과
#
# Worstweatherimageenhancement,ObjectrecognitionTracking,DynamicRangeCompression,Noisereduction,Realtimeimageprocessing,Retinex,Computervision,UAV,Drone 무인 무인항공기 항공기 론 활용 통합 통합형 형 실시간 고속 고속영상처리 영상 처리 기술 개발 악천후 영상개선 개선 객체 객체인식 인식 추적 다이나 다이나믹 믹 영역 압축 잡음 잡음제거 제거 영상처리 레 레티넥스 티 넥스 컴퓨터 비전 항 최근 미국 민간 허가 사용 가능 지면 장착 카메라 사건 사고 발생 때 상황 전송 효율적 초동 초동대응 대응 수 한 해외 상품 배송 관리 배송중계 중계 이 본 과제 획득 계산 복잡 복잡도와 도와 연산 연산량 량 최소 최적화 1 1차년 차년 시스템 프레임 작업 단계 안정적 영상분석 분석 저조 통계학 접근 특징 추정 선명 시야 시야확보 확보 안개 안개제거 영역기반 기반 2 2차년 호환성 검증 유사 지역 지역구조 구조 고려 기상 기상상태 상태 실시 간 객체추적 그래프 매칭 3 3차년 완성 간 복원 융합 화질 이용 파라미터 초고 초고해상도 해상도 영상생성 생성 알고리즘 구현 파노라마 랜덤 포 포레스트 레스트 산불 산불연기 연기 검출 기대 기대효과 효과 응용 응용분야 분야 활용범위 범위 기존 디지털 캠코더 초고화질 항공 위성 감시 보안 탐색 강화 연구 구현결과 결과 관련 연구인력 인력 배출 학문 학문발전 발전 기여 차세대 선 선점유 점유 첨단 첨단기술 이전 산업 경제
#
# Wirelesssensornetwork,Industrialdistributedcontrolsystem,Realtimecommunications 산업용 분산 분산제어시스템 제어 시스템 폐쇄 폐쇄제어루프 루프 구현 무선 무선센서네트워크 센서 네트워크 기반 실시간 무선통신기술 통신 기술 개발 실시간통신 본 연구 프로 프로토콜 토 콜 이 다음 특성 필드 필드버스 버스 요구 엄격 신뢰성 보장 응용 프로세스 프로세스간 간 1 다 통신모델 모델 효율적 지원 발생 주기적 메시지 제한 자원 수행 수행가능 가능 전체 5 5년 년 연 연차별 차별 연구목표 목표 연구내용 내용 1차년 차년 적합 무선링크 링크 성능 평가 평가척도 척도 측면 기존 비교 비교분석 분석 2 2차년 라 라우팅 우 팅 우선 우선순위 우선순위기반 순위 패킷 스캐쥴 스캐쥴링 링 알고리즘 성능분석 3 3차년 멀티 멀티캐스팅 캐스팅 상 멀티캐스트 캐스트 포함 개발-1 -1 4 4차년 이용 프로토타입 타입 5차년 현장 현장적용 적용 테스트 작업 작업현장 시나리오 작성 테스트베드 베드 구축 결과 개선 응용분야 분야 공장 공장자동화 자동화 산업체 제조 제조환경 환경 모니터링 차량 차량간 간 등 활용 활용범위 범위 산업 산업현장 위험 위험요소 요소 경보 경보기능 기능 산업재해방지시스템 재해 방지 자동차 조선 조선산업 제조라인 라인 장비 제품 제품상태 상태 안전 안전주행 주행 필요 기대 기대효과 효과 학문적 기술적 논문 논문발표 발표 국제 국제논문 3편 편 국내 국내논문 국제학술회의 학술회의 5편 설계 플랫폼 임 임베디 베 디 경제 제어시스템 비용 절감 작업위험 근로자 작업환경 작업능률 능률 향상
#
# Largescalescenereconstruction,Realtimealgorithm,Polygonalgeometryreconstruction,Indoorscenehierarchicalstructureanalysis,RGBDvideo 계층 구조 구조정보 정보 기반 실시간 대규모 환경 복원 알고리즘 다각형 기하 기하정보 실내 분석 동영상 본 연구 빌딩 내부 체육관 등 렌더링 가능 모델 속도 목표 촬영 입력 이로 모델링 삼차원 이 처리 수 평면 입방체 추출 기술 카메라 위 추정 개발 구조물 바탕 효과적 배치 한 효율적 수행 사용자 이 이용 몰입 몰입형 형 증강 증강현실 현실 시스템 프로 프로토타입 토 타입 구축 응용 가능성 세부 각 구성 요소 다음 최적화 기법 영상 물체 분리 검출 계층구조 이해 실시 간 적합 상호 상호작용 작용 인터페이스 학술적 기대 기대효과 효과 컴퓨터 전과 그래픽스 분야 모두 발전 기여 핵심 핵심기술 기존 활용 활용방안 방안 건물 소방 소방훈련 훈련 다양 위치 위치인식 인식 인테리어 변경 설계 설계도가 도가 문화재 환경복원
#
# mobiledeviceenvironment,voicesearch,speechrecognition,unsupervisedlearning,Bayesianlearning,interactivelearning,acousticmodel,languagemodel,highquality 모바일 환경 고품질 음성 음성인식 인식 기반 응용 응용서비스 서비스 비 비교사 교사 베이지 베이지안 안 상호 학습 기술 연구 기기 음성검색 검색 음향 음향모델 모델 언어 언어모델 스마트 스마트폰 폰 등 이용 자동 자동통역 통역 문자 메시지 음성인식기의 기의 개발 목표 실제 발생 사용자 발성 발성변이 변이 주변 다양성 직접적 반영 광대 분량 로그 데이터 해당 레이블 추가 추가적인 적인 제공 즉각적 훈련 사용 기법 기존 구축 파라 파라메터 메터 사전 사전확률 확률 정보 동시 점진 점진적이면 적이면 효율적 성능 확보 수 간 존재 상호보완 보완 개별 통합 간 결과 전체 음성인식시스템 시스템 광범위 활용 활용분야 분야 포함 장애 장애요소 요소 극복 일상생활 주요 영역 활용도 획기적 음성합성 합성 적용 음성답변 답변 방식 통계 통계모델 적응 방법 레이블링 링 작업 필요 막대 비용 시간 절감 수집 음성인식기 기 자동훈련 관련 핵심 핵심원천기술 원천 지적 지적재산권 재산권 핵심적 응용분야 진입 진입장벽 장벽 시장 선점
#
# Seoul Accord,Spreading of CAC 서울 서울어코드위원회 어코드 위원회 운영 공학 공학교육인증 교육 인증 연구 서울어코드 초대 사무 사무국가 국가 사무국 경험 바탕 ㅇ 활성화 위상 제고 기여 국제적 리더십 확대 분야 공학인증 증 제도 제도개선 개선 우수 공학인력 인력 양성 산업체 수요 부합 학습 학습성과 성과 전문 전문역량 역량 보유 전문인력 시스템 구축 지속적 국제 국제교류 교류 국제적인 적인 협력 확보 우리 우리나라 나라 공학교육 증진 경쟁력
#
# Seoul Accord,Spreading of CAC 창의 미래 미래기술지향 기술 지향 산 산업체 업체 밀착 전문 전문인재 인재 양성 서울 서울어코드 어코드 실무 역량 수요 수요지향 인재양성 교육 교육혁신 혁신 내실 기초 실무역량 제고 산학연 학연 기초역량 강화 ㅇ 학생 아이디어 아이디어형 형 멘토링 중심 산학 산학협력 협력 프로젝트 기업체 수요형 확대 질적 수준 학 결과물 특허 등록 논문 등 연계 수 수준의 유인 교과 교과과정 과정 인턴 을 중소기업 개별 개별기업 기업 맞춤 맞춤형 산학연계 프로그램 추진 대학 등의 활동 학점 채용 참여 운영 운영위원회 위원회 구성 환경 산업 산업수요 적합 개선 수 시스템 확보 우리 우리나라 나라 정보 정보통신산업 통신 분야 핵심 핵심인재 교육기반 기반 구축 기술개발 개발 실 실습 습 경험 졸업생 배출 국내 신입 사원 재교육 부담 경감 정보통신 산업계 업계 요구 적극 반영 교육과정 실용적 인력 교육환경 교수진 연구 학부 총체적 질 향상 기능 기준 만족 양질 산업기술자 기술자 정보통신분야 국가 경쟁력 활성화 글로벌 표준 확립
#
# LED,System Lighting,Multi Sensor,Wire/Wireless Communication Module,tandardized Engine Module 시스템 시스템조명 조명 핵심 핵심부품 부품 원천 원천기술 기술 적용 응용 응용기술 개발 티 센서 유무선 통신 모듈 표준 엔진 제어 주관 주관기관 기관 총괄 세부 세부과제 과제 1 기능 여부 확인 2 제품 3 시나리오 작성 워크 워크샵 샵 운영 운영위원회 위원회 세부과제간 간 컨셉회 과제간 간 협력 연계 통합 연계성 효과성 산업화 추진 검토
#
# RT(Radiation Therapy),RTP,RTQA,RT Chart(OIS),Moblie 방사선 방사선치료 치료 관리 통합 솔루션 개발 방사선치료계획 계획 방사 방사선량 선량 검증 차트 모바일 전체 시스템 임 임상 상 적용 시험 평가 성 성능 능 최적화 제품 1 다양 치료관련 관련 영상 저장 데이터 방법 종류 구조 테스트 시나리오 수립 표시 항목 사용자 2 간 정합 보완 모듈 3 치료계획 결과 도시 분석 기능 파라 파라메터 메터 등 대상 선정 모의 확보 샘플 일정 개선 4 적용영상 복부 확장 적용기관 기관 3차년 차년 기반 기반기술 기술 간 신장 분할 밝기 밝기값 값 유사 주변 주변기관 발생 다기관 가능 3차년도 차 년도 흉부 좌우 좌우폐 폐 심장 연결 집중 4차년도 견고 견고히 히 수 함 5 위치 비교 6 치료장치 장치 연동 지원 외부 영상기반 근접 근접방사선치료 장비 토모 치료계획장치 획득 7 정보 정보시스템 사용 사용환경 환경 선 량 시제품 -3 실제 환자 수행 연구 5건 건 이상 병용 교차 절 절데 데 모니터링 선형 선형가속기 가속기 토모치료기 치료기 설치 후 2개월 개월 감지 기록 정립 생성 오류 수집 배 배포 포 설치도구 도구 파일 프로그램 업데이트 시 온라인 자동 간의 일원화 뷰어 제공 라이선스 정책 토대 진행 서버 서버기반 컴퓨팅 패키지 구성 요소
# Smartgrid,Demand Response,Energy Storage,Economic Evaluation,Smartgrid Network Communication Platform 스마트 스마트그리드 그리드 비즈니스 비즈니스융합 융합 고급 고급트랙 트랙 수요 수요반응 반응 에너지 저장 저장장치 장치 경제성 평가 통신 네트워크 플랫폼 기업 기업참여 참여 전력 경제 경영 수요맞춤 맞춤 운영 전기 에너지분야 분야 정보 정보통신분야 경영분야 특화 교육 교육과정 과정 제공 연 연차별 차별 교재 교재개발 개발 목표 4 4차년도 차 년도 실시간 요금 공통 인력 인력양성 양성 사업 사업목표 동계 하계 단기 강좌 전력경제 워크숍 실증 실증단지 단지 견학 연구 연구논문 논문 지도 국내외 학술지 논문게재 게재 학술 학술대회 대회 논문발표 발표 정보교류 교류 기회 전문가 세미나 기술 습득 산업체 연계 실무 실무능력 능력 배양 저 1 연구부 기상 기상인자 인자 고려 전력수요예측 예측 피크 피크부하절감 부하 절감 부하평준화 평준화 배터리 이용 에너지저장시스템 시스템 적용 방안 나 2 통합 유무선 소프트 소프트웨어 웨어 시뮬레이터 검증 최적화 다 3 투자 투자촉진 촉진 정책 사업모델 모델 관련 전력수요 신규 발굴 적용방안 기상민감도 민감도 데이터 통계 통계분석 분석 연동 최적 최적운영 계획 예비력 확보 수요관리 관리 필요량 산출 산출방안 계통 계통연계 모의 효과 재생 재생에너지원 에너지원 발전량 충 충방전 방전 상태 효과적인 적인 검토 이종 종류 전송 파라미터 입력 스마트폰 폰 웹 플 플리케이션 리 케이 션 개별 기준 구성 알고리즘 디버깅 시행 소비자 선택 요금제도 제도 확대 판매 판매사업 경쟁 활성화 특성 반영 자발적 을 위 모형 현장 최신 이론 구현 통신기반 기반 활용 활용방안 제시 세계 시장 선도 제품 제고 비즈 니스 전략 보급 확산 기여 국내 산업 발전 녹색 녹색성장 성장 구체적 도구
#
# RFenergyharvesting,rectenna,rectifier,rectifyingcircuit,impedancematching,voltagemultiplier,wirelesspowertransmission 무용 공중 공중전파 전파 활용 저전력 에너지 하베스팅 연구 하 하베스팅 베스 팅 렉 렉테 테 정류기 정류 정류회로 회로 임피던스 매칭 매칭회로 전압 전압체배기 체배기 무선 무선전력송신 전력 송신 산재 비의 비의도성 도성 다중 주파수 주파수대역 대역 효율적 재활용 하베스터 터 개발 융합 원천 원천기술 기술 확보 응용 응용산업분야 산업 분야 적용 수 응용기술 최종 최종목표 목표 1 1차년도 차 년도 의도 단일 수신 고효율 설계 제작 전력레벨 레벨 감응 감응형 형 변환 효율 렉테나의 나의 핵심 핵심요소 요소 안테나 2 2차년도 통합 성능 성능평가 평가 알고리즘 3 3차년도 센서 센서노드 노드 이동 이동형 전파에너지 하베스 특성 특성평가 최적화 등 소 소전력 전원 가능 응용디바이스 디바이스 기술적 측면 유비 유비쿼터 쿼터 술 장치 지능 등에 을 공급 경제적 배 배선 선 시스템 관련 정기적 유지 유지관리 관리 비용 뿐 초기 장소 설치 데 필요 작업 애플리케이션 배터리 교체 요구 제거 사회 문화적 녹색 새 정부 규제 환경 환경관련 문제 곳 사용 재생 대 증가 가운데 사회적 시대적 해소 인력 인력양성 양성 학위 과정 학생 참여 욕 고취 이론 실무 접목 중요 계기 장비 프로 램 능력 배가 기타 자체 외부 너지를 인체 내 삽입 임 임플란트 플란트 기기 공급원
#
# CPUscheduling,SoftwareDevelopment,Packetscheduling,Smartdevice,LinuxKernel,CrossSystemoptimization,Multicore,Android,QoSQualityofService 스마트 디바이스 다중 홉 네트 네트워킹 워킹 시스템 협력 스케줄 스케줄링 링 기술 연구 임 임베디드 베 디드 소프트 소프트웨어 웨어 개발 프로세서 패킷 스마트 스마트기기 기기 리눅스 널 교 교차 차 최적화 멀티 멀티코어 코어 안 안드로 드로 본 동작 다양 실시간 멀티미디어 플 플리케이션 리 케이 션 효율적 지원 목표 1 다수 처리 수 저전력 기반 2 종단 종단간 간 보장 네트워크 측면 3 단말 의 협업 기법 알고리즘 제시 마지막 단 기여 하드웨어 성능 향상 현재 대부분 쿼드 쿼드코어 탑재 증강 증강현실 현실 대용량 데이터 전송 요구 복합 들 등장 이 필요 내부 지연 상의 지연시간 시간 상당 소비 전력량 프로 세서 연산 관리 전달 관련 다음 3가지 가지 접근 방식 전술 문제 해결 확보 첫째 동시 수행 바 우선 우선순위 순위 차별화 작업 자원 할당 중요 에너지 효율 연산처리 능력 둘 트래픽 송 수신 손실률 처리량 지 지터 터 등 고려 시 공간적 변화 무선 채널 상태 에러 발생 노드 사이 셋째 과제 기존 간과 과도 연산량 량 서비스 내 간의 제안 시장 창출 대 기대 가능 한 산업 경쟁력 강화 예상
#
# ABC 이종 이종기기 기기 시스템 프로그래밍 아키텍처 협력 기술
#
# IT, SAR, Ship Area Network 해상 애드 애드혹 혹 네트워크 기반 선박 안전 안전운항 운항 솔루션 개발 자동 자동운항 해상안전운항 최종 최종목표 목표 공통 데이터 모델 지원 플랫폼 광대역 무선 통신 인프라 응용 서비스 구현 연근해 100 반경 1 이상 무선통신 연근 연근해상 안전관리 관리 원격 원격관리 등 6 6건 건 기술 멀티 릴레이 연계 이동 위성 해상통신 연계기술 통신거리 거리 통합 교환 프로 프로토콜 토 콜 6종 종 세계적 국내 바탕 고부 가치 확보 인터넷 제공 도모 통신기술 시장 창출 중소 기업 글로벌 경쟁력
#
# NonvolatileMemory,MRAM,OperatingSystem,VolatileMemory,DRAM,BootupTime,Lowpower,DataIntegrity,ComputerArchitecture 기반 임 임베디드 베 디드 운영 운영체제 체제 연구 휘발성 램 메모리 부팅 시간 저전력 데이타 안전성 컴퓨터 구조 현재 전원 공급 데이터 때문 필요 저장 저장장치 장치 부팅시간 전력 소모 정전 손실 단점 대신 메인 사용 제로 초 절전 안정성 제공 기술 목표 초소형 계획 세부 주제 아래 최적화 파일 시스템 관리 본 프로세스 통합적 새 제안 예정 제로시간부팅 지원 기법 소비 절반 이하 획기적 신뢰성 향상 보장 수 결과물 기대 기대효과 효과 예상 종료 종료시간 제로인 인 상용 초경량 결과 국내 산업과 해외 시장 삼성 삼성전자 전자 하이닉스 반도체 기업 미래 선점
#
# nonphotorealisticanimation,pencildrawingstylization,painterlyrendering,rigidbodydynamics,videofiltering,motionestimation 비디오 펜화 파스텔 유화 붓 시뮬레이션 애니메이션 생성 비사 비사실적 실적 연필화 스타일링 렌더링 강체 역학 필터링 움직임 추정 등 스트로크 기반 그림 스타일 일반인 꾸밈 편집 수 자동화 방법 방식 적용 기본 기본적인 적인 프레임 프레임워크 워크 자연 효율적 도출 시스템 이미지 성질 모델링 위치 밀도 방향 텍스 크기 매 파라 파라메트릭 메트릭 매핑으 색상 알파 알파블렌딩 블렌딩 수행 모델 강체역학 이동 회전 변환 시간적 일관 수정 검출 옵티칼 플로우 사용 객체 값 시공간 플 우 계산 라 속도 조절 구상화 추상화 특성 적합 아티스트 효과 자동 생산 제공 저작 구로 추후 바탕 스마트 디바이스 용 소프트 소프트웨어 웨어 드라마 게임 게임제작 제작 영상 표현 독특 가능성
#
# ProgramAnalysis,StaticAnalysis,StringAnalysis,LRParsing,HTMLValidation,InjectionVulnerability,AutomatedRepair,WebApplication 웹 응용 소프트 소프트웨어 웨어 자동 검증 보안 보안약점 약점 탐지 기술 개발 프로그램 프로그램분석 분석 정적 정적분석 문자열 문자열분석 파 파싱 싱 유효성 유효성검사 검사 삽입 취약 취약점 점 수정 응용소프트웨어 대표적 방 방법인 법인 요약 요약해석기법 해석 기법 파싱이론 분석기술인 기술인 요약파싱기법 목표 현재 보유 생성 문서 문법 추가 의미 의미분석 수행 틀 첫째 파싱복구이론 복구 이론 문법오류 오류 둘 외부 입력 삽입공격 공격 가능 지 수 오염 오염여부분석 여부 크로스 크로스사이트스크립트 사이트 스크립트 마지막 셋째 접근 평가 도구 기존 실제 대상 동적 분석방법 방법 소스 소스코드 코드 차원 권한 환경 환경문제 문제 이 등 조합 작성 나 질의 질의문 문 유용 요약파싱기술 요약파싱 축 확장 생성가능 핵심 핵심구문트리 구문 트리 집합 파스 파스그래프 그래프 기반 세가지 응용기술 접목 파싱오류 발생 경우 한번 연구 신뢰 외부입력 악의 동작 이용 이 수준 원천적 지침 사용 접근권한 일부 비율 요약파 때문 준수 준수여부 확인 요소 사람 눈 다수 요약파싱으 웹페이지 페이지 필요 다음 기대 기대효과 효과 예상 자동수정 최근 다양 방향 계속 휴 휴리스 리스 기본 기본적이면 적이면 상 위치 효과적 대안 제시 상용 상용도구 시도 의심 지점 뿐 공격사례 사례 방어 방어방법 부족 과제 제안 발생가능 예제 파악 2008 2008년 년 4 4월 월 11 11일 일 장애인 차별 금지법 시행 이후 공공 공공기관 기관 요구 5 5년 유예 유예기간 기간 2013 2013년 민간 민간기업 기업 검토 누락 평가여부 방안
#
# data vitualization,distributed cloud,big data analytics platform,convergence analysis,multi tenant 대 대형-5세부 형 -5 세부 분산 클라우드 환경 데이터 컴퓨팅 자원 유동적 공유 융 융복합 복합 분석 가능 멀티 멀티테넌트 테넌트 플랫폼 개발 가상 복합분석 빅 빅데이터 지리적 다종 지원 아키텍처 핵심 기술 설계 서비스 에코 에코시스템 시스템 연동 접근 접근제어 제어 프레임 프레임워크 워크 계정 관리 사일로 간 플 플리케이션 리 케이 션 실행 별 다 수준 기종 성 동적 위치 위치정보 정보 코드 요구 요구사항 사항 맞춤 맞춤형 실시간 프로 프로비 비 닝 메모리 소토 소토리지 리지 네트워크 의 배치 배치기술 이동 최소화 최적화 상의 알고리즘 코딩 스크립트 그래픽 방식 다중 인터페이스 워크플 우 생성 생성관리 시험 구축 시범 공공 민간 활용 공개 커뮤니티 운영 차세대 성장 동력인 분석서비스 시장 흐름 주도 해외 업체 지배 소 소셜네트워크분석 셜 데이터마이닝 마이닝 텍스트 텍스트마이닝 등 유기적 순환적 복합적 상용 세계 대규모 수익 창출 기대 2017 2017년 년 이후 연간 해외시장 250 250백만 백만 약 2500 2500억원 억 원 국내 국내기장 기장 14 14백만 150 150억원 이상 매출 효과 시장규모 규모 5000 5000백만 예상 5 시장점유 점유 시 70 70백만 20
#
# NextGenerationStorageDevice,VirtualMemory,NextGenerationNonVolatileMemory,MMAP,SWAP,OperatingSystem 차세대 저장 장치 고려 소프트 소프트웨어 웨어 기반 메모리 확장 기술 연구 저장장치 가상 휘발성 스왑 운영 운영체제 체제 본 접근 지연 시간 목적 최적화 기존 페이지 폴트 처리 회수 부분 관리 방식 설계 구현 이용 수행 개발 활용 탑재 시스템 구축 바탕 리눅스 성능 입출력 패턴 분석 이 연구진이 진이 보유 보드 사용 에뮬레이션 실제 워크 워크로드 로드 스택 프로 프로파일링 파일링 고속 인터페이스 연속 쓰기 연산 병합 수 읽기 동시 점 병목 지점 개선 적용 병목지점 비효율 유발 문맥 전환 최소화 방법 대용량 효율적 기법 본격화 상태 때문 핵심 중의 하나 하나인 인 이슈 제시 선점 방향 연구가 요구 메인 메인메모리 데이터베이스 응용 클라우드 컴퓨팅 분야 검증 서버
#
# IFC 골조 외피 최적화 설계 시공 시공기술 기술 혁신 융합 융합기술개발 개발 최적 최적설계 설계도서 도서 건축 건축정보모델링 정보 모델링 시공관리 관리 마이다스 마이다스아이티 아이티 정보기반 기반 엔진 통합 플랫폼 구축 기획 엔진기반 기하 구조 기능 해 해석 석 구조설계 생성 2 3 기하모델 모델 프로젝트 단위 강도 내진 내진해석 강도검증 검증 자동 자동설계 평면도 단면도 부 부재 재 일람표 작성 환경 유 유누스 누스 구조물 분석 물량 물량산출 산출 프로세스 철골 철골자재 자재 시공공정 공정 시 시공관 공관 시공현황 현황 공 에너지 전자 전자부품 전자부품연구원 부품 연구원 센서 클라우드 협업 단계 계측 요구 요구사항 사항 데이터 수집 등록 형식 포스 포스코건설 코 건설 실무자 실무 활용 검토 공종별 종별 업무 입력 입력정보 범위 시스템 적용 조직 구성 방안 도면 정보입력 기존 가능 시공사 공사 설계도 기준 기준양식 양식 정리 정합성 제공 실용성 자재별 별 부위별 작업 작업방식 방식 산출물 결과 비교 자재정보 시공현황관리 수행 상용 그리기 편집 포함 정보관리 추가 특화 자동전환 전환 규모 효율적 저장 수 모듈 설계정보 통합관리 정보통합관리시스템 필요 선형 비선형 정적 정적해석 국내 중국 일본 탑재 정보모델 구조계산서 계산서 등 서류 대상 자재종류 종류 철근 콘크리트 추출 소요 생산 배송 설치 작업지시 지시 현황보고 보고 현황관리 기타 설비 효율성 사전 과거 효율 지표 피드백 유형 항목 특성 조건 데이터베이스 베이스 기본 검색 제어 표준 체계 설정 전송 에뮬 에뮬레이터 레이터 플 플리케이션 리 케이 션 네트워크 상황 제한 접근 공유 실시간 대용량 처리 대비 완성도 지원 기술적 측면 다양 설계기술 확보 패키지 관련 설계업체 업체 보급 확산 기술경쟁력 경쟁력 향상 초기 설계단계 뿐 공정관리 공사용 사용 시공단계 신뢰성 있음 경제적 산업 국산 솔루션 고가 외 외산 산 대체 연간 1,000 1,000억원 억 원 시장 수입 수입대체 효과 이 외화 외화절감 절감 합리적 가격 건설설계 산업분야 분야 기여 정보화 건설융합 부분 제품 건축구조물 시공계획 계획 최적안 안 컨설팅 서비스 전문화 새 비지니스 창출 발생 사회적 업계 교육 교육기관 기관 학계 능력 인력 육성 세계적 강국 우수 전문가 진출 유도 긍정적 기대
#
# power consumption,pay broadcast,set-top box,power management,Low power 유료 유료방송 방송 셋톱 셋톱박스 박스 소비 소비전력 전력 저감 기술 개발 저전력 전력관리 관리 주요 주요기능 기능 규격 제어 동작 동작모드 모드 전원 전원관리 고속 복귀 전환 미들 미들웨어 웨어 정보 정보보호 보호 모듈 정합 매체 전력제어 운영 플랫폼 대기 대기모드 최적화 프로그램 변환 파라미터 프로 프로토콜 토 콜 클라우드 가상 적용 전력소모 소모 절감 절전 효율 분석 보 보안 안 접근 채널 데이터 사용자 장비 서버 상호 인증 키 키관리 불법 원격 접속 생성 프로세스 구동 구동여부 여부 자동 탐지 대응 웹 웹브라우저 브라우저 등 플 플리케이션 리 케이 션 취약 패치 패치관리 대기전력 핵심 소프트 소프트웨어 위성 네트워크 협력 협력기반 기반 표준화 콘텐츠 해킹 상 상요화 요화 국내 보급 1 시 약 330 330억원 억 원 발전 발전용량 용량 확보 투자 투자비 비 절감효과 효과 발생 8 현재 10 2 2,640 2,640억원 해외 관련 규제 규제사항 사항 선제 시장 경쟁력 수출 증대 세계적 디지털 2011 2011년 년 150 150억 달러 수준 2015 2015년 159 159억 연평균 1.3 의 성장세 전망 생산액 2006 2006년 지속 지속적인 적인 증가 증가추세 추세 2010 2010년 2조원 조 규모 돌파 2012 2012년 년 정보통신산업통계 통신 산업 통계 연보
#
# Power free, Wireless, Sensor network, Railroad, Monitoring 철도 철도시스템 시스템 미래형 무선 스마트 싱 기술 자가 자가발전 발전 센서 센서네트워크 네트워크 모니터링 고속 주행 철도차량 차량 가혹 통신 환경 수 주변 주변에너지 에너지 스스로 전원 생산 개발 실시간 저전력 무선통신 모듈 자동 구동 미래 산업 산업융합 융합 세계 최고 성능 대용량 자율 자율구동 일체형 상태 진단 발전성능 50 급 노드 핵심 핵심기술 가혹환경 프로 프로토콜 토 콜 혹한 조건 간의 무선센서망 망 장치 이용 유지 유지보수 보수 정비 정비기지 기지 전송 유지관리비 관리비 점감 점감효과 효과 최적 관리 관리프로그램 프로그램 수행 인건비 절감 부품 축소 정비공 정비공정의 정의 감소 등 가능 연간 10 이상 있음 실제적 국내 철도운영기관 운영 기관 발생 유지관리 기반 예측 2008 2008년도 년도 모든 1 1조 조 225 225억원 억 원 추정 총 수송 수송비용 비용 계산 본 완료 운영기관 적용 경우 약 1,000 1,000억원 판단
# Businness, Idea, commercialization 사업 지원 비즈니스 아이디어 비즈니스아이디어 발굴 평가 권리 모델 기획 투자 투자연계지원 연계 기술화 비즈니스플랜발굴 플랜 타당성 수요자 매칭 수익성 확보 도입 도입아이디어 상용 기술 기술개발 개발 투자자금 자금 국내외 판로 판로확보 성장 정체 산업 부가 부가가치형 가치 형 고부 가치형 이전 산업간 간 장벽 신규 신규사업군 군 계기 마련 정책 정책환경 환경 조성 정부 민간 투자자본 자본 기업 기업성장 기반 기 인프라 활용 재생 재생에너지 에너지 시장 시장도입기 도입기 단계 본격화 때 축적 역량 바탕 세계 세계시장 선도 차세대 핵심 핵심기술 강화 협의체 중심 공동 예산 기업간 상생 체계 구축 가능 내외부 통 무형 무형자산 자산 기술혁신 혁신 육성 관련 기업체 테스트 테스트베드 베드 정보 정보지원 등 지원센터 센터 전문 인력 필요성 확대 유사 유사분야 분야 고용 필요 기존 설비 유지 유지보수 보수 다수 요구 풍력 태양력 핵심원천 원천 지역 부가가치 향상 기여 산업파급효과 파급 효과 성장잠재력 잠재력 산업군 성장동력 동력 매출 증대 고급 일자리 창출 지역경제 경제 활성화 기대 에너지분야 신 신선장동력 선장 추진 중인 울산 전 전북간 북간 최초 연계협력사업 협력 초 초광역 광역 성과 도출 테크노 파크 수출 기술이전사업 협력모델 진행 경우 우수 성과도출
#
# M2M,TVWS, Mainhub system, remote, Gate, sensor,hub 유휴 유휴대역 대역 스마트 스마트폰 폰 기술 활용 2 망 관제 관제시스템 시스템 개발 티브이 화이트 화이트스페이스 스페이스 엠 엠투엠 투 센서 주요 주요기능 기능 규격 ㅁ 접속 250 250개 개 이상 사설 할당 고정 동적 관제서버 서버 상태 감시 제어 방식 가용 채널 설정 서비스 기술적 측면 세계적 활성화 방송 융합 기술인 무선 기반 장치 농업 플 원격 관리
#
# virtual machine 대형 대형통합 통합 스마트 네트 네트워킹 워킹 핵심 기술 개발 트랜스 트랜스포트 포트 소프트 소프트웨어 웨어 정의 네트워크 마이크로 데이터 센터 빅 빅데이터 클라우드 서비스 브로커 1 1차년 차년 2014 융합 플랫폼 1단계 단계 분산 고품질 제공 가능 기반 동시 서비스사업자 사업자 수 100 100개 개 초당 플 우 처리 처리수 6 컨트롤러 간 연동 프레임 프레임워크 워크 컴퓨팅 자원 가상 자원분석 분석 프로 프로토타입 토 타입 단일 도메인 제어 제어관리 관리 테스트 테스트베드 베드 구축 구조 설계 로컬 멀티 멀티테 테 시 확장 고속 확보 대용량 대규모 신규 시장 창출 개인 벤처 중소기업 등 생태계 조성 때문 지속적 고용 유발 효과 시스템 구분 예측 등 자료 참조 산업 산업전략연구부 전략 연구부 세계 6년간 년 2018 2023 총 매출 47,003 47,003백만달러 백만 달러 목표 국내 2013 11 11조 조 8 8천억원 천 억 원 사업 종료 후 113,792 113,792명 명 기여도 30 가정
#
# Vehicle IT Convergence,Smart Car,Vehicle S/W,Mechatronics,Telematics 차량 융합 융합혁신센터 혁신 센터 운영 차량아이티 아이티 스마트 카 소프트 소프트웨어 웨어 전장 전장모듈 모듈 텔 텔레매틱스 레 매 틱스 기술 기업 네트워크 구성 관련 활동 지원 강화 미래 신기술 신기술과제 과제 발굴 기반 확보 수요 수요기업 상용 마케팅 해외 시장 동반 진출 모색 국제 표준화 선도 정보 등 체계적 방안 강구 중장기 로드맵 방향성 전개 회원사 국내 참여 협의체 참여사간 사간 교류 교류확대 확대 협력 협력체계 체계 구축 영역 정기적 반도체 소재 부품 육성 기회 기존 산업 기초 분야 부 품 기초기반 중점 로 로드맵 드맵 추진 과제수행 수행 성공 내부 내부지원 관제 관제관리 관리 시스템 활용 사전 교육 기술세미나 세미나 워크숍 실시 공유 연구 연구협력 자 자문단 문단 개선 애로 해결 개발 개발사업 사업 기술지원 전문가 지원체계 지속 기술개발 결과 결과물의 물의 양산 양산적용 적용 지원활동 평가 다양 비즈 모델 수요기관 기관 핵심 원천 기술력 경쟁력 향상 점유율 증대 독자 설계 능력 성능 고도화 고부 가치 세계 수입국 수출국 위상 제고 부품업체 업체 화 완성 완성차 차 의존도 완화 핵심기술 자체 자체설계능력 보유 수출 예상 첨단 편의 편의안전 안전 차량안전 효과 효과기대 기대 안전장치 장치 안전운전 운전 교통사고 교통사고예방효과 예방 에코 에코드라이빙 드라이빙 연비 연비향상 탄소 탄소배출량 배출량 저감 자동차 통신 그리드 연계 새 대규모 융합산업 파급 파급효과 국 국내외 내외 실 실차 인증 일괄 일괄지원 유럽 북미 향후 규제 대비 수출증가세 증가세 유지 가능
#
# SmartphonePlatforms,MobileServices,UsercenteredSmartSpace,CollaborativeMobileComputing,UserSensing,IntelligentMobileInteraction 사용자 중심 스마트 스페이스 실현 차세대 스마트폰 폰 플랫폼 서비스 지원 핵심 기술 모바일 협력 컴퓨팅 싱 지능 본 연구 환경 제공 미래형 확보 최종 목표 달성 코어 개발 테스트 베드 구축 다수 간 연동 플 플리케이션 리 케이 션 구동 개인 그룹 모니터링 티 달 인터 인터랙션 랙 기반 등 5 5개 개 분야 선택 중점적 유비 유비쿼터 쿼터 센서들과 구성 자동적 능동적 선행 생활 밀착 효과적 다음 이동성 다양 이기 이기종 종 센서 센서기기 기기 포함 동적 자원 에너지 제약 고려 분산 관리 조율 수행 컴포넌트 사용자간 간 시스템 아키텍처 설계 융합 실행 효율성 극대화 사용 기법 상황 정보 모델링 질의 복합적 추출 데이터 최적화 프라이버시 보안 보장 처리 조화 변화 대응 전환 시나리오 기획 유용 기 효용 검토 획득 실시간 프레임 프레임워크 워크 인터넷 배포 체험 체험형 형 엔터테인먼트 콘텐츠 경험 수행과정 과정 활용 시장 앱 폭발적 성장 향후 수년 수년간 성장세 지속 전망 가운데 수 구체적 생활 공간 촉진 선점 한 엔터테인먼트 교육 소 소셜 셜 네트 네트워킹 워킹 의료 출현 유도 모바일 견인차
#
# ARM Server,Android,Emulator,Docker,App Streaming 모바일 게임 뮬 뮬레이션 레이션 저전력 서버 개발 암 안 안드로이드 드로 이드 뮬레이터 레이터 도 앱 스트리밍 시장 온라인 규모 정도 시작 검색 트래픽 증가 유효 유효화 화 수 웹 상 실행 요구 플랫폼 실제 단말기 타겟 마이크로 프로세서 종속적 레지스터 기반 달 달빅 빅 과 가상 가상머신 머신 때문 기존 데이터 데이터센터 센터 86 기 기반의 반의 문제 사업 선 종류 코어 적합 전용 필요 서비스 운용 측면 고려 대부분 내 구축 운영 환경 특성 다음 설계 1 상화 지원 효율적 단위 단위면적 면적 최대 수의 해당 최대한 유효성 을 보장 하이퍼 하이퍼바이저 바이저 가상화가 화가 2 2011 2011년 년 말 전기세 특별법 폐지 전력 소모 지속적 투자 투자수익률 수익률 고려 고려사항 사항 인텔 계열 구현 3 네트워크 성능 우수 과제 제안 배경 유도 뒤 진행 웹브라우저 브라우저 중요 목적 사용자 속도 실시간 4 입출력 확장성 결과 사용 사용내역 내역 다양 정보 기록 저장 하드디스크 외부 확장 가능 내 기본 요건 중 하나 최종 목표 설명 만족 번째 요소 본래 하드웨어 모드 별 이상 조건 삼성 삼성전자 전자 럭 럭시 시 최근 출시 최신형 스마트 스마트폰 폰 내장 태블릿 특징 최적화 프로 세서 메모리 간 내의 무엇 소프트 소프트웨어 웨어 경우 발열 수명 안정성 안정적 사의 6 최종적 선정 채택 앞 항목 결과적 단점 클라우드 돌풍 리눅스 컨테이너 기술 이용 해결 있음 내용 이더넷 스위치 연동 집적도 케이스 제작 기능 포팅 드로이드 글로벌 리서치 기업 뉴 뉴주 주 발표 2014 보고서 세계 게임시장 2013 2013년 700 700억 억 달러 한화 약 72 72조 조 8 8천억 천 원 2014년 750 750억 78 78조 300 300억 조사 한 2015 2015년 800 800억 돌파 2016 2016년 860 860억 예상 조금 차이 공통적 이후 10 성장 예측 2000 2000년대 년대 각종 악재 전세계 산업 게임산업 성장세 셈 한국 한국콘텐츠 콘텐츠 진흥원 해외 해외콘텐츠 동향 동향조사 온라인게임시장 중국 브라질 인도 등 내수 신흥국 팽창 연평균 8.2 의 2012 2012년 204 204억 700만 만 달러 2017 2017년 시장규모 302 302억 7,000 7,000만 확대 모바일게임 10.5 전망 87 87억 5,700 5,700만 144 144억 이 그 비례 엔진 대한 솔루션 결과물 수요 급증 응용 외 테스트 디버깅 개척 효과 기대 마지막 버들 대체 소비 소비전력 개선
#
#  기반 통합 통합개발지원 개발 지원 환경 환경개발
#
# Fluorescence Cell Imaging,Fast Fluorescence Cell Image Analysis Algorithms,Fluorescence Cell Image Analysis Algorithms,Cell Measurement Tools,Motor Control Technique 통합 디지털 형광 징 장비 고성능 임 임베디드 베 디드 시스템 시스템기반 기반 세포 이미지 분석 소프트 소프트웨어 웨어 개발 알고리즘 가속화 가속화기법 기법 측정 도구 모터 제어 적용 적용가능 가능 다중 멀티 코어 프로그래밍 실시 실시간 간 획득 임베디 디 용 카메라 장치 드라이버 전자동 획 형태학 편집 3 정합 계수 사멸 주기 트랜스 트랜스팩션 팩 션 효율 전문 하드 하드웨어 가속 가속기능 기능 이용 1 1차년도 차 년도 자동 고감도 형 광 사양 모듈 2 2차년도 이미지기반 정 정밀 밀 스테이지 병렬 전 세계 현미경 시장 2010 2010년 년 기준 약 약2.5조원 2.5 조 원 3조원 추정 연간 10 이상 고성 고성장 장 있음 광학 광학현미경 이중 40 해당 1.2 1.2조정도 조 정도 규모 8.5 의 성장세 2015 2015년 시장규모 1.8 1.8조 조 국내 240 240억원 억 성장 가정 367 367억원 2018 2018년 462 462억원 기존 존재 새 개념 신제품 출현 초기 틈 틈새시장의 새시 장의 공략 형태 진입 이후 독자적 형성 예상 제품 출시 후 100 200 200억원 수출
#
# Radio Interference Interference Signal Generation,GNSS,Navigation Signal Jamming,Radio Interference Verifcation Platform 전파 전파혼신 혼신 검증 플랫폼 기술 기술개발 개발 전파혼신검증플랫폼 혼신신호 신호 생성 생성기술 항법 항법신호 재 재밍 밍 전 전지구 지구 위성 위성항법 본 사업 1 2 신호대역 대역 발생 민간 항법수신기 수신기 영향 평가 분석 수 전파혼신신호 발생장치 장치 측정 신호측정장치기술 영향평가 목적 신호발생 재 재밍신호 기만 기만신호 협대역 4 이하 광대역 24 주파수 대 대역 역 재방송 재방송신호 동기 스푸 대 재방송기만 0 100 값 제공 수신 수신안테나 안테나 입력 입력단 단 130 기준 신호생성 시나리오 연구 시험 신 호 다양 특성 방향 고려 전파혼신원 혼 신원 모사 제작 기반 모듈 시제 설계 종합 신호측정 환경 반영 위성항법수신기 대응 대응능력 능력 성능 성능변화량 변화 량 등 응용 응용분야 분야 상용 상용수신기 7 7종 종 결 도출 측정기반 성능평가 측정결과 결과 대응방안 방안 생성구축 구축 종류 적합 주 파수 다중 다중항법신호처리 처리 기법 측정치 여부 재밍 판단 알고리즘 모델 신세기 고도 고도정보 정보 전파예측모델 예측 활용 특 기술적 기대 기대효과 효과 수요처 산업체 연구소 대학 대학등 대응알고리즘 등에 제조 모듈제작 업체 시험검증 대응기술개발 감시 기관 정부 영향범위 범위 파악 진화 적용 적용시스템 시스템 칩셋 활용내용 내용 항 항재밍 대응기술 발생기법 국가 국가기간통신 기간 통신 인프라 인프라용 용 전파교란방어기술 교란 방어 전파교 교 대응기능 기능 도시 등
#
# 3-dimensional segmentation,high performance computing,fluid-structure interface,hemodynamic simulation,non-rigid registration 다중 다중의료영상 의료 영상 활용 3 3차원 차원 초정밀 시뮬레이션 기반 심 심ㆍ혈관 ㆍ 혈관 질환 진단 치료 치료지원 지원 통합 통합소프트웨어 소프트 소프트웨어 웨어 시스템 개발 삼차원 영역 고성능 고성능컴퓨팅 컴퓨팅 유체 구조 상호 상호작용 작용 혈 혈류역학 류 역학 비강 정합 주관 주관기관 기관 연세대 연세대학교 학교 다양 환경 하 선택적 혈관조영술 조영술 임상 유효성 확립 후 잔류 조영제 괴사 괴사심근 심근 평가 평가기술 기술 관류 관류영상 절대 절대혈류량 혈류 량 역학적 등 세부 기능 적합성 고려 관상 관상동맥 동맥 조정 타세 타세부 부 이차원 심장 심장영상 경화 경화반 반 고속 구현 과제 과제요소기술 요소 검증 전임 질환모델 모델 구축 개발요소기술 전 전임상시험 시험 개발기술 임상적용 적용 실용성 확보 기술개발 의료전문가 전문가 피드백 결과 결과예측 예측 정확도 임상검증 효용 시간 비용 절감 접촉 접촉상호작용 심혈관 대변 해석 생체 중재 중재시술기구 시술 기구 간 파악 접촉역학 유 요소해석 기법 참여 참여기관 1 서울대 서울대학교 생리적 정보 실시간 30 가시화 속도 개선 데이터 종류별 유용성 중 고화질 교차점 교차점오류제거 오류 제거 융합 심방 심실 성능 2 서울 서울과학기술대학교 과학 기술대 생 체 중재시술 혈류유동 유동 고체 수치 수치해석 죽상 죽상경화반의 반의 연산 수 효율적 이론 정립 울산 울산대학교 대학교 멀티 멀티스케일 스케일 유체역학적 계산 모델링 환자 환자특정 특정 형상 비 비정렬 정렬 전산 전산격자 격자 자동 자동생성 생성 근 근실시간 고속연산 하이브리드 병렬 병렬연산 벡터 알고리즘 최적화 4 숭실대학교 결합 선 조영 조영영상 에너지 함수 조영영상-3 -3 혈관구조 초기 탄성 특징 기술적 측면 축적 의료기구 임상시험 마련 성과 심혈 심혈관계 관계 병변 바탕 스텐트 인공 인공판막 판막 후반 후반단계 단계 비용절감 기간 기간단축 단축 효과 기대 있음 산업 영상획득과정 획득 과정 위험도 최소화 예후 예후개선 생리 기능적 제공 불필요 감소 맞춤 맞춤치료 치료과정 합병증 의료비용 최소 침습 시장 성장 촉진
#
# autonomousunderwatervehicle,underwaterglider,controlsystem,hybrid 하이브리드 하이브리드형 형 무인 무인잠수정 잠수정 제어 제어시스템 시스템 자율 자율무인잠수정 수중 글라이더 장점 혼합 개발 추진기 사용 추진력 꼬리 꼬리날개 날개 목표 이동 부력 조절 무게 무게중심 중심 추진 필요 에너지 수직 수직방향 방향 추진시 시 필수적 속도 회전 반경 단점 기존 추진방식 방식 추가 효율 필요시 이동거리 거리 효과적 임무 수행 가능 1 1차년도 차 년도 제어방안 방안 연구 6 6자유도 자유도 수학적 모델링 시뮬레이터 시뮬레이터개발 각 제 설계 구현 필터 필터기반 기반 복합 복합항법 항법 교육 항법시스템 개조 실험실 스케일 2 2차년도 장 장거리운항 운항 글라이더모드 모드 임무수행 운용 운용방안 경유 경유점 점 추적 제어기 년도 국립 국립수산과학원 수산 과학원 3 깊이 유체 유체저항계수 저항 계수 측정 실험 3차년도 수조 수조테스트 테스트 완성 통신 사용자 인터페이스 부 부경대 경대 로봇 로봇해양거점센터 해양 거점 센터 20 성능 성능실험 모선 활동 수 영역 확대 선진국 활성화 학계 수중기뢰탐색 기뢰 탐색 등 국방 국방분야 분야 해저 해저지형탐색 지형 민간 민간분야 활용 관련 산업 산업기반확대 산 산학연 학연 연계 연구인력 인력 양성 기여
#
# Multi Dimensional Visualization,ITSM,Network Bandwidth Effectiveness,IoT,Industrial Video 대용량 데이터 해석 기술 개발 다차원 다차원시각화 시각화 아이티 아이티자원관리 자원 관리 네트워크 네트워크효율 효율 사물 사물인터넷 인터넷 1 1차년 차년 개발목표 목표 항목 항목1차년 중점 사업 이종 표출 표출기술 공간 시간 부문 고도화 핵심 핵심기능 기능 모듈 임 이종데이터 영상 매시 매시업 업 원격 화면 전송 제어 제어기술 2 자동 논리 생성 실시 실시간 간 문제 문제탐색 탐색 알람 알람기능 3 일반 동기화 개발내역 내역 주요 정교 작업 작업임 기존 비디오 처리 향상 운영 운영환경 환경 영향 수 기술인 자동생성 엔진 엔진개발 사용자 모니터링 분석 물리적 논리적 구조 자동재생 재생 변경 상황 대응 가능 최적화 포함 제공 시각화엔진 기반 뷰어 사후 검색 구축함 나 다 실 기대 기대효과 효과 상 저작 강화 강화개발 1개 개 복합 복합구조 형식 개선 멀티 디스플레이 상 저장 다중 응답 응답속도 속도 엑 엑시노스 시 노스 모바일 적용 입출력 칩셋 음향 음향지원 지원 추가 녹화 녹화기능 연결 빅 빅데이터 자동적 구성 다양화 터 생성 생성단계 단계 다이어그램 생성과정 과정 포착 화면상 위치 특정 해당 표 차트
# Selfchecking,ReconfigurableSystems,layeredsystem,Errordetectioncoding,Contextawareness,Errorrecovery,ALUDesign,AutonomicComputing,DependableComputing 확장 확장가능 가능 자가 자가오류 오류 탐지 오류회복 회복 연산기 설계 자가오류탐지 재구성 재구성가능 시스템 계층 계층구조시스템 구조 오류탐지코드 코드 상황 상황인식 인식 자율 자율시스템 최종 최종목표 목표 핵심 핵심기술 기술 연구 연 연차별 차별 1 1차년도 차 년도 2 2차년도 활용 자가회복 기술연구 3 3차년도 성능 최적화 통합 오류발생 발생 안정적 대처 수 발전 도모 관련 인력 양성 교육적 인지도 확산 작동 업체 교류 이전 제반 여건 제공
#
# MobileCloud,DeviceCentricCloud,SmartDevice 스마트 디바이스 디바이스간 간 협업 핵심 소프트 소프트웨어 소프트웨어플랫폼 웨어 플랫폼 기술 개발 모바일 클라우드 장치 기반 소 소셜 셜 네트 네트워킹 워킹 필요성 증가 현재 수준 기능 제공 때문 필요 응용 응용프로그램 프로그램 경우 자체 구현 연구 간의 작업 분산 분산처리 처리 자원 자원공유 공유 등 가능 목표 계층 프레임 프레임워크 워크 하위 단계 시스템 서비스 상위 호출 사용 수 분산처리기능 내용 다음 1 구성 각 수행 부하 빈도 분석 작성 원격 도출 프로 프로토콜 토 콜 2 100 공통 함수 대상 선정 선 정 산화 전체 과정 관리 주체 판별 발생 문제 대응 플랫 플랫품 품 협력 차세대 핵심기술 선점 가전 폰 냉장고 구축 확보 다수 유휴 컴퓨팅 인프라 장치기반 업체 탑재 활용
#
# reconfigurableantenna,tunableantenna,integratedantenna,ITS,WAVE,VX,VV,VI,VN 지능 교통 시스템 재구성 내장형 2 통합 안테나 가변 차량 차량환경무선접속 환경 무선 접속 차량통신 통신 차량간통신 간 차량인프라간 인프라 간 기반 스마트 적용 적용가능 가능 소형 개발 목표 내장 수 크기 내 을 만족 동작 동작주파수 주파수 편파 빔 빔패턴 패턴 지원 예측 불가능 적응 개별적 제어 개 이상 특성 동시 가변능력 능력 구체적 연 연차별 차별 아래 1 1차년 차년 2014.5 2015.4 정형 다중 다중대역 대역 소자 2차년 2015 4 개별 3 3차년 2016 본 연구 연구과제 과제 최종 최종목표 통합기능 기능 제공 구현 설계 기술 습득 연도별 관련 시제품 뒤 설정 성능 평가 기존 사례 조사 소 형 모든 제작 측정 결과 바탕 통신시스템 분석 고속 고속주행 주행 다중경로 경로 페이딩 현상 강한 원형 원형편파 다이버 다이버시티 시티 구조 구조간 상호 간섭 최소화 응용 방안 전 전복 복 사고 대비 반대 반대차선 차선 신호 신호간섭 편파재구성 연구결과 고안 변 변소자 포함 바이어스 회로 저전력 가변소자 종류 개수 최적화 기법 차량환경 시험 시험평가 차량통신시스템 성능개선 개선 검증 학문적 기대 기대효과 효과 다기능 차세대 무선통신 단말기 모듈 활용 이용 이론적 과정 체계화 해석 추후 노변 노변인프라 기지국 폭 이득 배열 배열안테나 경제 사회적 전파 전파분야 분야 무선통신시스템 네트워크 정보 정보보안 보안 자동차 자동차부품설계 부품 등 다양 학제 융합 우수 인력 양성 차량무선통신시스템 사용 독립적 서비스 만큼 다수 고정 대체 있음 소형화 추구 궁극적 연구결과물 결과물 비영리 공공 공공사업 사업 획득 원천 원천기술 차량부품 무선통신단말제조 단말 제조 업체 등에 전이
#
# speechtechnology,mentalfatigue,physicalfatigue,fatigueevaluation,fatiguediagnosis,fatiguesolution 음성 음성기술 기술 이용 피로 측정 방법 진단 모델 연구 정신 정신피로 육체 육체피로 피로측정방법 피로진단모델 피로해소방안 해소 방안 본 연구개발 개발 목표 인간 영향 지 실험 토대 간 상관관계 규명 변화 평가 정신적 육체적 부과 주관적 설문지 측정방법 고안 음성특징 특징 피로와의 와의 정량적 도출 이 바탕 수준 수 제시 이 실생활 응용 스마트 스마트폰 폰 앱 창작 1 1차년 차년 상관 관계 1차년도 차 년도 설계 수행 실험결과 결과 분석 2 2차년 2차년도 완성 3 3차년 3차년도 파라미터 동시 피로감 체계적 자동차 각종 감성 감성평가 객관적 평가지표 지표 유용 활용 가능 운전자 신체적 건강 건강상태 상태 초래 교통사고 주요 주요원인 원인 교통 사고 발생 발생빈도 빈도 일상 일상생활 생활 삶 영위 과제 결과물 편리 사용자 관련 관련기업 기업 기술이전 이전 상품화
#
# MM,WirelessMMApplications,WirelessQoS 범용 무선 솔루션 이용 플랫폼 구현 연구 통신 2 서비스 품질 특정 목적 전 전송 송 속도 시간 지연 송수신 거리 의 칩 개발 기술적 일 국내 모뎀 설계 생산 업체 유수 대기업 곳 수백 수백명의 명의 박사 박사급 급 인력 투입 반면 활용 경우 근거리 네트워크 수 칩셋 등 이 데이터 가능 제한 문제점 스마트 미터링 예로 영상 영상정보 정보 송신 비디오 센서 지원 전송률 다양 기존 표준 요구 만족 본 플 플리케이션 리 케이 션 과 연산 연산량 량 처리 마이크로 프로세서 구축 이론적 하드웨어 증명 복수 모듈 목표 성능 분석 포함 2년 년 기간 과제 진행 계획 차 별 다음 1 1차 차 년도 해상도 증가 이기 이기종 종 결합 2차 기종 다중 홉 제어 계층 1차년 차년 주제 이 단계 각각 특징 파악 수학적 모델링 하나 측면 간섭 환경 싱 기법 단순 적용 통신칩 특성 반영 차별성 2차년 채널 트랜시버 기술 확장 중계 인지 인지무선통신 주파수 유연성 실현 들 학문적 시스템 기반 마련 활성화 촉진 트래픽 상황 효율적 확보 최적화 분산 조직화 기능 프로 프로토콜 토 콜 실질적 가교 역할 수행 국제 국제수준 수준 학술 학술논문 논문 및 학술대회 대회 논문게재 게재 발표 임의 접속 분야 기술수준 국제화 경제 산업 저전력 특허 지적 지적재산권 재산권 연구개발 결과 향후 지속적 발전 모색 토대 산 산업체 이전 무선통신 자립 향상 가격 경쟁력 제고 지식 지식재산 재산 국제적 상호 상호사용승인 사용 승인 을 통 이동 이동통신 비용 비용절감 절감 융합 선도 전문 양성 실무 능력 겸비 지방 육성
#
# Flash Memory Storage,Smart SSD,Open Source Database,NVDIMM,NVMe SSD 스타 스타랩 랩 휘발성 메모리 기반 개방형 고성능 개발 오픈 소스 데이터 데이터베이스 베이스 지능 플래시 저장 저장장치 장치 양 양방향 방향 인라인 모듈 인터페이스 최적화 시스템 읽기 지연 지연시간 시간 을 증가 구조 개선 버퍼 버퍼매니저 매니저 관리 정책 특성 반영 설계 구현 가능 멀티 멀티큐 큐 멀티코어 코어 활용 새 최적화기술 기술 분석 독립적 고려 다중 다중대기열 대기 열 키 키텍 텍 연구 우선 우선순위 순위 대기열 열 상의 문제 해결 수 적용 기존 성능 성능대비 대비 2 2배 배 성능향상 향상 효과 기대
#
# Project Coordination,Image Bigdata,Industrial Support,Ecosystem Generation,Quality Assurance 딥 딥뷰 뷰 총괄 대규모 실시간 영상 이해 기반 시각 시각지능 지능 플랫폼 개발 재난 재해 조기 감지 예측 기술 세부 세부과제 과제 조정 빅 빅데이터 데이터 산업 지원 생태계 조성 품질 품질관리 관리 이미지 동영상 수집 도심 도심공간 공간 다차원 시계열 변화 환경 위험 수행 국내 연구 연구역량 역량 결집 국제 국제교류 교류 등 글로벌 최고 수준 확보 퍼스트 무버 무버형 형 연구개발 리딩 사업 전 기간 결과물 제고 1 1단계 단계 4 4년 년 핵심 2 2단계 3 3년 결과 결과물의 물의 통합 시스템 3단계 경쟁력 시장 창출 주도 단계별 최종 제품 성능 객관적 공개적 제시 실용성 입증 기술개발 확산 보급 추진 산 산업계 업계 공동 수요 수요의견 의견 수렴 연구기관 기관 간의 협력 증진 사이 연계 조정관리 기술교류 워크 워크샵 샵 개최 시너지 효과 촉진 성과 극대화 그룹 개발결과 공개 홍보 시기 방법 범위 결정 과정 상시 감시 중심 온라인 비디오 비전 경제적 파급 파급효과 발생 기대 전세계 분석 관련 세계 2013 2013년 년 334 334억 억 달러 2018 2018년 740 740억 연평균 17.21 이상 성장 손실 2011 2011년 3,800 3,800억달러 보고서 피해 규모 7,942 7,942억원 원 미래 미래창조과학부 창조 과학 부 증가 복구 사전 예방 필요 동시 과거 불가능 대용량 비정형 가치 신 비즈니스 육성 국가 사회 사회안전망 안전망 고도화 재난재해 기반기술 공급 안전 미래사회 실현 기여 생산 생산유발효과 유발 고용 고용창출 2025 2025년 6,835 6,835억원 2010 2010년 한국 한국은행 은행 산업연관분석 연관 생산유발계수 계수 1.32 1억원 2020 2020년 예상 예상매출 매출 5,201 5,201억원 기준 측면 6,449 6,449명 명 고용유발계수 1.24
#
# Development of PLC Modem for Smart Grid with One Chip 이용 그리드 개발 스마트 전력 전력소비 소비 검침 신뢰성 향상 원 원칩 칩 설계 제작 성능 검증 용 보드 시험 한전 구매 구매규격 규격 잡음 내습성 모뎀 케이스 성능평가 평가 시제품 테스트 적합성 확인 베드 환경 구축 성능검증 터미널 프로그램 특성 양산 공인 공인인증 인증 기관 인증서 획득 동작 중 발생 최소화 회로 럭 럭단 단 유입 전원 안정화 시 수 지 지터 터 등 영향 입출력 방식 채널 측정 알고리즘 적용 제어 -10 출력 세기 고려 파급 효과 국내 외 스마트그리드 시장 규모 16 성장 핵심 분야 사업 2020 2020년 년 2,194 2,194만호 만 호 물량 정부 주관 1,000 수용 수용가 빌딩 사업체 대용량 사용자 추가적 설치 계획 무궁무진 함 국가 로드맵 비전 저탄소 녹색 기반 2030 2030년 세계 최초 단위 을 전력수요 수요 변화 효율적 대응 가능 때문 재생 에너지 에너지저장장치 저장 장치 전기 전기차 차 증대 있음 -2015 -2015년 실증 실증사업 토대 약 90 의 성공 2016 2016년 예정 250 250만호 입찰 공고 참여 기존 저가격 제품 초기 초기시장 확보 -2014 -2014년 4 4분기 분기 전라남 전라남도 도 나주 나주시 시 한국 한국전력 이전 지역 기업 살리기 프로젝트 진행 1 2 2차 차 벤더 광주 전 전남 남 1개 개 업체 실정 지역사회 사회 발전 이바지 현재 제조 단가 불량률 문제 별도 계약 공급 하면 제조단가 15 감소 부품 수량 37 이득 한 납품 동일 사용 80 만
#
# prediction model,Control-Instrumentation,wastewater,realtime,MBR 오염 저감 적분형 예측 예측모델 모델 내장 중소 중소규모 규모 하 폐수 제어 시스템 하폐수 제어계측 계측 리얼 리얼타임 타임 분 생물 생물반응기 반응기 기반 수행 연산 프로그램 개발 적합 데이터 데이터베이스 베이스 연동 패키지 처리 처리수 수 생산 시 발생 제시 미분 미분형 형 모 모델를 델를 변형 한국 현장 경험식 이론 이론식이 식이 결합 형태 알고리즘 공 공정의 정의 압력 압력값 값 외 다수 계측기 수집 근거 분석 실시 주 구성 프로 프로토콜 토 콜 기본 라우터 서버 옵션 옵션사항 사항 가공 각각 전달 양 양방향 방향 통신 저장 최종 사용자 이해 수 출력 고등 고등연산 533 8347 프로세서 이 동등 특정 자체 메모리 아날로그 입 디지털 구현 공정 유지 유지관리 관리 향상 운전 운전분석 예측시스템 적용 하 하폐수 분야 최적화 기존 유지보수 보수 유사 정밀 정밀여과막 여과 막 상수도 공업 공업용수 용수 해수 해수담수시스템 담수 가능 선진국 등 해외 시장 진출 글로벌 글로벌제품 제품 차별화 시장진입 진입 기술적 우위 차지 관련 관련시장 성장 긍정적 영향 줌 축적 국내 학술적 산업 가치 원본 원본자료 자료 확보
#
# Space Gesture,Real-time Tracking,Multi-touch,UI(User Interface),UX(User Experience 60 이상 대화 대화면 면 화질 투명 투명플렉시블 플렉시블 디스플레이 시각 공간 추적 가능 사용자 상호 상호작용 작용 기술 개발 공간제스처 제스처 실시간 실시간추적 멀티 멀티터치 터치 인터페이스 55 기반 응용 응용서비스 서비스 플랫폼 통합 환경 간섭 3 모션 인식 시제품 물리적 변형 변형기반 시나리오 세부 인터 인터랙션 랙 션 활용 객체 렌더링 다중 프로 프로토타입 토 타입 중심 시선 인지 디자인 요소 시각화 표준 고도화 작업 진행 적합 화면 화면설계서 설계서 추가 제작 요소기술 플랫폼간 간 안정화 융 융복합 복합 특징 추출 알고리즘 성능 개선 제안 구현 곡면 적용 기법 용 설계 컨셉 구동 초대형 스펙 검토 동작 동작인식 특허 특허출원 출원 1 1건 건 공공 특징점 점 트레킹 모듈 5 5개 개 입력 영상 처리 초당 30 구조 확장 아키텍처 투명패널 패널 광고 상용 프로토 휴대 1차 차 실험실 테스트 중대 양면 후 후방 방 사물 선택 예측 정확도 향상 이드 가정 내 실제 검증 전략 제품 산업용 급 교육 영상처리 보드 보드개발 지원 8 급 3840 2160 패 널
#
#  장비 글로벌 글로벌선도 선도 개발 개발촉진 촉진 기반 기반구축 구축 공동 콜 글로벌거점 거점 선도기술 기술 중소기업 생태계 진입 위 특성 유 유무형 무형 지원 인프라 협력 국내 기업 보유 제품 조기 확보 중소 선도시장 시장 현지 ㅁ 과제 과제수행 수행 절차 유망 유망중소기업 발굴 토단 밀착 밀착지원 글로벌시장 우선 우선지원기업선정 선정 참여 참여기업 모집 국내업체 업체 유망기업 대상 자문 자문위원단 위원단 의 밀착자문 을 통 미국 내 파트너 등 연계 산업 오피니언 리더 초청 오프라인 개최 트렌드 제공 집단 개별 실시 핵심 기술거점 중심 온 단계별 주요 내용 진단 해외 해외진출 진출 전략 수립 분석 미주 유럽 품목 진입전략 프레임 프레임워크 워크 유형 사례 시사 시사점 점 도출 실태 실태조사 조사 장비기업 설계 기획 경쟁력 강화 협업 탐색 지원체계 체계 마련 액 액셀러레이터 셀러 레이터 휴먼 네트워크 유기적 활용 맞춤 맞춤형 형 코칭 소재 대학 선 선제공 초기 초기시장 진출전략 국산 마케팅 분야 국 국제협 제협 업 연동 연동체계 시장진출 선순환 순환 교두보 기능 네트 네트워킹 워킹 지속 보완 정례 플랫폼 관련 전문 정보 교류 장 표준 적합성 장비인증 인증 포함 기술자 기술자문 문 전시회 참가 성과 성과홍 홍 복덕방 자리매김 시대 신속 틈새 틈새시장 가능 지속적 희망 자발적 사업 수 오픈 운영 정책 정책협의회 협의회 현장 니즈 파악 업계 애로 애로사항 사항 주기적 지연 최소화 데 기 구축중인 중인 토대 활동 급변 트랜드 매칭 효율적 안정적 유도 국제 국제공동 계약 기술기준 기준 전문가 성공적
#
# FunctionalEncryption,FullyHomomorphicEncryption,Efficientimplementationofcryptographicalgorithms,AppliedCryptography,Computingoverciphertexts,InformationSecurity 미래 정보 기술 시스템 차세대 함수 암호화 응용 암호 준동 효율적 알고리즘 구현 데이터 상의 계산 보안 1 기존 정의 문제점 개선 새 2 실용 실용적인 적인 사용 수행 이 최신 완전 성능 3 제안 이용 다수 사용자 존재 빅 빅데이터 마이닝 코드 멀티미디어 분야 현안 문제 해결 4 기반 분류 정리 방법 적용 가능 지 조사 암호문 평문 위 동작 특정 복호 수 개인 개인키 키 제공 해당 소유자 의 결과 결과값 값 외의 관련 목표 연구 현재 지적 이 만족 전문가 라이브러리 전단계 우리 실용화 어려움 성능개선 동시 시도 다양 를 도구 가능성 때문 이후 단순 경우 변형 프로 프로토콜 토 콜 설계 마지막 특징 추후 설계자 유용 연산 기능 통제 형태 서비스 제공자 자신 최소한 외 프라이버시 보호 본래 학문적 전 세계적 시작 단계 국제적 경쟁력 제고 측면 가치 생각 결과물 기능적 실용적 예상
#
# IEEE 802.11,Beyond 11ac,HEW (High Efficiency WLAN),Wi-Fi 802.11 표준 표준개발 개발 랜 고효율 무선 무선랜 차세대 와이 와이파이 파이 기술 검증 성능 기능 요구 요구사항 사항 정립 단계 초기 표준화 적극 참여 대응 11 작성 본격적 경쟁 제안 채택 표준규격 규격 규격화 확보 완료 시장 진입 기반 기반영 영 유지 관리 상용 제품 추진 ㅇ 원천 검증방법 방법 1 1차년 차년 중점 핵심 유스 유스케이스 케이스 시나리오 관련 환경 기술적 분석 실질적 사용자 체감 셀 셀경계 경계 보장 등 기능적 구체화 연계 특허 중소기업 정책적 활용 방안 실행 3 3차년 국내 정부 민간 지원 활성화 발굴 표준특허 특허풀 풀 맞춤 표준지원 포함 중소 기업 활용안 안 전파로 유도 후보 후보기술 구축 고도화 성숙 4 4개 개 분야 중심 선행 가능 광대역 다중 다중사용자 접속 2 빔 빔포밍 포밍 고밀도 실 실내외 내외 송수신 간 협력 제어 경험 향상 향후 성숙도 표준기술개발 단말 자원 효율 다채널 자원효율 간섭 간섭제어 기존 레 레거시 거시 단 단말과 말과 공존 제공 재 재전송 전송 실외 실외환경 협력통신 통신 엑서스 효과 핵심기술 선제 우리 우리나라 나라 주도 주도역량 역량 심화 발전 개인별 급 이상 초고 초고속 속 무선기술 국제 제정 실제 실내 외 획기적 기대 상용시스템 시스템 인프라 촉진 경제적 분쟁 효과적 보호 대외 지 강화 기여 상용화시 화시 기 기확보 로열티 수익 발생 외국 외국기술 의존성 탈피 집약적 산업 산업육성 육성 국산화 제고 요소 요소기술 조기 세계 세계시장 우위 선점 경쟁력 차 세대 사업 대비 수입 대체 수출 국외 경쟁업체 업체 악의 전략적 공세 기술료 부담 경감 예상 미래 모바일 장비 생산 고용 부가 부가가치 가치 창출 이동 이동통신 고품질 리치 리치미디어 미디어 새 데이터 서비스 15 21 21년간 년 673 673조원 조 원 총 63 63조원 전망 이 국가적 총1,143조원 1,143 생산유발효과 유발 378 378조원 유발효과 174 174만 만 명 고용창출
# trafficinformation,streamingdata,mobilesystem,incompletedata,uncertaindata,topkquery 불확실 스트리밍 교통 데이터 분산 모바일 시스템 교통정보 정보 불완전 최상위 질의 본 연구 궁극적 목표 개발 현재 스마트 스마트트래픽 트래픽 통합 이력 자료 실시간 도로 구간 갱신 구축 이 시간 지속적 수집 양 간의 관계 파악 다양 관점 이 분석 가능 저장 스키마 정의 도로구간 생성 데이터베이스 베이스 서로 독립적 모델 전체적 네트웍 가중치 그래프 모델링 노드 교차점 을 간선 은 표시 사용 위치 지도 형성 나 센서 추적 실제 매 1 차년 유연 처리 알고리즘 2 도로망 통계적 경로 비용 확률 분포 계산 기법 탐색 색인 3 3차년 저전력 샘플링 매칭 운행 추정 학술적 기술적 기대 효과 랭킹 새 기술 해당 기반 질의처리 토대 공헌 요소 관련 발전 기여 4 지능 네비게이션 독창적 파급 파급효과 판단 5 효율 중시 타 분야 경제 사회적 개별 자동차 측면 혼잡 수 최적 선택 경제적 시간적 정신적 낭비 제거 당국 전체 흐름 제어 체증 설계 증설 필요 획득 환경 유류 소모량 co2 발생량 개선
#
# WirelessCommunications,Relay,SmallCells,StochasticGeometryTheory,EnergyEfficiency,MIMO,RandomMatrixTheory 릴레이 스몰 스몰셀 셀 전송률 에너지 효율 관점 최적화 전송 전송기술 기술 연구 무선 무선통신 통신 시스템 확률 확률기하이론 기하 이론 성능 다중 다중안테나 안테나 불규칙 불규칙행렬이론 행렬 5 5세대 세대 중요 요소 관심 집중 과제 매크로 매크로셀 기반 공존 이종 이종셀 상황 분산 기지국 위치 바탕 모델링 분석 협력 불 규칙 적용 최적 기법 개발 최종적 레벨 하이브리드 도출 목표 기존 다중셀 셀룰러 위 경우 고려하여 사용자 터 신호 범위 증가 사용 안 때문 송신 송신단과 단과 수신 사이 거리 감쇠 통계적 확률기하 도입 기초 신호감쇠 효과 성 능 반영 전송방법 방법 이용 고려 네트워크 결과 전체 알고리즘 제안 복잡 채널 을 솔루션 빔 빔포밍 포밍 간섭 제어 제어기법 적합 다양 환경 단 단말수신단 말수 신단 등 적응 모드 결정 전송기법 송수신 송수신단의 단의 접근 방식 양 양방향 방향 직접 전송모드 각 비교 고찰 단말 채널변화 변화 확보 스몰셀의 의 이론적 성능분석 멀티 멀티셀 해석 가능 특성 동작 2 후속 파생 수 차세대 이동 이동통신 관련 촉진 해당 분야 주도권 디자인 국제적 시작 단계 만큼 장기적 안목 초기 투자 경쟁력 표준화 채택 해외 유명 유명학술지 학술지 게재 관련분야 선도 국내 기초기술 학문적 수준 향상 계기
#
# Greennetworking,CognitiveMM,Radioaccess,Radioresourcemanagement,Cognitiveradio,Cooperativecommunication,Energyharvesting,Artificialintelligentalgorithm,Energyefficiency 차세대 그린 2 무선 협력 통신 에너지 수집 인공 인공지능 지능 알고리즘 기반 효율적 무선접속 접속 자원 자원관리 관리 기법 연구 네트 네트워킹 워킹 무선자원관리 협력통신 인공지능알고리즘 효율성 최종 최종목표 목표 시스템 핵심적 모델 인지 구현 필요 핵심 요구 기술인 서비스 만족도 충족 동시 극대화 개발 이 통신기술 기술 고려 을 확장 전송 신뢰도 향상 노드 생애 생애시간 시간 효과적 연장 전략적 연계 구축 적응성 중심 적용 과제 바 본 수행 세부 연구내용 내용 아래 3 가지 요약 수 공통 공통제어채널 제어 채널 존재 다중 스펙트럼 대역 네트워크 적응 전력 전력제어 매칭 랑데부 성능 성능평가 평가 평가지표 지표 이웃 이웃노드탐지 탐지 무선노드 간의 데이터 선택 보장 의 변이성 학습 조건하에 정칙 이론 등 충족키 키 스케줄 스케줄링 링 발생 가능 휴지 모드 시나리오 불균형 유형 분석 정량화 기 도출 파라미터 최소화 휴지모드 소비 무선통신 현재 전세계 초입 초입단계 단계 국제적 학술 수준 차이 극복 나 아가 선도적 원천 원천특허 특허 길목 확보 지속적 원천기술 능력 배양 표준화 본격적 1 국제 국제표준화 기구 사실 자료 활용 수백 수백배 배 제공 가속화 동인 역할 고정 집중 시장 이동 촉진 한계 비즈니스 기여
#
# Multipledatatypes,Integrativedataanalysis,Multilayernetwork,Extendedtensor,ExtendedGraphs,Multikernel 생물 생물의학 의학 이종 데이터 통합 통합분석 분석 멀티 멀티래어네트워크 래어 네트워크 알고리즘 개발 바이오 바이오의료 의료 멀티래어 확장 터 서 구조 그래프 활용 이종데이터 의 자료 자료구조 확립 한 유용성 증명 현대 의료기술 기술 발전 다양 형태 생명 생명의료 정보 생성 환자 대 등 나이 성별 혈압 심전도 운동량 약물 약물투여 투여 기록 특정인 수집 복잡성 고려 때 각각 현상 단면 면 단일 타입 일부 상태 장님 코끼리 비유 수 정확 원인 예후 예후예측 예측 통합적 연구 아래 기반 들 상호 상호관계 관계 을 표현 가능 간 지식 모델링 의료데이터 수행 질병 분류 실험 병 통해 새 발견 의료학 학 바 바이로의료 이로 적용 목표 하나 외의
#
# realistic content, realistic content acquisition, realistic content interaction, realistic content auhorring and management 기가 기가급 급 대용량 양 양방향 방향 실감 콘텐츠 기술 개발 획득 실감콘텐츠 고속 렌더링 상호 상호작용 작용 저작 관리 유무선 네트워크 환경 다수 사용자 동시 참여 수 서비스 실현 초 점 그래픽 핵심 교육 의료 방송 통신 분야 활용 가능 시스템 중 동적 혼재 기반 초 영상 품질 측정 플랫폼 시범 상용 본 기술개발 일차적 상용화가 화가 예상 도구 수출 영화 방송제작물 제작물 경제적 효과
#
# transcoding,digital modulation,multi-channel,DTV,H.264 다채널 트랜스 트랜스모듈레이터 모듈 레이터 트랜스코딩 코딩 디지털 디지털변조 변조 디지털방송 방송 동영상 특징 3 랙 타입 장비 18 18개 개 264 입력 신호 실시간 변환 내장 3개 8 출력 1 1개당 당 2 2개 채널 송출 이중화 전원 지원 원격 제어 감시 실시 간 입출력 데이터 생성 표준 101 290 에러 측정 하드웨어 규격 6 1000 관리 포트 100 상태 482 200 132 이내 90 240 소비 소비전력 전력 동작 동작온도 온도 -20 -20도 도 60 동작습도 습도 0 18채널 트랜스코 코 영상 고품질 기반 칩 사용 영상신호 압축률 9.4 정도 대역폭 이용 기존 방송신호 품질 제공 정보 채널번호 번호 채널이름 이름 등 용 6개 동시 후 모듈레이터 하드 웨어 트랜스코더 더 구현 시스템 운용 안정성 확보 포트당 병렬 인터페이스 3채널 업 업컨버터 컨버터 하나 직렬 개발 개발완료 완료 당해 당해년도 년도 예상 예상매출 매출 30 30억 억 10 10억 개발종료후 종료 1년 년 50 50억 2년 90억 80 80억
#
# SaaS Aggregation,Cloud Data Binding,SaaS Service Interlock,Cloud Event Processing,Mashup Service 클라우드 서비스 메 메쉬업 쉬 업 기술 개발 이벤트 처리 데이터 바인딩 연동 기반 설계 핵심 모듈 구현 사용자 기초 분석 트렌드 예측 만족 제공 수 만족도 증진 분산 다양 통합 관리 플랫폼 테스트 테스트베드 베드 구축 성 성능지표 능지 표 시스템 자원 모니터링 제어 간 인증 표준 메커니즘 활용 기능 프레임 프레임워크 워크 이용 환경 등록 와의 상황 정의 각 텍스트 들 실시간 알고리즘 목적 등 복수 복수개의 개의 동시 적용 가능 규칙 분리 전송 보안 생성 비정형 저장 검색 변환 히 히스토리 스토리 맞춤 맞춤형 형 추천 유기적 지원 저장소 중심 관점 통합적 원천 확보 독립적 요구 구성 새 모델 창출 형태 진입 장벽 국산 국내 활성화
#
# FDS,DeepLearning,Mobile,Remittance,Payment 모바일 기기 소액 송금 결제 적합 사기 사기거래감지시스템 거래 감지 시스템 개발 사기거래감지 딥 딥러닝 러닝 방식 패턴 특정 사용자 프로 프로파일 파일 생성 해당 결제시 시 엔진 오픈 오픈소스 소스 기반 2 소 프트웨어 이용 개개인 서비스 장기 장기적인 적인 양성 배치 작업 대조 표준 차 통해 특징 인식 기술 디바이스 특유 데이터 수집 가공 정보 수 을 형태 당 암호 입력 래 내역 입력시의 시의 행동 인증 최적화 대표 경우 그 금액 사용 주요 출처 사용시간 시간 등 특화 구매 추출 머신 머신러닝 금융 학습 자체 빅 빅데이터 여부 판단 적응 적응형 형 모델 실시간 속도 인프라 스트럭 800 3 5 24 144 1 10 사기거래 확정 대량 때 사용자별 별 과정 가능 스마트 스마트폰 폰 연락처 소셜 셜 계정 이 모니터링 반응 취소 지연 관리자 기능 기존 명의자 금융시스템 때문 저장 구현 명의 명의자만 자만 본인 사용가능 각종 있음 축약 방법 30 30만원 만 원 미만 분석 특이점 도출 건 정상 메인 적용 도입 운영비 감축 효과 거래량 증가 판독 운영 운영비용 비용 사기거래감 감 지 지시스템 고효율 기대 판매 고도화 수요 충족 본 연구 결과 결과인 인 솔루션 사업 확보 최근 신용 신용카드사 카드 사 가맹점 사이 결제시스템 구축 관리 업무 수행 결제대행 대행 간편 간편결제 개편 한편 보안 핵심 핵심요소 요소 부상 이상 이상금융거래탐지 탐지 앞 국내 곳 업체 해외 금융권 영업 비즈니스 영위 상황 현재 제한 대부분 중심 인증기술 새 발견 필요 2년 년 이내 유지 유지보수 보수 도입요구 요구 무엇 다양 금액대 대 설계 앱에서 제공 리스크 감소 신뢰성 브랜드 그림 그림7 7 전자 전자지갑 지갑 불편 우려 우려사항 사항 결제환경 환경 이유 기술개발 2014 2014년 년 삼성 앱 앱카드 사고 미연 방지 지속적 시장 확대 잠재적 이미지 활용 활용분야 분야 상기 최종 제품 국외 모든 은행 증권 금융업 전자금융업 등록 등록업체 문제 테크 앞날 장애 장애요인 요인 작용 보안업계 업계 바이오 바이오테 테 시장 예상 기관 남 비율 상 전자상거래 상거래 신뢰 결제업체 장기적 대손 손실률 수익률 향상
#
# Optical Module,Field Assembly,Plastic Optical Fiber,Versatile,650nm LED 현장 현장조립 조립 플라스틱 광 광파이버 파이버 광모듈 모듈 개발 현장조립형 형 플라스틱광파이버 다목적 650 650나노미터 나노 나노미터 미터 엘이디 사용 광원 광수신 수신 송신기 650㎚ ㎚ 속도 기존 제품 수신부 전용 상 구현 렌즈 일체형 몰딩 하우징 부가 삽입 안정적 취급 패키지 특성 용 기술 최종 목표 다음 155 광전송 광출력 출력 -1 650㎚파장 파장 사용시 이용 100 전송 가능 -23 1 1㎜ ㎜ 0 부의 설계 제조 최적 부 장착 수 구조 안정 2 소형 공정 순서 중요 대 위 부착 부분 작업 작업틀 틀 정렬 수지 3 형상 일체화 케이스 등 고려 효율적 수광 4 외형 커넥터 제작 체결 정확 사 사출시 출시 재료 분석 신뢰성 본 코어 입사 때문 최소한 허용 허용오차 오차 이 고정 고정밀도 밀도 부품 완성 본제품 환경 장소 광섬유 오 오정렬 손실 내구성 5 고장 고장분석 평가 측정 광파장 25 온도 출력변화 변화 장치 장치설계 시스템 구성 선택 프로 프로토콜 토 콜 2,000 2,000시간 시간 광소자 소자 최근 시장 증가 상태 국내 업체 전무 후 수입 수입대체 대체 효과 물론 수출 수출증대 증대 소량 소량수입 중소기업 시제품 완료 즉시 국내업체 판매 국내시장 점유율 향상 중점 단시간 내 매출 매출효과 경우 미국 사가 세계 세계시장 점유 독과점 성격 정도 가격 사용자 국산화 15 이하 매출증대 데이터 통신 분야 치중 나 광통신 새 전략 관련 산업 적용 적용가능 422 신호 기기 로봇 서보 원격 컨트롤
#
# ComputerAnimation,Dcharacteranimation,Crowdsimulation 실시간 제어 제어가능 가능 패치 패치기반 기반 군중 시뮬레이션 기술 기술개발 개발 컴퓨터 애니메이션 캐릭터 본 연구 영화 영화등 등 콘텐츠 등장 3 3차원 차원 씬 자동 생성 그래픽스 소프트 소프트웨어 웨어 기법 핵 저작 애 메이 메이터 터 의도 최대한 반영 제어성 성 촛점 이 뎁스 센서 행동 행동양식 양식 패 재활용 계층 시 시공간충돌 공간 충돌 감지 하이브리드 궤적 궤적기반 집합 제약 제약조건 조건 만족 모션 합성 합성기법개발 구현 이용 사용 사용자의 자의 캡처 후 변형 중의 모션생성 적용 산란 을 개별 시공간 데이터 구조 저장 수 시스템 통합 하나 대한 사용자 평가 유용성 알고리즘 개체 길이 액션 셋 일종 클립 공간상 상 설정 위치 포즈 단순 사람 뿐 실세계 곤충 새 집단 움직임 분석 기본 모델 활용 궤 궤적를 적를 모든 바 바운딩 운 딩 박스 트리 체크 하다 물리적 분야 초기 초기값 값 결과물 경우 대부분 제안 결과 이 응용
#
# Tour,Travel,SNS,Planner,Sharing 기반 여행 여행플래너 플래너 플랫폼 기술 기술개발 개발 관광 소 소셜 셜 네트워크 계획 공유 한국 대표 글로벌 여행서비스 서비스 성장 관광산업 산업 기여 사업 목표 목표임 임 최종 최종목표 정보 여행후기 후기 사용자 공간 편집 저장 간 자유 소통 기존 한계 극복 결과 여행자 여행상품 상품 제공자 사용 수 여행계획 후 향후 여행관련 관련 빅 빅데이터 데이터 활용 국가 창조 창조관광 활성화 기대 내 회원 계획수립 수립 다수 사이트 항 항공사 공사 여행사 지도 등 방문 스케줄 비용 조정 엑셀 엑셀표 표 작성 불편 숙박 숙박시설 시설 역 가격 제안 마켓 마켓플레이스 플레이스 머스 연계 결제 기능 기간 동안 종료 원래 비교 해외 스타트 스타트업 업 기업 필요 페이스 페이스북 북 전세계 성장하면서 하면서 차별화 링크 구인 구인구직 구직 징 징가 소셜게임 게임 스타 스타그램 그램 사진 사진공유 등 특화 전문화 등장 한국어 제공 중 있음
#
# G,FutureRadioAccess,NonOrthogonalMutipleAccess,SpatialModulation,BioinspiredOptimization,Gametheory,SpectralEfficiency,Systemcapacity 5 미래 무선 접속 새 기술 연구 5세대 세대 직교 분할 공간 공간변조 변조 생체 모방 최적화 게임 이론 주파수 효율성 시스템 이상 의 이하 을 위 광대역 개발 논의 용량 확대 등 활용 제고 관련 원천 확보 전력 영역 향상 기술인 최적 분배 알고리즘 기반 수행 안테나 자원 할당 결합 방식 제안 각각 스펙트럼 전송 효율적 다양 선행 조사 분석 기존 성능 평가 수학적 모의 실험 비교 장 단점 설계 요구 요구사항 사항 정립 채널 고려 정리 기법 장점 접목 가능성 검토 시간 환경 모의실험 네트워크 시뮬레이터 2 3 통신망 사용자 사용자간 간 적용 평균 지표 도출 특성 테스트 베드 구축 방안 모델링 구현 선행연구 자료 트랜시버 기 검증 이전 사업 차세대 이동 만족 수 증대 특허 상용 결과 출원 국가 위상 강화 창업 학생 학생창업 지주 지주회사 회사 설립 설립등 통신 이외 유선 부분 우수 학문 후속 인력 분야 전문 양성
#
# light pose estimation,LED control,environment map,image based lighting,light intensity fuction 영상 영상무드변환기법 무드 변환 기법 적용 조명 조명환경파라미터 환경 파라미터 추정 소프트 소프트웨어 소프트웨어엔진 웨어 엔진 응용 응용소프트웨어 개발 제어 영상처리 처리 감성 감성조명 본 기술 이미지 기반 조명환경정보 정보 추출 조명무드정보추출 광원 광원정보 구성 제안 실효성 추억 추억속 속 분위기 만들기 응용프로그램 프로그램 구현 목표 영상기반 세부 세부개발 내용 다음 엔진개발 관심 관심객체 객체 분리 환 환경맵 경맵 생성 알고리즘 검출 주 주광원 보조 보조광원 특성 분석 기술개발 사진 사용자 직관적 선택 비교 미세 미세조정 조정 인터페이스 재현 최적 방법 최종 목표인 인 프로그램구현 최종개발목표 핵심 핵심기술 일반인 조명환경 본 추적 사용 입력 조명정보 한 장의 일반 어안 어안렌즈영상 렌즈 등 관심영역 영역 분할 구축 맵의 이진화 군집 밝기 밝기등 주요 조절 색상 각 색상정보 카메라 메타 데이터 이의 최종적 통 실제 다채널 전달 이 조명무드 공간 실내 실내조명 설계 초점 조명제어 경우 단순 단순제어 무드재현 고려 색상제어 도출 조명효과 효과 품질 향상 보정 색온도 발생 오차 이용 테스트 필요 환경요소 요소 과제 조명환경추출 수동적 나 사용자가 자가 표현 색감 정량화 객관적 조명특성 가능 점 차별 차별성과 성과 독창성 기존 제품 경험적 소비자 제공 정량적 가이드라인 제시 시간 비용 획기적 단축 소규모 창업 1 1인창조 창조 콘텐츠 다양 시장 활용 수 마찬가지 개별적 중소기업 개인 제작 창업장 장 솔루션 상용 가능성 업체 기 기개발 결합 통합 스마트 카페 음식점 1인 창작 시 배치
# 6.Wireless Telemetry,7.GAS AMI System,8.Data Collection Unit,9.Smart Meter,10.two-way communication, 가스 술 션 개발 1 검침 2 시스템 3 데이터 데이터수집장치 수집 장치 4 스마트 미터 5 양방향 양방향통신 통신 시범 시범사업 사업 단계적 확대 원격 무선 무선검침 기술 도입 실효성 검증 안정성 확보 상용 추진 수 서비스 제공 통합 관제 플랫폼 을 목적 있음 현 현안 안 이슈 해결 효율 인력 인력검침 원격검침 고 생산성 업무 전환 가능 댁내 가구주 부재 시 추정 추정검침 고객 민원 손실 사전 예방 방문 불편 불안감 해소 체납 적극적 대응 공급 차단 전력 수도 경쟁 한전 지능 전력망 망 구축 네트워크 종속 우려 정부 그리드 실증 이후 보급 중 신규 기회 활용 기반 등 수용 홈 내 모니터링 확장 예 기능 외형 방수 구조 생활 생활방수 65 등급 이상 태양광 전지 패널 연동 충전 전원 2일 일 900 정보 응용 서버 전송 6 6회 회 동기화 가스미터기 미터기 송신 주기 단선 통신장애 장애 오동 오동작 작 발생 자동 송출 사출 형태 값 적산 조정 리셋 배터리 수명 5년 년 약 5,800 잔량 후 진행 함 정확도 수준 오차율 이내 성공율 99 교체 안전 안전차단 향후 구현 세대 가구 적시 정확 용 성 체납고객
#
#  생체 생체모방자 모방자 로봇 특화 특화연구센터 연구 센터
#
# 6.research,7.development,8.security,9.evaluation,10.analysis, 제품 1 연구 2 개발 3 보안 4 평가 5 분석 본 사 현재 연구개발 연구장비 장비 공동 공동활용 활용 지원 지원사업 사업 개발중인 중인 신제품 소프트 소프트웨어 웨어 기반 네트워크 보안제품 개발완료 완료 단계 방화벽 침입 침입방지 방지 가상 가상사설망 사설망 등 기능 수행 통합 통합보안제품 외부 인터넷 침해 공격 조직 내부 정보 정보통신망 통신망 보호 수단 사용 서비스 요청 허가 접근 차단 성능 보안기능 객관적 수준 측정 정량적 제시 경쟁력 향상 3.0 1의 의 개발과정 과정 주관 주관기관 기관 한국 한국산업기술시험 산업 기술 시험 보유 유해 트래픽 발생 15408 보안기능시험 침입패턴 패턴 탐지 탐지시험 침투 침투시험 성능시험 측정자료 자료 결과 획득 신 적용 다음 자산 대한 침입코드 코드 확인 설계 설계상 상 문제점 취약 강화 성능저하 저하 문제 해결 근래 자주 보안사고 사고 적극 대응 가능 본사 보안취약점 점 필수 필수적인 적인 도움 예상 고객 검증 제공 고가 비용 비용절감 절감 예방 경제 기대
#
# Position Information Service,Taxi Control System,Integration Terminal,Taxi Meter,Card Payment Machine 택시 적용 3 무선 무선통신모뎀 통신 모뎀 을 이용 네비게이션 미터기 카드 카드결제기 결 제기 기능 스마트 스마트통합시스템 통합 시스템 개발 위치 위치정보서비스 정보 서비스 택시관제시스템 관제 통합단말 단말 택시미터기 2 2차년 차년 기술 기술개발 목표 주행 결제 관제센터 센터 실시간 제공 수 플랫폼 전송 상품 디자인 기구 제작 내용 센터서버 서버 미터 미터기간 기간 주기적 모듈 카드정보 카드사 사 방범 택시기사 기사 위급 위급상황 상황 발생 발생시 시 획득 위치정보 발송 운영 장착 결제기 상호 상호연동 연동 요금 요금정보 통합제어 제어 설계 수요처 요구 사항 상품디자인 기대 기대효과 효과 통합단말기 단말기 기술력 확보 운용 시작품 작품 신뢰성 검사 품질 확인 시장 경쟁력 제품 제품원가 원가 산출 선호
#
# 6.integration,7.GPS,8.IMU,9.absolute survey,10.spatial information, 이동 이동형 형 측 측위 위 시스템 1 통합 2 위성 위성측위시스템 3 관성 관성항법시스템 항법 4 절대 절대측위 5 공간 공간정보 정보 신 신청사 청사 위성측위 카메라 스캐너 등 티 센서 3차원 차원 취득 처리 개발 영상 영상정보 레이저 레이저스캐너 점 점군 군 데이터 위치 자세 측정 수 생성 기존 산업 선진화 이룩 해외 의존도 산업분야 분야 국내 독자적 기술력 확보 사업 사업분야 독립적 기술 구축 기법 도로 기반 시설물 상태 평가 재난 재해 재해사고 사고 예방 멀티 멀티센서 이용 다양 응용 프로그램 수행 목적 점군데이터 탑재 이동체 위치정보 자세정보 해석 필수적 통합과정 과정 절대위 가능 대여 장비 동시 트리거 신호 제공 간격 제어 핵심적 역할 예상 대여장비 장비임 임 제작 연구 연구개발사업 필요 모듈 활용 효과 융합 점군정보 영상내 내 절대위치 측량 측량업무 업무 대신 수치 수치지형도 지형도 도로기반 구축등 분석 안전성 적용 기대 경제 다음 인력 위주의 주의 측량산업 탈피 외 외업 업 내업 위주 변경 작업자 객관적 의사 결정 수단 시간 비용 절감 국산화 고가 기술확보
#
# BK21 Plus 21 플러스 휴먼 휴먼웨어 웨어 정보 정보기술사업단 기술 사업단 창의 창의형 형 인재 인재양성 양성 도전적 연구 연구문화 문화 융 융복합 복합 혁신 협업 사업 사업단의 단의 비전 전문가 하드웨어 소프트 소프트웨어 나아 인간 친화성 강조 패러다임 전환 선도 수 창 목표 창의성과 성과 도전 도전정신 정신 극대화 혁신적 교육 인프라 구축 창조 창조경제 경제 글로벌 학 학제적 제적 연구역량 역량 강화 국가 산업 경쟁력 제고 기여 비 전 달성 3 전략 다양 학문 다각적 체험 교류 수행 수행능력 능력 배양 새 정보기술 능동적 개척 형성 교 교내외 내외 산학 산학연 연 국내외 커뮤니티 주도적 참여 소통 고려대 고려대학교 학교 연구내용 내용 핵심 망라 반도체 나노 집적 집적회로 회로 통신 네트워크 컴퓨터 신호 신호처리 처리 전기 전기에너지 에너지 제어 제어로봇시스템 로봇 시스템 일곱 개의 그룹 구성 분야 인간친화 친화 철학 학문적 학문적기술적 기술적 전문 관점 노력 세부 전공 전문인력 인력 필요 기초 기초소양 소양 연구윤리 윤리 등 성장 인간적 인력양성 마련 본 생각 다음 7 7가지 가지 공동 공동연구실 연구실 융합 융합연구 활성화 기반 1 소자 소자관점 양자 광 기능 설계 제작 2 디스플레이 공정 세분화 저전력 고성능 메모리 프로 프로세서 세서 차세대 인터넷 이동 이동통신 광대역 무선 무선통신 홈 4 유비 유비쿼터 쿼터 컴퓨팅 병렬 병렬처리 컴퓨팅 5 영상 영상처리 음성 음성처리 생체 생체신호 영상전송 전송 음성인식 인식 6 변환 변환시스템 지능 성장동력산업 동력 한국 지속적 성장견인 견인 본 확립 최근 평생 평생교육 교육기반 자기계 자기계발 발 기술개발 개발 근거 체계 과학 과학기술인 기술인 과학기술자 기술자 인문 인문사회적 사회적 인간관 사회인 역할 기초기술 글쓰기 논문 논문작성 작성 말하기 발표 발표능력 연구기획 기획 팀장 팀원 능력배양 교수법 수법 교수 교수자로서의 자로 서의 기본 특허 특허발명 발명 개발자 특허기술 창업 사회 수요 수요창출 창출 바탕 전세계 환경 교육적 기대 기대효과 효과 교육혁신 인적 네트워크과 과 독창적 창의성 겸비 미래형 중추적 담당 배출 경제적 세계적 신 신시장 시장 미래 신성장 동력원 도약 사회문화적 문화적 기존 미래기술 인간중심 중심 트렌드 주도하 사회문화 국가경쟁력 발전 발전방향 전방향 방향 제시 강국 위상 인류 직면 문제 극복 지속 지속가능 가능
#
# video push-to-talk, voice push-to-talk, smartphone, 2-way radio, RoIP 스마트 영상 푸쉬 푸쉬투 투 플랫폼 음성 스마트폰 폰 무전기 연동 1 1단계 단계 사업 개발 솔루션 기반 2 2단계 비즈니스 모델 서비스 고도화 제품별 패 패키징 키 징 최종 최종목표 목표 실시간 현장 현장영상 공유 시스템 용 스마트워 워 앱 중계 클라우드 클라이언트 게이트웨이 장비 소개 제품 판매 서비스웹 웹 개발자 지원 개발자웹 1차 차 분 추가 기능 영상공유 송신 수신 서버 스마트워치 치 이용 아이 아이폰 안 안드로이드 드로 이드 고객 조직도 그룹 관리 대용량 확장성 이중화 러 러스터링 스터링 로드 런 런싱 싱 보안 보안강화 강화 암호화 레 레거시 거시 통합 통합연동 비즈니스모델 별 설치 설치형 형 패키지 사용자 채널 모니터링 통계 설정 웹인터페이스 인터페이스 관리자 페이지 매뉴얼 제작 임 임대형 대형 구축 버전 설치본 본 샘플 프로젝트 가이드 2포트 포트 연 연동 동 통신 통신모드 모드 브릿 브릿지 지 안내 회원 가입 구매 프로세스 다운로드 관련 기술 기술문서 문서 제공 프로그램 라이센스 발급 결과 활용 계획 공공 공공안전 안전 공장 관광 민간 민간기업 기업 등 기존 아날로그 사용 곳 적용 가능 산업 교신 시장 진입 커스 커스터마이징 터 마이 필요 대기업 주요 예상 판매처 현지 건설 제조 지사 글로벌 국내외 물류 물류센터 센터 보유 화물 운송 각 지방 자치 자치단체 단체 운영 중인 공공기관 기관 공공기업 구호 재난 분야 놀이 놀이시설 시설 공연장 전시장 시설물 빌딩 출동 출동보안 네트워크 개인 동호 동호회 회 악 바이크 자동차 생산 생산유발효과 유발 효과 시장창출효과 창출 2016 2016년 년 2,000 2,000억 억 원 국내 규모 기준 2017 2017년 3,440 3,440억 추정 2019 2019년 총 누적 약 11,169 11,169억 시장창출 추산 부가 부가가치유발효과 가치 2,393 2,393억 7,768 7,768억 부가가치 수입 수입대체효과 대체 20 의 시장점유율 점유율 달성 시 482 482억 수입대체 발생 1,564 1,564억 고용 고용유발효과 4,438 4,438명 명 고용유발 14,408 14,408명 고용창출
#
# speed measurement ,optical lens,high resolution video,band pass filter,laser pulse 원거리 고속 최대 최대300 300 이동체 실시간 포커 포커싱 싱 촬영 5 5백 백 가능 스피드 포스 포스먼트 먼트 장치 개발 속도 속도측정 측정 광학 광학렌즈 렌즈 고 고해상도 고해상도영상 해상도 영상 대역 대역패스필터 패스 필터 레이저 레이저펄스 펄스 기존 차량 시 포커스 수 지점 100 120 접근 때 만 활용도 제약 장소 고속차량 발견 발견시 단속 방법 배경 예측 구현 기술적 한계 제안 목표물 거리 가변 위치 주행 고정식 휴대 이동 이동형 형 장착 사용 교통 교통사고 사고 예방 핵심 장비 목표 함 주관 주관기업 기업 1 1차년 차년 메인 제 저장 통신 표시 부 네트워크 4 영상압축 압축 전송 센서 연동 트리거 동기 수신 기능 2 배율 기준 번호 번호인식가능 인식 해상력 50 이상 셔터 셔터스피드 밝기 제어 신호 줌렌즈 구동 구조 프레임 설계 제작 공동 공동개발기업 레이 기술 건설 광학렌즈설계 가공 가공기술 기계 물체 속 발 수 수광부 광부 미국 중국 바이어 요청 상태 기존제품 제품 소개 유럽 일본 등 선진국 효율적 발생 방지 수요 증대 동남아 중남미 신흥 국가 낙후 환경 개선 관련 신기술 관심 가격 운용 효용 장점 휴대형 과속 과속단속시스템 시스템 시장 확대 전망 있음 경제 산업 인포스먼트 외 지능 자동차 자동화 국방 국방산업 응용 응용분야 분야 경제적 파급 효과 국내 공간 공간인식 전무 수준 때문 확보 미래 산업기술 경쟁력 제고 기대
#
# healthcare,Wearable,Blood pressure,Bio-feedback,Biometric 다중 다중생체신호 생체 신호 이용 손목 손목시계 시계 형 혈압 측정 헬스 헬스케어 케어 러 바이오 바이오피드백 피드백 생체신호 1 사용자 고유 특성 분석 후 가능 모바일 플 플리케이션 리 케이 션 개발 2 처리 대용량 데이터 기술 고려 개인 개인화 화 기반 초경량 인증 시스템 구축 엔진 수집 분산 분산형 웹서버 5 5의 의 그래프 시각화 도구 실시 실시간 간 압축 계층화 알고리즘 확보 시장 선점 선도 우수 인력

# %%
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-9-b786e3290074> in <module>()
# ----> 1 import wordninja
#
# C:\ProgramData\Anaconda2\envs\py27\lib\site-packages\wordninja.py in <module>()
#      14
#      15 # Build a cost dictionary, assuming Zipf's law and cost = -math.log(probability).
# ---> 16 with gzip.open(os.path.join(os.path.dirname(os.path.abspath(__file__)),'wordninja_words.txt.gz')) as f:
#      17   words = f.read().decode().split()
#      18 _wordcost = dict((k, log((i+1)*log(len(words)))) for i,k in enumerate(words))
#
# C:\ProgramData\Anaconda2\envs\py27\lib\gzip.pyc in open(filename, mode, compresslevel)
#      32
#      33     """
# ---> 34     return GzipFile(filename, mode, compresslevel)
#      35
#      36 class GzipFile(io.BufferedIOBase):
#
# C:\ProgramData\Anaconda2\envs\py27\lib\gzip.pyc in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#      92             mode += 'b'
#      93         if fileobj is None:
# ---> 94             fileobj = self.myfileobj = __builtin__.open(filename, mode or 'rb')
#      95         if filename is None:
#      96             # Issue #13781: os.fdopen() creates a fileobj with a bogus name
#
# IOError: [Errno 2] No such file or directory: 'C:\\ProgramData\\Anaconda2\\envs\\py27\\lib\\site-packages\\wordninja_words.txt.gz'
