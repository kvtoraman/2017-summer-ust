# %%
# Author: Kamil Veli TORAMAN <kvtoraman@gmail.com>
# Seperates English words given without spaces
# infer_spaces function is from web

from __future__ import print_function
import pandas as pd
import logging
import numpy as np
from optparse import OptionParser
import sys, copy
from time import time
from random import randint
from math import log
#import matplotlib.pyplot as plt
from IPython.display import display, HTML
from sklearn.datasets import fetch_20newsgroups
from sklearn.datasets import fetch_rcv1

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import RidgeClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.svm import SVR
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.extmath import density
from sklearn import metrics

# %%
# Build a cost dictionary, assuming Zipf's law and cost = -math.log(probability).

def infer_spaces(s):
    """Uses dynamic programming to infer the location of spaces in a string
    without spaces."""

    # Find the best match for the i first characters, assuming cost has
    # been built for the i-1 first characters.
    # Returns a pair (match_cost, match_length).
    def best_match(i):
        candidates = enumerate(reversed(cost[max(0, i-maxword):i]))
        return min((c + wordcost.get(s[i-k-1:i], 9e999), k+1) for k,c in candidates)

    # Build the cost array.
    cost = [0]
    for i in range(1,len(s)+1):
        c,k = best_match(i)
        cost.append(c)

    # Backtrack to recover the minimal-cost string.
    out = []
    i = len(s)
    while i>0:
        c,k = best_match(i)
        assert c == cost[i]
        out.append(s[i-k:i])
        i -= k

    return " ".join(reversed(out))

# %%
file_name = 'B_trainwith8542rows.dat'
data = open(file_name).readlines()
out = open('rev_'+file_name,'w')
ENCODING = 'utf-8'
data_train_data = []
y_train = []
def is_ascii(s):
    return all(ord(c) < 128 for c in s)

words = open("words-by-frequency.txt").read().split()
wordcost = dict((k, log((i+1)*log(len(words)))) for i,k in enumerate(words))
maxword = max(len(x) for x in words)

for line_id,line in enumerate(data):
    items = line.split('\t')
    if len(items) == 2:
        out.write(items[0]+'\t')
        line = items[1].decode(ENCODING, 'ignore')
        ascii_mode = False
        tmp = ""
        if(line_id%100 == 0):
            print(line)
        for i,c in enumerate(line):
            if(c!=' ' and is_ascii(c) and not ascii_mode):
                ascii_mode = True
            if(not is_ascii(c) and ascii_mode):
                ascii_mode = False
             #   print(line_id,tmp)
                blocks = tmp.split(' ')
                for block in blocks:
                    block = block.lower()
                    spaced = infer_spaces(block)
                    for guess in spaced.split():
                    #    if len(guess)>2:
                            out.write(guess+' ')
                tmp=""
            if not ascii_mode:    
                out.write(c.encode('utf-8'))
            else:
                tmp += c.encode('utf-8')
            if c!=' ' and len(line)>i+1 and is_ascii(c) and not is_ascii(line[i+1]):
                #if(i%200 == 0): 
                #    print(i,c, line[i+1])
                out.write(' '.encode('utf-8'))
        out.write("\n")
    else:
        print("ERROR in train")
out.close()
# Out:
# Mobile Web/APp,Process oriented,Gateway Server,Service Platform,encryption 스마트 단말기 기반 업무 업무시스템 시스템 연동 모바일 플 플리케이션 리 케이 션 서비스 컨버전스 플랫폼 기술 개발 프로세스 프로세스중심형 중심 형 게이트웨이 게이트웨이서버 서버 서비스플랫폼 암호화 기업 연계 미들 미들웨어 웨어 프레임 프레임워크 워크 적용 공인 인증 조합 조합형 패키지 데이터 확보 체계 구축 부 부문 문 특화 시범 경제적 효과 시험 참여 자 간 신규 시장 비즈니스 모델 발굴 교육 컨설팅 등 직접적 보급 다양 채널 활용 홍보 산업 산업인력 인력 육성 최 최신 신 확산 주도 업무혁신 혁신 강화 기술적 기존 구현 기여 플랫폼간 표준 표준화 기술강화 분리 완성 완성도가 도가 사회적 보안 보안모듈 모듈 개인 개인정보 정보 지적 자산 유출 방지 비즈 니스 도메인 가속화
#
# NIR,Automation,Robot Hardware,Multitasking,DataMining 근적외 근적외선 선 분광기 샘플링 측정 자동화 분석 시스템 개발 로봇 하드웨어 멀티 멀티태스킹 태스킹 데이터 데이터마이닝 마이닝 2 2차년 차년 과제 목표 1 1차년도 차 년도 안정 제품 기능 수 전체 업그레이드 수행 외부 통신 연계 장애 극복 등 구현 디바이스 기계 전기적 안정성 유럽 인증 을 공식적 소프트 소프트웨어 웨어 스케줄 스케줄링 링 제어 기본 기능외 외 7 7일 일 24 24시간 시간 운용 극복형 형 에러 대응 유기적 작동 5 5가지 가지 관점 다음 근 적외선 분광 유연 실시간 쌍방 위 대량 작업 실현 단순 통계 기존 기술 접합 기반 샘플 강화 현재 대상 독일 브루 옵틱스 옵틱스사 사 분광기술 생산성 향상 인력 효율 극대화 융합 고급 사용자 유용 정보 제공 상황 엔진 주변 환경 인지 3 반자동 지능 연동 편의 편의성 성 강조 구축 4 모듈 시리얼 사용 주 연결 모드 모드버스 버스 이용 간 쌍방향 프로 프로피버스 피 6 유럽연합 연합 증 안전 준수 컨트롤 기계적 위험 요소 방지 최소화 레벨 안전성 미들 미들웨어 실시 간 체크 로그 오류 내성 무정지 산업 측면 완벽 국내외 주요 농수산물 검역 연구원 세관 화학 재료 연구소 대학 연구실 농 농화학 물질 제조사 국가 시험 공정 공정분야 분야 생명 생명과학 과학 대기업 디스플레이 제약 제약회사 회사 식품 상품 한약재 생산적 연구 업무 기술적 분석기 효과 독자적 솔루션 활용 있슴 가치 궁극적 노하우 체득 고부 경험 축적
#
# Globalillumination,Realtimerendering,Temporalcoherence,Shadowmap,Shadowtexture,Softshadow,Graphicsprocessingunits,Dgame,Virtualreality 시간 일관성 이용 실시간 전역 조명 렌더링 전역조명 그림자 텍스 그래픽스 프로세싱 유닛 가상 장면 현실감 요소 가지 중 전역적인 적인 계산 중요 역할 효과 빛 현실 어디 관찰 수 현상 실제 유사 재연 자료 자료구조 구조 필요 최근 컴퓨터 기법 연산 을 활용 목적 연구 비용 정답 표현 우리 사용 하드웨어 가속 기존 정보 재활용 특성 가속화 공식 지점 전 방위 영역 입사 입사광 광 눈 반사광 방법 성능 처리 응용 프로그램 적용 근 근사 사 상대적 방법은 데 고 고해 고해상도 해상도 상도 수 생성 이전 속도 고려 범위 확대 추진 계획 1 3 3차년도 차 년도 이론 다수 사각형 면 면광원 광원 임의 모양 계산량 량 기하급수 증가 정적 프레임 재사용을 통해 시도 4 4차년도 간접 간접조명 사실 사실적인 결과 진행 간접광원 맵으 경우 역시 비교 주 주광원 유효 향상 5 5차년도 동적 변화 물체 일반적 완전 환경 가상공간 소요 단축 대상 수행 3차원 차원 그래픽 대다수 콘텐츠 게임 가상현실 등 사용자 상호 상호대화 대화 지속적 동등 혹 품질 요구 시장 부합 수준 결과물 제공
#
# scalable video,Automatic adaptive streaming,Heterogeneous,Media Transport,Network 이종 네트워크 환경 동적 적응 적응형 형 미디어 전달 기술 개발 다 다계층 계층 비디오 자동 스트리밍 전송 1 이종네트워크 기능 상위 설계 2 구현 3 동기화 4 하이브리드 플랫폼 5 시스템 6 테스트 베드 구축 시연 7 연동 서비스 확인 시험 8 통합
#
# AR,Embedded,Avionics,Mission Flight,Safety 증강 증강현실 현실 기반 조종사 임무 훈련 시스템 비행 안전성 향상 기술 개발 임 임베디드 베 디드 항공 항공전자 전자 임무훈련 한길 한길씨앤씨 씨 앤 씨 ㅇ 영상시 영상시현 현 소프트 소프트웨어 웨어 상 상세구 세구 테스트 테스트벤치 벤치 제작 에어 매스 매스터 터 컴퓨터 실용 시제 주요 모듈 통합 조립 전자부품 전자부품연구원 부품 연구원 적 위협 상황 정보 이용 안전 경로 탐색 알고리즘 비행모드 모드 공대지 저고도 야간 변경 안전비행 가이드 이미지 상세구현 프로 프로토타입 토 타입 결과 결과분석 분석 설계 보안 구현 상세 세 하드웨어 전술 전술환경 환경 모의 반영 모듈제작 비 행
#
# EmbeddedSystem,EmbeddedDevice,PhysicalSecurity,PhysicalAttacker,JTAG,HardwareSecurity,SystemModification,AccessControl,SecureDeletion 임 임베디드 베 디드 시스템 물리적 공격 위협 분석 대응 방안 연구 기기 물리 보안 공격자 하드웨어 변조 접근 제어 안전 고려 때 안전성 보장 부가 부가적인 적인 선택 사항 필수적 요구 요구사항 판단 과제 향후 발생 가능 주요 시나리오 방어 기술 과학적 공학 설계 한 효용 실 사용자 대상 보안성과 성과 편의성 평가 검증 실제적 사용 수 솔루션 제공 일반적 경우 관리자 이외 내부 직원 포함 외부 분실 도난 교체 정보 유출 존재 때문 1 검출 방지 기능 2 적합 3 민 저장 장치 삭제 대 목표 단계적 데이터 자체 보호 세부 수행 내부적 개 구성 요소 간의 통신 설정 전력 신호 전송 방식 절차 회피 예 디지털 도어락 정상적 비밀 비밀번호 번호 솔레노이드 전원 공급 잠금 전기 에너지 구동 대부분 재 재전송 취약 대책 실정 터 간 채널 기계 학습 등 동작 상태 모델링 변 변조로 조로 특성 변화 효과적 디버깅 업데이트 용도 인터페이스 노출 펌웨어 악의 악의적인 코드 삽입 문제점 해결 인증 방법 제안 현재 패스 패스워드 워드 통계적 추측 무차별 대입 목적 차등 최소 권한 을 부여 모델 수준 종래 확장 효율적 개발 저장장치 저당 나머지 구분 적용 이 기밀 여부 속성 추가 성능 읽기 쓰기 속도 측정 뿐 실제 모바일 단말기 고용 연산 다양 애플리케이션 증명 연구과제 후속 이론적 기술적 토대 마련 백도 기반 분야 신호처리 처리 의 성공적 결합 융합 귀감 관련 범용 성격 제품 스마트 스마트폰 폰 프린터 무선 무선랜 랜 에어콘 서비스 응용 실용화 단계별 결과 국내 국제 지적 지적재산권 재산권 취득 예상 기업화 기술이전 이전 국가 국가연구소 연구소 삼성 삼성전자 전자 현대 자동차 활용 기업 공유 유사 효과 기대 추후 연구가 진행 본 확산 직접적
#
#  융합 확산 정책 정책지원 지원 우수 아이디어 발굴 반영 업계 인식 인식제고 제고 홍보 활동 추진 가속화 관련 종합적 정보 수집 정부 민간 협력 협력기반 기반 조성 역량 강화 현장 소통 수 기능 정책수립 수립 전략 전략수립 정책연구 연구 전문가 간담회 협의 협의회 회 포럼 등 구성 민간기업 기업 투자 활성화 조세 조세제도 제도 개선 개선방안 방안 국방 분야 중소기업 해외 해외진출 진출 연구용역 용역 한 캐나다 기술 기술협력 회의 네트워크 커뮤니티 참여 산업 정책이슈 이슈 정책수요 수요 성과 성공 성공사례 사례 벤치마킹 기회 기회제공 제공 성과확산 홍보기능 융합기업인상 인상 반기 신규 기업인 현장투어 투어 산학 교류 문화 협의체 적극 산업별 수요자 공급자 다양 요구 요구사항 사항 의견 수렴 시 방향 실효성 가능 산업특성 특성 고려 제도개선방안 정책제안 제안 부처 실제 이슈사항 적극적 전통 전통산업 개발 기존 시장 부가 부가가치 가치 새 창출 도모 함 지속적 기여 수요자간 간 지원체계 체계 구축
#
# V2V/V2I/V2P communication, Dual communication, WAVE, mmWave communication, Autonomous driving, vehicle platooning 협력 적응 자동차 운행 제어용 이중 듀얼 통신망 차량 통신 웨이브 밀리미터 밀리미터파 파 자율 자율주행 주행 군집 군집주행 안전 안전운행 자동 자동주행 협력통신망 신뢰성 실시간 제어 기술 지원 무선 제시 구조 차량통신 뿐 관련 연구 철도 철도간 간 현황 전망 선박 통신기술 동향 레이다 싱 한계 등 미래 요구 내용 바탕 확대 확대적용 적용 자율주행기반 기반 인포테인먼트 예측 멀티미디어 정보 전송 가능 성과 성과활용 활용 2 이중망 망 확보 현재 센서 중심 극복 강조 네트워크 선박통신 응용 응용확대 가능성 운전자 광대역 통신망를 망를 수 기대 기대효과 효과 차량통신망 전 세계적 산업 산업분야 분야 경쟁 본 참여 네트 네트워킹 워킹 세계 경쟁력 국내 4 5 이동 이동통신 선도
#
# Civil Defense Alert System, Integrated Emergency Alert System, In-Door/Out-Door Emergency Alert System, Intelligent Emergency Alert System, Efficient/Reliable Alert Information Transmission Technique 지능 맞춤 통합 통합경보시스템 경보 시스템 고도화 연구 민방위 민방위경보시스템 옥내 외 경보시스템 맞춤형 형 고효율 고 고신뢰 신뢰 경보전달기술 전달 기술 난지 난지역 역 경보발령 발령 매체 해외 선진 선진사례 사례 조사 분석 경보발령기술 지 지능형 능형 재난 재난유형 유형 의사 의사결정 결정 절차 알고리즘 핵심 핵심기술 활용 전시 상황 차세대 확보 경제 산업 기술개발 개발 활성화 유도 관련 신규 신규시장 시장 창출 환경 지적 지적재산권 재산권 제품 제품시장 우위 선점 사회 문화 기종 예 지역 재난경보 사각지대 해소 대규모 인명 인명피해 피해 사회간접자본 간접 자본 보존
#
# social big data,public data,data visualization,cloud system,data analysis 실시간 소 소셜 셜 빅 데이터 바이오 정보 시각화 서비스 소셜빅데이터 공공 공공데이터 데이터시각화 클라우드 클라우드시스템 시스템 데이터분석 분석 수집기 개발 공동 소셜데이터 수집 등 최신 오픈 오픈소스 소스 기술 도입 활용 소셜네트워크 네트워크 웹 문서 알고리즘 기반 네이버 구 구글 글 웹문서 크롤링 구조 부분 주관 주관기업 기업 채널 의미 추출 사용자 제공 이 다양 마이닝 기법 기계 기계학습 학습 을 이용 모듈 종류 텍스트 프로 프로파일링 파일링 트랜드 있음 오피니언 중 긍정 부정 중립적 감정 분류 특정 대상 사람 긍 부정적 감성 통계적 속 개인 입력 프로필 인맥 관계 성향 속한 그룹 영향력 파악 사용 상호 상호관계 키워드 명성 개체 마케팅 설정 트렌드 최근 게시물 무작위 언급 단어 링크 이미지 현재 분산 처리 참여 참여기업 서버 운영 안정성 보장 라 프로세스 효과적 안정적 이것 수행 셋 특성 가능 그래프 비교 후 최종적 효과 효과적인 적인 후보 후보군 군 추천 약 15 15종 종 1 검색 검색엔진 엔진 노드 노드구조 자동화 비동기 방식 구축 2 추천기술 인 인사이트 사이트 차트 인터 인터렉티브 렉 티브 태그 구현 기술적 측면 아이템 연구 연구개발 결과물 빅데이터 고도화 누구 수 범용 솔루션 형태 대중화 핵심 예상 유사 라이브러리 콘텐츠 연동 영역 폭 3 에디터 관련 시간 장소 제약 시성 이 강화 경제 경제산업 산업 시장 시장규모 규모 2012 2012년 년 2.7 2015 2015년 8 이상 추정 예측 가공 소비자 일률 일률보편적 보편적 과정 제시 우리 세계 일조 2017 2017년 534 534억 억 달러 여기 국내 2020 2020년 9 9억 전망 선점 선두 제품 확보 활용방안 방안 판매 중대 적용 컨설팅 업체 광고 기획자 기초적 기능 이외 해당 필요 툴 추가 중소기업 사업자 웹서비스 추가적 월 월정액 정액 인포 인포그래픽 그래픽 의뢰 제작
#
# Toy Robots,Educational Robots,NEOBOT,Smart Network Blocks,Application 멀티 링크 구조 스마트 네트워크 블록 시스템 개발 완구 로봇 교구 네오 네오봇 봇 플 플리케이션 리 케이 션 1 1차년 차년 목표 시스템블록 테크닉 테크닉블록 활용 수 멀티링크 블록프레임 프레임 디바이스 통신 통신방식 방식 분석 선정 모션 모션블록 슈팅 슈팅블록 플러그인 조합 조합기능 기능 프레임웍 웍 연계 내용 엔터테인먼트 엔터테인먼트로봇 위치 위치이동 이동 수행 감속 감속모터 모터 해당 조종 장착 방향 사용 기존 로봇완구 구동 컨트롤러 내장 배터리 배터리블록 모터블록 개 연결선 등 연결 단일 연결로 가능 외부 제어 레 등 아이템 하나 있음 하나의 의 전후 전후진 진 전용 좌우 좌우조종 병행 전 후 좌 우 축 축연결 양쪽 확장성 향상 이 4 4족 족 보행 보행로봇 6 6족 제작 안정 안정검증기준 검증 기준 레이저 광원 빛 발사 송신부 감지 수신부 구성 게임 경우 횟수 세팅 피폭 일정 일정시간 시간 동안 동작 정지 알고리즘 컨트롤 상대방 운 운팅 팅 게임아이템 뿐 놀이 놀이동산 동산 인기 블록완구 통신기능 전자 전자기술 기술 접목 레이 수신 수신센서 센서 슈팅게임 점 점단위 단위 집적도 발사기 초점 10 10㎝ ㎝ 조준 장 장전횟수 조정 설계 수 수광부 광부 카 카운팅 움직임 일시 일시정지 제어신호 신호 발생 영상 영상모듈 모듈 결합 개별 기능모듈 단독 다수 모듈블록 내 2 2개 이상 상호 연동 작동 결합식 식 적 하면 화면 각각 블록방식 구현 사용자 조작 편의성 확보 타입 제품 기대 기대효과 효과 블록구조 센서블록 참고 일체형 치수 배율 유지 레고와 고와 100 호환 하드웨어 모든 무선 무선방식 채택 소형 건전지 저전력 블루투스 4.0 4.0버전 버전 안정적 환경 구축 문제 안전성 테스트 스마트폰 폰 효과적 음성 음성인식 인식 내 활성화 비활성 구분 모습 배경 내 디자인 간 염두
#
# Wi-Fi,indoor Positioning,passive location tracking,active location tracking,low power beacon 이용 능동형 수동형 실내 위치 측 측위 위 기술 개발 와이 와이파이 파이 위치추적 추적 저전력 발신기 스마트 디바이스 전력 신호 의 경우 설치 연산 서버 통신 자체 발신 수신 시간 비컨 정보 전달 장애물 벽 등 이 오차 설정앱 지정 위치별 별 리브 리브레이션 레이션 정확 가능 설정 기능 스마트폰 폰 패드 사용자 유아 유아동 동 노인 러 재산 자전거 열쇠 지갑 장착 사용 수 발신기의 기의 역 역추적 해당 전송 시스템 기존 블루투스 대비 배 지역 정확도 2 3 미만 확인 발신기만 기만 등록 대형 놀이 놀이공원 공원 쇼핑몰 사람 공간 미아 방지 유실물 그동안 시장 접목 진출 움직임 기업 기업시장 관심 기대 주 해외 인식 국내 도입 수입 대체 효과 다양 기반 서비스 서비스등 연계 파급 파급효과
#
# Embedded Software,Open HW platform,robot control,robot SW,EtherCAT 다중 다중코어 코어 실시간 필드 필드버스 버스 통신 인터페이스 지원 임 임베디드 베 디드 로봇 로봇제어기 제어기 개발 임베디 디 소프트 소프트웨어 웨어 오픈 하드웨어 플랫폼 로봇제어 제어 캣 보드 기반 오픈소스 소스 운영 운영체제 체제 구축 활용 485 등 등의 의 범용 적용 다양 디지털 아날로그 처리 수 모듈 구현 필요 부가 부가적인 적인 제작 모델 모델링 링 리브 리브레이션 레이션 모션 모션프로그래밍 프로그래밍 6 6자유도 자유도 프레임 프레임워크 워크 실장 프로 프로토타입 토 타입 멀티 멀티코어 프로세서 고성능 동일 실행 환경 마스터 스택 인 포팅 레 레이브 이브 펙 4 168 32 407 7 024 8 24 5318 사용 1 2 9 사 설 설치하 치하 테스트 선정 해당 추 네트워크 카드 디바이스 확장 일반 이용 트랜시버 프로토콜 콜 향후 10 10년 년 이내 시장 저가 재편 기대 고부 가치 선점 국내 임베 제품 경쟁력 재고 제작업체 업체 라이선스 고성 능 제공 관련 산업 진출 해외 개척 중소 로봇제작업체 뿐 로봇제어기업체 가격 가격경쟁력 유지 시스템 기술 확대 보급 창출 기회 마련 사물 사물인터넷 인터넷 용 게이트웨이 자동화 자동화장치 장치 가능
#
# Position Information Service,Taxi Control System,Integration Terminal,Taxi Meter,Card Payment Machine 택시 적용 3 무선 무선통신모뎀 통신 모뎀 을 이용 네비게이션 미터기 카드 카드결제기 결 제기 기능 스마트 스마트통합시스템 통합 시스템 개발 위치 위치정보서비스 정보 서비스 택시관제시스템 관제 통합단말 단말 택시미터기 1 1차년 차년 기술 기술개발 목표 모듈 결제 부착 차등 외장 정합 정합통신포트 포트 장치 제품 디자인 목 목업 업 제작 통합단말기 단말기 모니터 해당 각종 표출 수행 길 길안내 안내 배차 배차정보 정보입력 입력 정보표출 결제기 모듈개발 주행 주행정보 제공 속도 주행거리 거리 요금 등 정보수집 수집 식 독립형 소켓 소켓형태 형태 연결 주행종료 종료 후 카드결제 연계 택시요금정보 수신 교통 교통카드 13.56 신용 신용카드 마그네틱 칩 결제가능 가능 영수증 영수증프린터 프린터 일체형 결제정보 통신모듈 카드사 서버 송수신 통합제어 제어 핵심 핵심장치 가공 저장 내부 내부연계 구성 정보연계 전원 방범 방범버튼 버튼 갓 갓등 과 기대 기대효과 효과 기술력 확보 시 시작품 작품 기동 확인 검사 원가 원가산출 산출 생산성 검토 품질 품질기준 기준 정의
# ComputerArchitecture,Microprocessor,MulticoreProcessor,CPU,SoC,HighPerformance,LowPower,Reliability,LowTemperatureTechnique 멀티 멀티코어 코어 프로세서 효율적 저온도 유지 기법 개발 컴퓨터 구조 마이크로 마이크로프로세서 고성능 저전력 신뢰성 3 3차원 차원 차세대 설계 때 성능 향상 중요 고려 고려사항 사항 예상 연구 연구과제 과제 구조적 접근 방식 내부 온도 효과적 관리 프로 세서 실험 도구 구성 요소 배치 조절 과열 가능성 제어 저하 최소화 수 등 체계적 수행 목표 대상인 기술 다음 1 기존 확장 전력 예측 2 활용 변경 기반 동적 동작 작업 분배 4 탐지 5 다양 추가 추가지원 지원 본 통합 향후 공정 미세화 시스템 시스템반도체 반도체 문제 해결 방안 40 노 이하 사용 제품 경쟁력 확보 요구 냉각 비용 감소 칩 가격 핵심 제안 국내 일조 내용 뿐 생산 적용 결과 우수성 입증 업체 협력 상용
#
# MovingObjectDetection,SurroundView,AdvancedDriverAssistanceSystem 차량 초광각 카메라 기반 동적 장애물 기술 개발 물체 검출 서라운드 뷰 첨단 운전자 지원 시스템 동작 수 이하 을 적용 임 임베디드 베 디드 상황 정적 장착 일반 일반렌즈 렌즈 어안 어안렌즈 이용 4 4대 대 사용 전 방향 전방향 알고리즘 환경 연구용 실제 실시간 다양 날씨 대상 실증 실증시험 시험 안정화 사업 포항 포항공과대학교 공과 대학교 1 1차년도 차 년도 고정 시 2 2차년도 1차년 차년 바탕 3 3차년도 2차년 왜곡 보정 대구 대구대학교 실시 간 중요 영상 특성 구현 필수 포팅 영남 영남대학교 가지 유모차 보행자 동물 등 테스팅 진행 야외 날씨별 별 시간 시간대별 대별 테 테스팅 스팅 객관적 평가 원인 분석 후 추후 모색 베이 베이다스 다스 4방향 하나 접목 기 보유 다량 영상정보 정보 수집 데이터 데이터베이스 베이스 구성 하드웨어 검증 추진 경북 지역 자동차 부품 제조 관련 매출 1000 1000억원 억 원 이상 업체 집중 집중분포 분포 이 연계 순수 융합 부품업체 전환 시도 중 대표적 아진 아진산업 산업 에스 에스엘코 엘코 레이션 타이 타이코 코 기능 주력 주목적 함 외 소재 솔루션 국내 해외 완성 완성차 공급 있음 언급 대학 인재 능력 능력향상 향상 도모 재의 진출 경쟁력 강화 작년 4명 명 학생 취업 대표 대표이사 이사 포함 회사 내부 인력 다수 출신 과제 지역인재 경제 영향 시장 안정적 성장 기여 최종적 활성화 추구
#
# BlackBox,Client,ErrorTracking,Computer,Monitoring 클라이언트 단말 오류 추적 블랙 블랙박스 박스 프로그램 관리 시스템 개발 오류추적관리 컴퓨터 모니터링 발생 사후 장애 원인 확인 수 시 상태 기록 기술 발생시 문제 상황 정확 진단 조치 기반 지원 저장 온도 상시 별도 정보 분석 각종 공공 공공기관 기관 교육 교육기관 효과적 설치 활용 전산 전산담당자 담당자 후 개발자 내용 전달 프로세스 간소화 시간 소모 업무 중단 문제해결 해결 감소 전체 생산성 향상
#
# Biosignal Processing, Wearable Computing, EEG 뇌파 이용 러 스마트 헬스 케어 기술 생체 신호 처리 컴퓨팅 뇌전도 본 연구 사용자 어디 측정 건강관리 증진 사용 수 개발 시스템 적 적시성 시성 효율성 본인 공간적 제약 휴대 휴대가능 가능 편리 장 장비 함 추출 보장 원칙 연구팀 팀 자체 자체개발 기기 모바일 플랫폼 활용 추진 보유 중 이 장치 뇌 뇌파도 파도 센서 그것 소형 컴퓨터 건강 정보 표시 디스플레이 포함 계속 이번 소형화 하드웨어 소프트 소프트웨어 웨어 성능 향상 착용 패턴 분석 집중 이완 감정 상태 피로 피로한지 한지 등 표현 원천 원천기술 확보 그동안 혈당 혈압 체중 심전도 신체 미래 정신 중심 대비 향후 복지 분야 산업 생태 환경 구축 선도 선도적인 적인 역할
#
# CultureCoexistence,HeritageTimeView,AugmentedImage,RealtimeInteraction,CultureofPresentandPast,MobileCultureExhibition,FeatureClustering,MultiplePhotoSynthesis,TimelineTechnology 현재 과거 공존 증강 증강영상 영상 타임 타임라인 라인 활용 기술 개발 문화 문화유산 뷰 실시간 인터 인터랙션 랙 션 모바일 전시 특징 특징점 점 군집 다중 본 연구 과제 증 강 기반 핵심 분야 증강현실 현실 설계 문화기술 과 스마트 융합 실외 효과적 예술 예술작품 작품 지역 랜드 랜드마크 마크 시대 현실세계 세계 결합 융합형 형 목표 시스템 다음 기술적 내용 대상지 대상지역 역 선정 역사적 자료 데이터베이스 유산 데이터 베이스 전문가 검증 상호 상호작용 작용 위치 방향성 정보 획득 처리 이미지 추출 매칭 측정 센서 파노라마 최적화 계층 사용자 인터페이스 인터랙션 지원 기대 기대효과실감형 효과 실감 콘텐츠 관리 체계 수립 문화정보 패러다임 제공 제공실시간 미래형 확보 세계시장 시장 선도 선도실감 문화콘텐츠 산업화 국민 참여 풍요 문화생활 영 영위활용분야 위 서비스 시나리오 요소 요소기술 관광 광고 광고시장 교육 확장 적용 가능 국내외 도서관 박물관 문화원 우리 우수성 홍보 장
#
# FPGA,network,security,accelerator,packet 기반 네트워크 보안 시스템 가속기 개발 에프 에프피지 피지 패킷 초고 초고속 속 필터링 알고리즘 데이터 흐름 악성 악성코드 코드 행위 시 처 일종 구현 방식 적합 메모리 최적 이용 고속 탐지 엔진 수 탑재 보안시스템 처리 속도 저하 문제 획기적 개선 이식 보드 타입 방화벽 대응 대응장비 장비 등 기 설치 운용 신규 기술 융합 가능 벤더 기술제휴 제휴 기술개발 내용 다양 성능 우수 방법 주관 주관기관 기관 남 남서울대학교 서울대 학교 산학 산학협력단 협력 단 연구 과 디자인 활용 참여 참여기업인 기업인 온 온시스템 개발인력 인력 사업 고객 사이트 필드 테스트 기존 대용량 공유 부하 발생 연구개발 적용 병렬 전용 계 수 공간 확보 수백만 개 좀비 공격자 선별 국내 제품 시 등 패 킷 킷처리 요구 요구사항 사항 해결 10 존재 한 최대 패킷수 약 3,000 3,000만개 만 양방향 14.880 2 처리하 리하 지 단점 향상 기대 처리율 정도 1,000 1,000만개 이상 보안장비 자체 부팅 현상 본 적 용 경우 99 최신 공격 패턴 방어 능력 지원 해소 해외 다수 점유 대형 시장 대 용량 산업 수입 대체 효과 활성 화 기여 국산 국제 경쟁력 성능저하 회의감 산업체 활성화
#
# AR,VR,smart,Edutainment,3D 증강 증강현실 현실 활용 창의 창의교육 교육 시스템 개발 색칠 색칠공부 공부 스마트 스마트교육 이 이러닝 러닝 1 기술 기술개발 목표 최종 최종개발목표 유아 초등학생 체험 체험형 형 놀이 학습 콘텐츠 세부 세부개발목표 기 색칠놀이 스케치북 폰 앱 융합 2 학습방법 방법 3 구현 아이 무한 상상 도움 내용 동작 스케치 북 스마트폰 실행 자신 그림 2차원 차원 의 공간 곤충 화면 입체 상호 상호반응 반응 주요 기능 스토리텔링 평면 이용 입체감 이미지 변화 몰입 몰입감 감 객체 식물 정보 제공 내 캡 통 실시간 자원 생산 적용 모바일 카메라 촬영 영상 내 표면 재질 변환 트래킹 범위 보관 각도 정규화 추출 분석 통한 스의 재구성 기술개발시 시 예상 예상효과 효과 기대 기대효과 에듀테인 에듀테인먼트 먼트 제품 업체 학습장 유치원 납품 인재 분야 창조 경제
#
# DistributedNetwork,OptimalCSMA,SelfHealingAlgorithm,CoverageHoleProblem 대규모 환경 완전 분산 분산형 형 부분 무선 자율 자율네트워크 네트워크 핵심 기술 개발 최적 자가 치유 알고리즘 홀 문제 인프라 기반 중앙 중앙집중 집중 셀룰라 이동 이동통신 통신 용량 한계 해결 중요 후보 고려 분산네트워크 연구 발생 1 1차년 차년 2014 2014년 년 중심 다중 다중접속 접속 자원 자원관리 관리 관련 주요 문제점 기술이슈 이슈 도출 충돌 전파 현상 다양 노드 분포 등 사용자 간 보장 증대 요소 요소기술 정보 생성 이것을 조절 이용 가능 2 2차년 2015 2015년 고도화 기존 환경임 임 채널 솔루션 을 제시 고 노드밀도 밀도 제안 현실성 메시지 전달 최소화 3 3차년 2016 2016년 이론적 가정 의 현실적 관점 유틸리티 최대화 계층 계층교차 교차 최적화 성능 분석 시뮬레이터 개선 통합 프로 프로토콜 토 콜 완전분산형 부분분산형 기술개발 미국 선진국 격차 상태 선행 지적 지적재산권 재산권 확보 시장 시장선점 선점 향후 산업 수 효과 실 시 경우 단위 단위면적 면적 당 고용량 요구 만족 망 부하 경감 전체 시스템 동작 에너지 소모 절감 기술적 파급 전망 차세대 원천 국내 기여 있음 한 무선네트워크 표준 국제 경쟁력 강화
#
# infographic,imageeditor,Dynamic Inforgraphic,Sharing System,bigdata visualization 인포 인포그래픽 그래픽 제작 제작비용 비용 절감 동적 자동 자동생성 생성 공유 공유시스템 시스템 개발 이미지 이미지편집기 편집기 동적인포그래픽 빅 빅데이타시각화 데이타 시각화 종료 해 해당년 당년 2015 2015년 년 이 베타 서비스 구축 투자 투자계획 계획 10 10백만원 백만 원 확보 내수 50 50백만원 고용 고용창출 창출 2 2명 명 확대 1 1년 후인 2016 2016년 국내 100 100만원 만 100백만원 5 5명 2년 2017 2017년 해외 300 300백만원 수출 200 200백만원 을 10명 라이브러리 요소 500 500종 종 레이 레이아웃 아웃 샘플 20 20종 관리 관리시스템 이미지등록 등록 수정 삭제 분배 툴 방식 기능 기 기반의 반의 저작 저작도구 도구 플랫폼 운영 솔루션 온라인 판매 손 활용 사이트 접속 구입 일반인 학생 공공 공공기관 기관 디자인 업체 시 수 유료 무료 무료회원 회원 구분 유료회원 다양 동 적인 포 신문사 잡지사 등 대상 공급 공급계약 계약 추진 콘텐츠 정보 정보제공 제공 효과적 링크 광고 광고수익 수익 유료회원제 회원제 발생 기대 3 홍보 마케팅 방안 관련 공모전 응모 지원 자체 개최 공공정보 보도 보도자료 자료 배포 사회적 이슈 사안 신속 타 때 노출 뷰 증가
#
# IMTAdvanced,wirelessmobilesystems,Gmobilecommunications,videotransmissions,scalablevideocoding,MPEG,testbed,crosslayer,radioresourcemanagement 이동 이동통신망 통신망 비디오 전송 연구 무선 무선이동시스템 시스템 4 4세대 세대 이동통신 통신 802.16 표준 등 기술 적용 기반 솔루션 확보 이 기존 시뮬레이터 구현 모듈 완성 추가 실제 데이터 생성 통해 품질 측정 수 도구 값 통합 테스트 테스트베드 베드 구축 코덱 파라미터 적응 변화 애플리케이션 개선 방법 정보 링크 1 1차년도 차 년도 동작 이해 분석 파일 송수신 가능 요구 요구조건 조건 변경 무선망 방법론 기술적 해결 요소 셀 경계 성능 저하 원인 기초적 수행 2 2차년도 계층 바탕 무선자원 자원 할당 당 알고리즘 공존 경우 하향 하향링크 버퍼 관리 핸드 핸드오버 오버 개발 방식 비교 3 3차년도 확장성 보완 2차년도와 차년 도와 반대 토대 트래픽 로드 환경 기법 상향 상향링크 말 아키텍처 동시 결과물 멀티미디어 3세대 무선랜 랜 적용가능 6 기 반 미래 인터넷 홈 홈네트워크 네트워크 가전 오디오 스마트 기기 등에 확장 제인 음 음영 영 유용 사용 발전 기여 서비스 사업자 기지국 단말 자원관리 부족 주파수 경제성
