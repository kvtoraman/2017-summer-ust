# %% [markdown]
# # Classification of text documents using sparse features
#
# This is an example showing how scikit-learn can be used to classify documents
# by topics using a bag-of-words approach. This example uses a scipy.sparse
# matrix to store the features and demonstrates various classifiers that can
# efficiently handle sparse matrices.

# %%
# Author: Peter Prettenhofer <peter.prettenhofer@gmail.com>
#		  Olivier Grisel <olivier.grisel@ensta.org>
#		  Mathieu Blondel <mathieu@mblondel.org>
#		  Lars Buitinck
# License: BSD 3 clause

from __future__ import print_function

import logging
import numpy as np
from optparse import OptionParser
import sys, copy
from time import time
#import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import RidgeClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.svm import SVC

from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.extmath import density
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
def transform_label(clf, prob, topk):
	rst_arr = np.empty( (len(prob), topk), dtype=object) 
	for i in range(len(prob)):
		s_items = np.argsort(prob[i])[-topk:]
		
		for j in range(len(s_items)):
			rst_arr[i][j] = clf.classes_[s_items[j]]
			
			
	return rst_arr

def apk_per_class(actual, predicted, k=1):
	"""
	Computes the average precision at k.
	This function computes the average prescision at k between two lists of
	items per each class
	Parameters
	----------
	actual : list
			 A list of elements that are to be predicted (order doesn't matter)
	predicted : multi list
				A list of predicted elements (order does matter)
	k : int, optional
		The maximum number of predicted elements
	Returns
	-------
	score : double
			The average precision at k over the input lists
	"""
	class_score = {}
	micro_correct = 0.0
	length = 0

	if len(actual) == len(predicted):		
			
		for	i in range(len(actual)):
			if actual[i] not in class_score:
				class_score[actual[i]] = [0.0, 0.0] # correct_score, length
			well_classified = False
			for pred in predicted[i]:				
					
				if actual[i] in pred:
					class_score[actual[i]][0] += 1.0
					micro_correct += 1.0
					well_classified = True
			if(type(actual[i]) is list):
				print("!! actual[",i,"] is ",actual[i])
			if(actual[i] == CODE):
				print(well_classified , "docID:",i,"prediction of ",CODE," was:",predicted[i])
				fail_list.append(i)
			class_score[actual[i]][1] += 1.0
			length+=1
				
	avg_acc = 0.0 
	for cl in class_score.keys():
		avg = class_score[cl][0]/class_score[cl][1]
		if(avg<0.5 and count[cl]-class_score[cl][1] > class_score[cl][1]):
			print("!Low precision :! #Correct:", class_score[cl][0], "#Tested:", class_score[cl][1],"#Train",count[cl]-class_score[cl][1])
		print ("\t", cl, "Acc.:", avg, "Correct:", class_score[cl][0], "Tested:", class_score[cl][1],"#Train",count[cl]-class_score[cl][1])
		avg_acc +=avg

	print ('Total Test Examples', length, "\nMicro Acc.(item level)", micro_correct/length)
	return avg_acc/len(class_score)

###############################################################################
# Benchmark classifiers
def benchmark(clf):
	print('_' * 80)
	print("Training: ")
	print(clf)
	t0 = time()
	clf.fit(X_train, y_train)
	train_time = time() - t0
	print("train time: %0.3fs" % train_time)

	t0 = time()
	
	# Top 1 
	pred = clf.predict(X_test)	  
	probs = clf.predict_proba(X_test)
	
	for topk in range(5, 6):
		best_n_label = transform_label(clf, probs, topk)
		
		test_time = time() - t0
		print("test time:  %0.3fs" % test_time)

		pred = best_n_label
		print ("Top-", topk)
		print ("Macro Acc.(class level)", apk_per_class(y_test, best_n_label, topk), "\n\n")

# %%
##################################################################
### Define train/test/code list files 
#################################################################
#code_list_fn = "./data/KSSC_sample_data_170206_Codelist.dat"
#train_fn = "./data/KSSC_sample_data_170206_Train.dat"
#test_fn = "./data/KSSC_sample_data_170206_Test.dat"

code_list_fn = "NSCC_sample_data_170309_Codelist.dat"
train_fn = "rev_utf8_train_big.dat"
test_fn = "rev_utf8_test_big.dat"
ENCODING = 'utf-8'

###############################################################################
# Load some categories from the training set
categories =  [x for x in open(code_list_fn,'r').read().split('\n') if len(x) > 0]

print("Loading NSCC	 dataset for categories:")
print(categories if categories else "all")
print(len(categories))

data_train = open(train_fn).readlines()
data_test = open(test_fn).readlines()
#all_data = open('rev_reserved_data_all.dat').readlines()
all_data = open('rev_izip_new_data_all.dat')
data_train_data, data_test_data = [], []
y_train, y_test = [], []
all_x, all_y = [], []
count = {}
for cat in categories:
    count[cat] = 0


for line in all_data:
    items = line.split('\t')
    if len(items) == 2:
        all_x.append(items[1].decode(ENCODING, 'ignore'))
        all_y.append(items[0])
        if not count.has_key(items[0]):
            count[items[0]] = 0
        count[items[0]] += 1
    else:
        print('ERROR IN READING')
"""
for line in data_train:
	items = line.split('\t')
	if len(items) == 2:
		data_train_data.append(items[1].decode(ENCODING, 'ignore'))
		y_train.append(items[0])
        count[items[0]] += 1
for line in data_test:
	items = line.split('\t')
	if len(items) == 2:
		data_test_data.append(items[1].decode(ENCODING, 'ignore'))
		y_test.append(items[0])
        count[items[0]] += 1
"""
data_train_data,data_test_data,y_train,y_test = train_test_split(all_x,all_y,random_state =7, train_size = 0.70)
#trash_a,data_test_data,trash_b,y_test = train_test_split(all_x,all_y,random_state =1, train_size = 0.60)
print (len(data_train_data), len(data_test_data))
print('data loaded')
# order of labels in `target_names` can be different from `categories`
target_names = categories #data_train.target_names
guess = 80000*[""]
#for i,line in enumerate(data_test_data):
#    if(u'개선' in line and u'공정' in line and u'관련' in line and u'국내' in line and u'최적' in line  and u'환경' in line):
#        print("Obvious:",CODE,y_test[i])
#        guess[i] = "EH14"
# Out:
# Loading NSCC	 dataset for categories:
# ['EA99', 'EI02', 'EI03', 'EI01', 'EI06', 'EI07', 'EI04', 'EI05', 'EG08', 'EI08', 'EI09', 'EG09', 'EA08', 'EA09', 'EA02', 'EA03', 'EA01', 'EA06', 'EA07', 'EA04', 'EA05', 'EC10', 'EE99', 'EB08', 'EF99', 'EI11', 'EI10', 'EI12', 'EA15', 'EA14', 'EA11', 'EA10', 'EA13', 'EB99', 'EA12', 'EE08', 'EE09', 'EE06', 'EE07', 'EE04', 'EE05', 'EE02', 'EE03', 'EE01', 'EB01', 'EB03', 'EB02', 'EB05', 'EB04', 'EB07', 'EB06', 'EE11', 'EE10', 'EE13', 'EE12', 'EI99', 'EE14', 'EC08', 'EC09', 'EC01', 'EC02', 'EC03', 'EC04', 'EC05', 'EC06', 'EC07', 'EF05', 'EF04', 'EF06', 'EF01', 'EF03', 'EF02', 'ED10', 'ED11', 'EG04', 'EG05', 'EG06', 'EG07', 'EG01', 'EG02', 'EG03', 'ED07', 'ED06', 'ED05', 'ED04', 'ED03', 'ED02', 'ED01', 'ED09', 'ED08', 'EH10', 'EH11', 'EH12', 'EH13', 'EH14', 'EH15', 'EG99', 'EC99', 'ED99', 'EC11', 'EH09', 'EH08', 'EH03', 'EH02', 'EH01', 'EH07', 'EH06', 'EH05', 'EH04', 'EH99', 'EG10']
# 111
# 29826 12784
# data loaded

# %%
# Add Word Embedding (Word Embedding, Topic Embedding, Topic-Event Embedding) Features

print("Extracting features from the training data using a sparse vectorizer")
t0 = time()
my_stop_words = [unicode(x.strip(), 'utf-8') for x in open('kor_stop_word.txt','r').read().split('\n')]

#print (my_stop_words)

vectorizer = TfidfVectorizer(sublinear_tf=True, max_df=0.5,stop_words=my_stop_words,max_features = 50000,min_df = 3)
X_train = vectorizer.fit_transform(data_train_data)

duration = time() - t0

print("n_samples: %d, n_features: %d" % X_train.shape)
print()

print("Extracting features from the test data using the same vectorizer")
t0 = time()
X_test = vectorizer.transform(data_test_data)
duration = time() - t0
print("n_samples: %d, n_features: %d" % X_test.shape)
# Out:
# Extracting features from the training data using a sparse vectorizer
# n_samples: 29826, n_features: 50000
#
# Extracting features from the test data using the same vectorizer
# n_samples: 12784, n_features: 50000

# %%
feature_names = vectorizer.get_feature_names()
fail_list = []
CODE = "EH15"
feature_names = np.asarray(feature_names)
# Train SGD model
clf = SGDClassifier(loss='modified_huber', alpha=.0001, n_iter=50, penalty='l2')
benchmark(clf)
# Out:
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='modified_huber', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=None, shuffle=True,
#        verbose=0, warm_start=False)
# train time: 142.577s
# test time:  0.988s
# Top- 5
# False docID: 2026 prediction of  EH15  was: ['EI11' 'EI04' 'EH01' 'EE09' 'EE02']
# False docID: 3494 prediction of  EH15  was: ['ED08' 'EA10' 'EA08' 'ED06' 'EA14']
# False docID: 3759 prediction of  EH15  was: ['NC10' 'EC03' 'ED10' 'EH07' 'EH09']
# False docID: 6006 prediction of  EH15  was: ['EA03' 'ED99' 'EA02' 'EC09' 'EE01']
# 	 EA99 Acc.: 0.566037735849 Correct: 60.0 Tested: 106.0 #Train 252.0
# 	 EI02 Acc.: 0.907407407407 Correct: 49.0 Tested: 54.0 #Train 111.0
# 	 EI03 Acc.: 0.95 Correct: 171.0 Tested: 180.0 #Train 405.0
# 	 ND08 Acc.: 0.846153846154 Correct: 11.0 Tested: 13.0 #Train 48.0
# 	 EI01 Acc.: 0.923076923077 Correct: 36.0 Tested: 39.0 #Train 105.0
# 	 EI06 Acc.: 1.0 Correct: 69.0 Tested: 69.0 #Train 151.0
# 	 EI07 Acc.: 0.809523809524 Correct: 17.0 Tested: 21.0 #Train 25.0
# 	 EI04 Acc.: 0.963917525773 Correct: 187.0 Tested: 194.0 #Train 456.0
# 	 EI05 Acc.: 0.882352941176 Correct: 60.0 Tested: 68.0 #Train 136.0
# 	 ND02 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 2.0
# 	 EG08 Acc.: 0.736842105263 Correct: 14.0 Tested: 19.0 #Train 52.0
# 	 EI08 Acc.: 0.884615384615 Correct: 23.0 Tested: 26.0 #Train 52.0
# 	 EI09 Acc.: 0.953125 Correct: 61.0 Tested: 64.0 #Train 169.0
# 	 ND06 Acc.: 0.5 Correct: 1.0 Tested: 2.0 #Train 4.0
# 	 ND07 Acc.: 1.0 Correct: 11.0 Tested: 11.0 #Train 20.0
# 	 ND04 Acc.: 0.272727272727 Correct: 3.0 Tested: 11.0 #Train 9.0
# 	 EG09 Acc.: 0.892857142857 Correct: 25.0 Tested: 28.0 #Train 56.0
# 	 LA09 Acc.: 0.857142857143 Correct: 6.0 Tested: 7.0 #Train 31.0
# 	 LA08 Acc.: 0.5 Correct: 4.0 Tested: 8.0 #Train 21.0
# !Low precision :! #Correct: 1.0 #Tested: 3.0 #Train 7.0
# 	 SC09 Acc.: 0.333333333333 Correct: 1.0 Tested: 3.0 #Train 7.0
# !Low precision :! #Correct: 4.0 #Tested: 11.0 #Train 43.0
# 	 EH14 Acc.: 0.363636363636 Correct: 4.0 Tested: 11.0 #Train 43.0
# 	 LA03 Acc.: 0.0 Correct: 0.0 Tested: 4.0 #Train 1.0
# 	 LA02 Acc.: 1.0 Correct: 2.0 Tested: 2.0 #Train 6.0
# 	 LA05 Acc.: 1.0 Correct: 5.0 Tested: 5.0 #Train 24.0
# 	 LA07 Acc.: 0.842105263158 Correct: 32.0 Tested: 38.0 #Train 97.0
# !Low precision :! #Correct: 0.0 #Tested: 4.0 #Train 17.0
# 	 EH15 Acc.: 0.0 Correct: 0.0 Tested: 4.0 #Train 17.0
# 	 EA08 Acc.: 0.808 Correct: 202.0 Tested: 250.0 #Train 547.0
# 	 EA09 Acc.: 0.9375 Correct: 390.0 Tested: 416.0 #Train 985.0
# 	 EA02 Acc.: 0.677248677249 Correct: 128.0 Tested: 189.0 #Train 427.0
# 	 EA03 Acc.: 0.798913043478 Correct: 147.0 Tested: 184.0 #Train 452.0
# 	 EA01 Acc.: 0.789473684211 Correct: 90.0 Tested: 114.0 #Train 303.0
# 	 EA06 Acc.: 0.862903225806 Correct: 107.0 Tested: 124.0 #Train 356.0
# 	 EA07 Acc.: 0.820717131474 Correct: 206.0 Tested: 251.0 #Train 558.0
# 	 EA04 Acc.: 0.834532374101 Correct: 116.0 Tested: 139.0 #Train 412.0
# 	 EA05 Acc.: 0.920962199313 Correct: 268.0 Tested: 291.0 #Train 710.0
# 	 ND14 Acc.: 0.5 Correct: 1.0 Tested: 2.0 #Train 6.0
# 	 EC10 Acc.: 1.0 Correct: 4.0 Tested: 4.0 #Train 21.0
# 	 ND11 Acc.: 0.0 Correct: 0.0 Tested: 1.0 #Train 1.0
# 	 ND10 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 9.0
# 	 ND13 Acc.: 0.6 Correct: 3.0 Tested: 5.0 #Train 9.0
# 	 EE99 Acc.: 0.755980861244 Correct: 158.0 Tested: 209.0 #Train 463.0
# !Low precision :! #Correct: 2.0 #Tested: 5.0 #Train 11.0
# 	 LC10 Acc.: 0.4 Correct: 2.0 Tested: 5.0 #Train 11.0
# 	 EB08 Acc.: 0.6875 Correct: 11.0 Tested: 16.0 #Train 35.0
# !Low precision :! #Correct: 0.0 #Tested: 4.0 #Train 5.0
# 	 HE04 Acc.: 0.0 Correct: 0.0 Tested: 4.0 #Train 5.0
# 	 EF99 Acc.: 0.692708333333 Correct: 133.0 Tested: 192.0 #Train 324.0
# 	 EI11 Acc.: 0.918181818182 Correct: 101.0 Tested: 110.0 #Train 247.0
# 	 EI10 Acc.: 0.894736842105 Correct: 17.0 Tested: 19.0 #Train 60.0
# 	 EI12 Acc.: 0.872549019608 Correct: 89.0 Tested: 102.0 #Train 212.0
# 	 EA15 Acc.: 0.869565217391 Correct: 20.0 Tested: 23.0 #Train 76.0
# 	 EA14 Acc.: 0.833333333333 Correct: 30.0 Tested: 36.0 #Train 128.0
# 	 SD02 Acc.: 0.0 Correct: 0.0 Tested: 1.0 #Train 1.0
# 	 EA11 Acc.: 0.962962962963 Correct: 78.0 Tested: 81.0 #Train 189.0
# 	 EA10 Acc.: 0.940170940171 Correct: 220.0 Tested: 234.0 #Train 596.0
# 	 EA13 Acc.: 0.972222222222 Correct: 35.0 Tested: 36.0 #Train 83.0
# !Low precision :! #Correct: 40.0 #Tested: 92.0 #Train 232.0
# 	 EB99 Acc.: 0.434782608696 Correct: 40.0 Tested: 92.0 #Train 232.0
# !Low precision :! #Correct: 0.0 #Tested: 1.0 #Train 9.0
# 	 SC11 Acc.: 0.0 Correct: 0.0 Tested: 1.0 #Train 9.0
# !Low precision :! #Correct: 1.0 #Tested: 3.0 #Train 6.0
# 	 LC14 Acc.: 0.333333333333 Correct: 1.0 Tested: 3.0 #Train 6.0
# 	 OA02 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 4.0
# 	 SC12 Acc.: 0.714285714286 Correct: 5.0 Tested: 7.0 #Train 15.0
# !Low precision :! #Correct: 3.0 #Tested: 7.0 #Train 17.0
# 	 OA04 Acc.: 0.428571428571 Correct: 3.0 Tested: 7.0 #Train 17.0
# 	 ND09 Acc.: 0.928571428571 Correct: 13.0 Tested: 14.0 #Train 24.0
# 	 EE08 Acc.: 0.729166666667 Correct: 35.0 Tested: 48.0 #Train 127.0
# 	 EE09 Acc.: 0.848484848485 Correct: 112.0 Tested: 132.0 #Train 282.0
# 	 EE06 Acc.: 0.921568627451 Correct: 141.0 Tested: 153.0 #Train 366.0
# 	 EE07 Acc.: 0.865384615385 Correct: 45.0 Tested: 52.0 #Train 129.0
# 	 EE04 Acc.: 0.885245901639 Correct: 54.0 Tested: 61.0 #Train 121.0
# 	 EE05 Acc.: 0.810344827586 Correct: 47.0 Tested: 58.0 #Train 133.0
# 	 EE02 Acc.: 0.948377581121 Correct: 643.0 Tested: 678.0 #Train 1674.0
# 	 EE03 Acc.: 0.979899497487 Correct: 195.0 Tested: 199.0 #Train 377.0
# 	 EE01 Acc.: 0.930555555556 Correct: 268.0 Tested: 288.0 #Train 658.0
# 	 OB02 Acc.: 0.666666666667 Correct: 2.0 Tested: 3.0 #Train 10.0
# 	 OB01 Acc.: 1.0 Correct: 3.0 Tested: 3.0 #Train 10.0
# 	 ND03 Acc.: 0.333333333333 Correct: 1.0 Tested: 3.0 #Train 2.0
# 	 LC99 Acc.: 0.25 Correct: 1.0 Tested: 4.0 #Train 3.0
# 	 SH01 Acc.: 0.0 Correct: 0.0 Tested: 5.0 #Train 4.0
# 	 OB99 Acc.: 0.5 Correct: 1.0 Tested: 2.0 #Train 4.0
# !Low precision :! #Correct: 1.0 #Tested: 5.0 #Train 6.0
# 	 ND01 Acc.: 0.2 Correct: 1.0 Tested: 5.0 #Train 6.0
# 	 EB01 Acc.: 0.83922829582 Correct: 261.0 Tested: 311.0 #Train 645.0
# 	 EB03 Acc.: 0.886120996441 Correct: 249.0 Tested: 281.0 #Train 634.0
# 	 EB02 Acc.: 0.878431372549 Correct: 224.0 Tested: 255.0 #Train 579.0
# 	 EB05 Acc.: 0.6 Correct: 36.0 Tested: 60.0 #Train 135.0
# 	 EB04 Acc.: 0.836734693878 Correct: 41.0 Tested: 49.0 #Train 140.0
# 	 EB07 Acc.: 0.6 Correct: 18.0 Tested: 30.0 #Train 66.0
# 	 EB06 Acc.: 0.765306122449 Correct: 75.0 Tested: 98.0 #Train 206.0
# 	 EE11 Acc.: 0.760273972603 Correct: 111.0 Tested: 146.0 #Train 351.0
# 	 EE10 Acc.: 0.612068965517 Correct: 71.0 Tested: 116.0 #Train 243.0
# 	 EE13 Acc.: 0.741935483871 Correct: 23.0 Tested: 31.0 #Train 117.0
# 	 EE12 Acc.: 0.903846153846 Correct: 47.0 Tested: 52.0 #Train 111.0
# 	 EI99 Acc.: 0.693181818182 Correct: 61.0 Tested: 88.0 #Train 181.0
# 	 EE14 Acc.: 0.592592592593 Correct: 16.0 Tested: 27.0 #Train 61.0
# 	 LB07 Acc.: 0.8 Correct: 8.0 Tested: 10.0 #Train 19.0
# 	 EC08 Acc.: 0.944444444444 Correct: 17.0 Tested: 18.0 #Train 46.0
# 	 EC09 Acc.: 0.952830188679 Correct: 101.0 Tested: 106.0 #Train 267.0
# 	 HE14 Acc.: 0.769230769231 Correct: 10.0 Tested: 13.0 #Train 35.0
# 	 HE15 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 2.0
# 	 HE13 Acc.: 1.0 Correct: 2.0 Tested: 2.0 #Train 5.0
# 	 EC01 Acc.: 0.806451612903 Correct: 100.0 Tested: 124.0 #Train 298.0
# 	 EC02 Acc.: 0.781954887218 Correct: 104.0 Tested: 133.0 #Train 330.0
# 	 EC03 Acc.: 0.651162790698 Correct: 56.0 Tested: 86.0 #Train 184.0
# 	 EC04 Acc.: 0.967213114754 Correct: 59.0 Tested: 61.0 #Train 184.0
# 	 EC05 Acc.: 0.904109589041 Correct: 66.0 Tested: 73.0 #Train 242.0
# 	 EC06 Acc.: 0.584905660377 Correct: 31.0 Tested: 53.0 #Train 143.0
# 	 EC07 Acc.: 0.884057971014 Correct: 61.0 Tested: 69.0 #Train 149.0
# 	 SC99 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 5.0
# 	 EF05 Acc.: 0.840425531915 Correct: 79.0 Tested: 94.0 #Train 228.0
# 	 EF04 Acc.: 0.714285714286 Correct: 30.0 Tested: 42.0 #Train 111.0
# 	 LC09 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 4.0
# 	 EF06 Acc.: 0.945631067961 Correct: 487.0 Tested: 515.0 #Train 1259.0
# 	 EF01 Acc.: 0.872727272727 Correct: 48.0 Tested: 55.0 #Train 132.0
# 	 EF03 Acc.: 0.85 Correct: 34.0 Tested: 40.0 #Train 95.0
# 	 EF02 Acc.: 0.886363636364 Correct: 39.0 Tested: 44.0 #Train 135.0
# 	 LC03 Acc.: 0.833333333333 Correct: 10.0 Tested: 12.0 #Train 44.0
# !Low precision :! #Correct: 3.0 #Tested: 8.0 #Train 15.0
# 	 LC02 Acc.: 0.375 Correct: 3.0 Tested: 8.0 #Train 15.0
# 	 LC01 Acc.: 0.642857142857 Correct: 9.0 Tested: 14.0 #Train 25.0
# !Low precision :! #Correct: 2.0 #Tested: 5.0 #Train 17.0
# 	 LC06 Acc.: 0.4 Correct: 2.0 Tested: 5.0 #Train 17.0
# 	 LC05 Acc.: 0.733333333333 Correct: 22.0 Tested: 30.0 #Train 51.0
# 	 LC04 Acc.: 0.872727272727 Correct: 48.0 Tested: 55.0 #Train 140.0
# 	 HE01 Acc.: 0.0 Correct: 0.0 Tested: 1.0 #Train 1.0
# 	 SC05 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 1.0
# 	 ED10 Acc.: 0.843137254902 Correct: 172.0 Tested: 204.0 #Train 445.0
# 	 ED11 Acc.: 0.695652173913 Correct: 48.0 Tested: 69.0 #Train 124.0
# 	 EG04 Acc.: 0.944444444444 Correct: 68.0 Tested: 72.0 #Train 152.0
# 	 EG05 Acc.: 0.862068965517 Correct: 25.0 Tested: 29.0 #Train 63.0
# 	 EG06 Acc.: 0.960784313725 Correct: 49.0 Tested: 51.0 #Train 106.0
# 	 EG07 Acc.: 0.944 Correct: 118.0 Tested: 125.0 #Train 299.0
# 	 EG01 Acc.: 0.916666666667 Correct: 22.0 Tested: 24.0 #Train 42.0
# 	 EG02 Acc.: 1.0 Correct: 17.0 Tested: 17.0 #Train 61.0
# 	 EG03 Acc.: 0.769230769231 Correct: 10.0 Tested: 13.0 #Train 59.0
# !Low precision :! #Correct: 0.0 #Tested: 1.0 #Train 3.0
# 	 SI05 Acc.: 0.0 Correct: 0.0 Tested: 1.0 #Train 3.0
# 	 LA06 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 4.0
# 	 NC10 Acc.: 0.75 Correct: 3.0 Tested: 4.0 #Train 18.0
# 	 SB12 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 1.0
# 	 SA07 Acc.: 0.0 Correct: 0.0 Tested: 1.0 #Train 0.0
# 	 SF01 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 1.0
# 	 ED07 Acc.: 0.8046875 Correct: 103.0 Tested: 128.0 #Train 315.0
# 	 ED06 Acc.: 0.812834224599 Correct: 152.0 Tested: 187.0 #Train 399.0
# 	 ED05 Acc.: 0.671428571429 Correct: 141.0 Tested: 210.0 #Train 480.0
# 	 ED04 Acc.: 0.948509485095 Correct: 350.0 Tested: 369.0 #Train 745.0
# 	 ED03 Acc.: 0.854166666667 Correct: 164.0 Tested: 192.0 #Train 420.0
# 	 ED02 Acc.: 0.80412371134 Correct: 78.0 Tested: 97.0 #Train 225.0
# 	 ED01 Acc.: 0.8995215311 Correct: 188.0 Tested: 209.0 #Train 457.0
# 	 SC07 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 1.0
# 	 ED09 Acc.: 0.945945945946 Correct: 105.0 Tested: 111.0 #Train 231.0
# 	 ED08 Acc.: 0.803571428571 Correct: 90.0 Tested: 112.0 #Train 254.0
# 	 NC05 Acc.: 0.533333333333 Correct: 16.0 Tested: 30.0 #Train 56.0
# !Low precision :! #Correct: 2.0 #Tested: 5.0 #Train 14.0
# 	 NC04 Acc.: 0.4 Correct: 2.0 Tested: 5.0 #Train 14.0
# 	 NC07 Acc.: 0.6 Correct: 3.0 Tested: 5.0 #Train 4.0
# 	 NC01 Acc.: 0.75 Correct: 3.0 Tested: 4.0 #Train 13.0
# 	 NC03 Acc.: 0.714285714286 Correct: 5.0 Tested: 7.0 #Train 17.0
# 	 NC02 Acc.: 1.0 Correct: 3.0 Tested: 3.0 #Train 18.0
# 	 EH10 Acc.: 0.705882352941 Correct: 36.0 Tested: 51.0 #Train 119.0
# !Low precision :! #Correct: 25.0 #Tested: 51.0 #Train 111.0
# 	 EH11 Acc.: 0.490196078431 Correct: 25.0 Tested: 51.0 #Train 111.0
# !Low precision :! #Correct: 9.0 #Tested: 19.0 #Train 52.0
# 	 EH12 Acc.: 0.473684210526 Correct: 9.0 Tested: 19.0 #Train 52.0
# 	 EH13 Acc.: 0.620689655172 Correct: 18.0 Tested: 29.0 #Train 70.0
# 	 NC09 Acc.: 0.607142857143 Correct: 17.0 Tested: 28.0 #Train 56.0
# !Low precision :! #Correct: 3.0 #Tested: 12.0 #Train 28.0
# 	 NC08 Acc.: 0.25 Correct: 3.0 Tested: 12.0 #Train 28.0
# 	 EG99 Acc.: 0.855670103093 Correct: 83.0 Tested: 97.0 #Train 261.0
# !Low precision :! #Correct: 1.0 #Tested: 4.0 #Train 8.0
# 	 NB09 Acc.: 0.25 Correct: 1.0 Tested: 4.0 #Train 8.0
# 	 NC99 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 6.0
# !Low precision :! #Correct: 8.0 #Tested: 24.0 #Train 35.0
# 	 EC99 Acc.: 0.333333333333 Correct: 8.0 Tested: 24.0 #Train 35.0
# 	 LB02 Acc.: 0.818181818182 Correct: 9.0 Tested: 11.0 #Train 17.0
# !Low precision :! #Correct: 1.0 #Tested: 3.0 #Train 5.0
# 	 LB06 Acc.: 0.333333333333 Correct: 1.0 Tested: 3.0 #Train 5.0
# !Low precision :! #Correct: 61.0 #Tested: 128.0 #Train 366.0
# 	 ED99 Acc.: 0.4765625 Correct: 61.0 Tested: 128.0 #Train 366.0
# 	 LB04 Acc.: 1.0 Correct: 3.0 Tested: 3.0 #Train 9.0
# 	 LB05 Acc.: 1.0 Correct: 4.0 Tested: 4.0 #Train 14.0
# 	 SF07 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 1.0
# 	 LB08 Acc.: 0.866666666667 Correct: 13.0 Tested: 15.0 #Train 31.0
# 	 LB09 Acc.: 1.0 Correct: 10.0 Tested: 10.0 #Train 16.0
# 	 OC03 Acc.: 0.6 Correct: 3.0 Tested: 5.0 #Train 16.0
# 	 EH09 Acc.: 0.815789473684 Correct: 62.0 Tested: 76.0 #Train 146.0
# 	 EH08 Acc.: 0.827586206897 Correct: 24.0 Tested: 29.0 #Train 75.0
# 	 EH03 Acc.: 0.952380952381 Correct: 60.0 Tested: 63.0 #Train 137.0
# 	 EH02 Acc.: 0.954314720812 Correct: 188.0 Tested: 197.0 #Train 405.0
# 	 EH01 Acc.: 0.90990990991 Correct: 101.0 Tested: 111.0 #Train 263.0
# !Low precision :! #Correct: 0.0 #Tested: 1.0 #Train 5.0
# 	 NB03 Acc.: 0.0 Correct: 0.0 Tested: 1.0 #Train 5.0
# 	 EH07 Acc.: 0.890909090909 Correct: 98.0 Tested: 110.0 #Train 261.0
# 	 EH06 Acc.: 0.895833333333 Correct: 43.0 Tested: 48.0 #Train 105.0
# 	 EH05 Acc.: 0.5 Correct: 8.0 Tested: 16.0 #Train 14.0
# 	 EH04 Acc.: 0.96 Correct: 24.0 Tested: 25.0 #Train 77.0
# 	 NA07 Acc.: 0.5 Correct: 1.0 Tested: 2.0 #Train 3.0
# 	 NA06 Acc.: 1.0 Correct: 4.0 Tested: 4.0 #Train 10.0
# 	 NA05 Acc.: 0.666666666667 Correct: 2.0 Tested: 3.0 #Train 15.0
# 	 NA02 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 1.0
# 	 SC10 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 1.0
# 	 LB99 Acc.: 1.0 Correct: 2.0 Tested: 2.0 #Train 5.0
# 	 NA09 Acc.: 0.5 Correct: 1.0 Tested: 2.0 #Train 3.0
# 	 NA08 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 3.0
# 	 LC08 Acc.: 0.666666666667 Correct: 2.0 Tested: 3.0 #Train 11.0
# 	 LB18 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 3.0
# 	 ND05 Acc.: 0.333333333333 Correct: 1.0 Tested: 3.0 #Train 2.0
# 	 EH99 Acc.: 0.722222222222 Correct: 26.0 Tested: 36.0 #Train 97.0
# 	 LB17 Acc.: 0.777777777778 Correct: 7.0 Tested: 9.0 #Train 9.0
# 	 LB16 Acc.: 0.875 Correct: 7.0 Tested: 8.0 #Train 9.0
# 	 LB11 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 5.0
# 	 LB10 Acc.: 0.75 Correct: 3.0 Tested: 4.0 #Train 9.0
# 	 LB13 Acc.: 0.833333333333 Correct: 5.0 Tested: 6.0 #Train 30.0
# 	 LB12 Acc.: 0.666666666667 Correct: 8.0 Tested: 12.0 #Train 11.0
# 	 LB15 Acc.: 1.0 Correct: 2.0 Tested: 2.0 #Train 2.0
# 	 SH99 Acc.: 0.0 Correct: 0.0 Tested: 2.0 #Train 1.0
# 	 EG10 Acc.: 1.0 Correct: 27.0 Tested: 27.0 #Train 74.0
# 	 LB14 Acc.: 0.714285714286 Correct: 5.0 Tested: 7.0 #Train 6.0
# 	 EC11 Acc.: 0.666666666667 Correct: 2.0 Tested: 3.0 #Train 15.0
# 	 NB04 Acc.: 0.833333333333 Correct: 10.0 Tested: 12.0 #Train 29.0
# 	 NB05 Acc.: 0.826086956522 Correct: 19.0 Tested: 23.0 #Train 59.0
# 	 NB06 Acc.: 0.833333333333 Correct: 40.0 Tested: 48.0 #Train 109.0
# 	 NB07 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 3.0
# 	 NB01 Acc.: 1.0 Correct: 1.0 Tested: 1.0 #Train 7.0
# !Low precision :! #Correct: 0.0 #Tested: 2.0 #Train 4.0
# 	 LA10 Acc.: 0.0 Correct: 0.0 Tested: 2.0 #Train 4.0
# 	 SE05 Acc.: 1.0 Correct: 4.0 Tested: 4.0 #Train 11.0
# 	 SE06 Acc.: 0.5 Correct: 3.0 Tested: 6.0 #Train 9.0
# 	 EA12 Acc.: 0.965517241379 Correct: 28.0 Tested: 29.0 #Train 63.0
# 	 LA99 Acc.: 0.833333333333 Correct: 5.0 Tested: 6.0 #Train 7.0
# Total Test Examples 12784
# Micro Acc.(item level) 0.841598873592
# Macro Acc.(class level) 0.739844517818

# %%
# EH14 is 95
# EH15 is 96
CODE_INDEX = clf.classes_.tolist().index(CODE)
CODE_INDEX
# Out:
# 96

# %%
white_list = []
for i,x in enumerate(vectorizer.get_feature_names()):
    if(clf.coef_[CODE_INDEX][i]>0.3):
        print(clf.coef_[CODE_INDEX][i],x)
        white_list.append(x)
# Out:
# 0.329216838227 mn
# 0.311856486217 센타
# 0.30803745042 수공구
# 0.410693569104 실험실
# 0.303040829188 안전
# 0.54930573803 안전관리
# 0.314817992082 전산시스템
# 0.343093755172 차년도의
# 0.327951856906 현장지도점검

# %%
out = file("features.txt","w")

for x in feature_names:
    out.write(x.encode('utf-8','ignore')+"\n")

# %%
print(y_test[fail_list[0]],data_test_data[fail_list[0]])
fail_data = []
for x in fail_list:
    fail_data.append(data_test_data[x])
# Out:
# EH14 생산 공정 불용 타겟 자원 오염 물질 저감 공정 기술 개발 생산 공정 불용 자원 오염 물질 저감 manufacturing process useless regeneration contaminants reduction 주관 기관 주 한청알에프 생산 공정 불용 타겟 나노급 전구체 원료 확보 이용 나노 분말 자원 오염 물질 저감 공정 개발 재생 원료 투입량 대비 재생량 비율 가공비 절감 기존 활용 타겟 분말 제조 공정 대비 재생 나노 분말 조성비 재생 나노 분말 순도 온실 가스 저감 참여 기관 전자 부품 연구원 전구체 나노 분말 확보 분산 기술 개발 재생 나노 분말 입도 재생 나노 분말 비표 면적 주관 기관 주 한청알에프 생산 공정 불용 타겟 회수 기술 연구 생산 공정 불용 타겟 미세 분쇄 불순물 오염 저감 조건 연구 분체 조성비 분석 유지 분쇄 공정 연구 분체 용매 용해 이온 연구 균일 전구체 원료 오염 물질 투입 저감 공정 연구 분산 기술 적용 환원 조건 전구체 석출 거동 관찰 석출 전구체 열처리 나노 분말 재생 연구 재생 나노 분말 응용 제품 제조 평가 기관 용역 개발 공정 청정 평가 수행 환경 성과 개선 참여 기관 전자 부품 연구원 용해 환원 전구체 분산 석출 연구 분산 적용 용매 분산 용 조합 연구 비율 용해 정도 분산 종류 전구체 석출 거동 연구 분산 농도 전구체 석출 거동 연구 조건 전구체 물성 평가 조건 확립 주관 기관 주 한청알에프 생산 공정 불용 타겟 나노급 전구체 원료 확보 이용 나노 분말 자원 오염 물질 저감 공정 개발 재생 원료 투입량 대비 재생량 비율 가공비 절감 기존 활용 타겟 분말 제조 공정 대비 재생 나노 분말 조성비 재생 나노 분말 순도 온실 가스 저감 참여 기관 전자 부품 연구원 전구체 나노 분말 확보 분산 기술 개발 재생 나노 분말 입도 재생 나노 분말 비표 면적

# %%
v = vectorizer.transform(fail_data)
v_array = v.toarray()
important_word = 80000*[0]
buffer = 80000*[0]
for i,doc in enumerate(fail_data):
    print(doc)
    #print(v.toarray()[i])
    #rev_list =  reversed(np.argsort(v.toarray()[i]))
    for j in range(len(v_array[i])):
        if(v_array[i][j]>0.0):
     #       print(index,feature_names[index])
            buffer[j] = 1
        
    for j in range(len(buffer)):
        if buffer[j] > 0:
            important_word[j] += 1
            buffer[j] = 0
# Out:
# 생산 공정 불용 타겟 자원 오염 물질 저감 공정 기술 개발 생산 공정 불용 자원 오염 물질 저감 manufacturing process useless regeneration contaminants reduction 주관 기관 주 한청알에프 생산 공정 불용 타겟 나노급 전구체 원료 확보 이용 나노 분말 자원 오염 물질 저감 공정 개발 재생 원료 투입량 대비 재생량 비율 가공비 절감 기존 활용 타겟 분말 제조 공정 대비 재생 나노 분말 조성비 재생 나노 분말 순도 온실 가스 저감 참여 기관 전자 부품 연구원 전구체 나노 분말 확보 분산 기술 개발 재생 나노 분말 입도 재생 나노 분말 비표 면적 주관 기관 주 한청알에프 생산 공정 불용 타겟 회수 기술 연구 생산 공정 불용 타겟 미세 분쇄 불순물 오염 저감 조건 연구 분체 조성비 분석 유지 분쇄 공정 연구 분체 용매 용해 이온 연구 균일 전구체 원료 오염 물질 투입 저감 공정 연구 분산 기술 적용 환원 조건 전구체 석출 거동 관찰 석출 전구체 열처리 나노 분말 재생 연구 재생 나노 분말 응용 제품 제조 평가 기관 용역 개발 공정 청정 평가 수행 환경 성과 개선 참여 기관 전자 부품 연구원 용해 환원 전구체 분산 석출 연구 분산 적용 용매 분산 용 조합 연구 비율 용해 정도 분산 종류 전구체 석출 거동 연구 분산 농도 전구체 석출 거동 연구 조건 전구체 물성 평가 조건 확립 주관 기관 주 한청알에프 생산 공정 불용 타겟 나노급 전구체 원료 확보 이용 나노 분말 자원 오염 물질 저감 공정 개발 재생 원료 투입량 대비 재생량 비율 가공비 절감 기존 활용 타겟 분말 제조 공정 대비 재생 나노 분말 조성비 재생 나노 분말 순도 온실 가스 저감 참여 기관 전자 부품 연구원 전구체 나노 분말 확보 분산 기술 개발 재생 나노 분말 입도 재생 나노 분말 비표 면적
#
# 미생물 오염 방지 제거 나노바이오 촉매 소재 개발 미생물 오염 방지 제거 나노바이오 촉매 소재 효소 코팅 생물 오손 방오 나노 바이오 촉매 페인트 나노바 microbial decontamination nano bio catalytic materials enzyme coatings bio fouling anti fouling nano bio catalytic paints nano bio catalytic films nano bio catalytic filters nano bio catalytic spraying solutions 과제 연구 목표 미생물 오염 방지 제거 환경 나노바이오 촉매 소재 개발 가교 결합 효소 나노 구조 물질 결합 안정 효소 기반 환경 나노바이오 촉매 소재 합성 미생물 오염 방지 제거 분야 성공 응용 환경 정화 필름 페인트 필터 스프레이 용액 다양 나노 바이오 촉매 소재 개발 미생물 오염 다양 환경 문제 문제 미생물 오염 정화 환경 안정 지속 가능 미생물 오염 방지 제거 기술 개발 실정 효소 기반 미생물 오염 방지 제거 기술 문제 해결 대안 주목 효소 자체 안정 실제 응용 제한 과제 미생물 오염 효율 방지 안정 효소 활성 환경 정화 나노바이오 촉매 소재 개발 제안 효소 안정 방식 효소 나노 구조 물질 공유 결합 효소 가교 결합 형성 효소 고집 획기적 안정 효소 코팅 방식 적용 미생물 오염 정화 성공 나노 바이오 촉매 소재 응용 나노바이오 촉매 기반 필름 페인트 필터 스프레이 용액 다양 소재 개발 효소 기반 미생물 오염 방지 제거 기술 전략 미생물 오염 방지 방오 기술 미생물 오염 제거 기술 접근 방식 활용 연구 과제 제안 최종 목표 다음 효소 나노 구조 물질 상호 작용 기초 연구 안정 효소 활성 나노바이오 촉매 소재 개발 미생물 오염 방지 제거 필름 페인트 필터 스프레이 용액 개발 성공 효소 기반 미생물 오염 방지 제거 기술 실현 과제 수행 안정 효소 활성 나노바이오 촉매 접근 방식 개발 안정 효소 기반 필름 페인트 필터 스프레이 용액 다양 종류 나노바이오 촉매 소재 성공 개발 기대 개발 나노바이오 촉매 소재 기술 환경 지속 가능 미생물 오염 방지 제거 가능 생물 전환 반응 바이오 센서 바이오연료 전지 이산화탄소 포집 전환 효소 안정 필요 다양 분야 응용 예상
#
# 분산 열원 이용 지열 냉난방 시스템 상용 기술 지열 냉난방 시스템 분산 열원 기상 데이터 제어 최적 최적 설계 기법 geothermal heat pump system distributed geothermal energy sources bin weather data optimization of control strategy optimum design procedure 주관 기관 코텍 엔지니어링 주 분산 열원 이용 지열 시스템 성능 모니터링 현장 검토 선정 실증 지열 냉난방 시스템 모니터링 장비 설계 시공 분산 열원 적용 효과 분석 기초 자료 수집 분산 열원 대응 지열 히트 펌프 유닛 기본 설계 참여 기관 한국에너지기술연구원 지열원 열펌프 시스템 설계 기상 자료 선정 분석 방법 위험 구분 분산 열원 지열 시스템 지열 에너지 부하 계산 기상 자료 작성 위항 결과 대상 현지 지중열 성능 측정 데이터 회수 분석 실험 대상 대상 건물 분산 열원 이용 지열 시스템 설계 착공 계획 검토 보조 참여 기관 한국건설기술연구원 각종 단일 열원 이용 지열 냉난방 시스템 성능 시뮬레이션 분산 열원 이용 지열 시스템 설계 기술 개발 건축물 에너지 부하 분석 분산 열원 이용 지열 시스템 최적 운전 제어 기술 개발 기본 데이터 구축 분산 열원 이용 지열 시스템 검증 실증 시스템 기존 단일 시스템 모니터링 분석 실증 지열 히트 펌프 시스템 설치 현장 조사 분석 참여 기관 설계 시공 지열 히트 펌프 시스템 설치 현장 검토 선정 실증 사이트 기상 데이터 지중 온도 각종 설계 자료 수집 실증 사이트 건물 에너지 수요량 사용량 검토 선정 건물 냉난방 부하 패턴 계산 에너지 사용량 예측 향후 분산 열원 이용 지열 시스템 동특 시뮬레이션 기초 자료 활용 실증 시스템 시공 모니터링 장비 설치 협의 실증 시스템 현장 지중 순환 수 히트 펌프 입출구 온도 유량 순환 펌프 히트 펌프 소비 전력 데이터 측정 필요 추가 센서 검토 기계실 수평 배관 리버스리턴 배관 균일 유량 분배 확인 유량 차압 계측 장비 설치 분산 열원 이용 지열 시스템 설계 실증 분산 열원 이용 지열 시스템 설계 건축물 정보 수집 현장 검토 결과 각종 설계 데이터 이용 실증 분산 열원 지열 시스템 설계 분산 열원 대응 지열 히트 펌프 유닛 기본 설계 분산 열원 대응 지열 히트 펌프 유닛 개념 정립 기본 설계 분산 열원 대응 지열 히트 펌프 유닛 시 작품 제작 성능 시험 준비 지열원 열펌프 시스템 설계 기상 자료 선정 분석 방법 분산 열원 이용 지열 냉난방 시스템 기상 조건 영향 설계 특징 조사 분석 기상 조건 수직 밀폐 지중열 교환기 용량 산출 영향 지열원 열펌프 시스템 설계 기상 자료 선정 분석 기준 최근 이상 기상 자료 적용 분산 열원 지열 시스템 지열 에너지 부하 계산 기상 자료 작성 지열 이용 시스템 설계 건축물 첨두 부하 에너지 부하 지중 회수 난방 기준 효과 열축열 냉방 기준 효과 산출 건축물 축열 효과 축열 부하 출연 지연 효과 고려 동적 부하 계산 첨두 부하 에너지 부하 계산 최선 수단 동적 부하 계산 대상 건물 기본 데이터 준비 기초 데이터 입력 원인 중소 규모 건물 법 계산 권장 기상청 기상 관측 지점 기준 관측 지점 연구 대상 대상 건물 위치 지점 인접 선정 기상 데이터 곳 대상 기상 자료 작성 분산 열원 이용 지열 시스템 성능 시뮬레이션 선행 연구 지열 냉난방 시스템 구성 요소 해석 모델 분석 각종 단일 열원 수직 수평 에너지 파일 해석 모델 분석 지열 히트 펌프 유닛 부하 설비 해석 모델 분석 상용 시뮬레이션 프로그램 이용 시스템 모델링 분산 열원 이용 지열 시스템 성능 시뮬레이션 기초 연구 각종 단일 열원 이용 지열 시스템 성능 시뮬레이션 단일 열원 종류 외기 건물 냉난방 부하 운전 스케줄 지열 냉난방 시스템 성능 영향 분석 에너지 수지 분석 시뮬레이션 도구 분석 결과 비교 기술 획득 실측 데이터 시뮬레이션 결과 비교 시뮬레이션 검증 기술 측면 히트 펌프 분산 열원 주 열원 열원 지상 구성 요소 연결 배관 계통도 표준 모델 구축 시스템 안정 성능 확보 열원 효율 운전 제어 알고리즘 개발 시스템 에너지 소비량 절감 관련 기술력 축적 기여 동일 조건 지반 각종 지중 열원 성능 체계 분석 기존 지중열 교환기 포함 분산 열원 시스템 적용 지중열 교환기 성능 측정 분석 기법 체계 구축 계기 마련 다양 형태 지중 열원 객관 성능 자료 확보 분산 열원 성능 향상 필요 핵심 기술 구축 시공비 절감 국내 기상 조건 적합 시스템 모델 개발 향후 지열 시장 성장 국가 신 재생 에너지 보급 향상 기여 현장 실증 연구 시스템 성능 객관 데이터 확보 사용자 냉수 공급 조건 온도 유량 지중 순환 수 히트 펌프 입 출구 온도 조건 최적 설계 데이터 확보 표준 시공 기준 적용 시스템 시공 부실시공 사전 방지 경제 산업 측면 국내 건물 연간 에너지 사용량 대부분 냉난방 급탕 비용 감안 분산 열원 이용 시스템 설계 시공 기술 개발 후 적극 보급 필요 분산 열원 이용 지열 시스템 객관 설계 가능 기존 단일 열원 시스템 성능 향상 정확 설계 데이터 설계 초기 단계 반영 최적 설계 가능 초기 투자비 소비자 믿음 지열 시장 안정 성장 기여 국내 외 시공 다양 형태 분산 열원 객관 성능 자료 확보 성능 우수 시공비 표준 시스템 적용 초기 투자비 절감 사회 측면 다양 지열 에너지 이용 방식 근거 제시 지열 에너지 사회 신뢰 확보 일조 기존 지열 시스템 초기 투자비 절감 에너지 성능 향상 민간 건설 시장 지열 시스템 확산 기여 제로 에너지 도시 에너지 자급자족 도시 개념 적용 국내외 도시 조성 사업 특화 기술 활용 가능 향후 시행 재생 에너지 열 공급 의무 제도 정착 기여
#
# 이상 저감 공정 이용 난연 수송 기계 흡차음 내외 장재 개발 난연 필름 지능 자동 공정 난연 수성 점착제 난연 필름 자동 적층 장치 hybrid flame retarding film intelligent automatic process flame retarding water - bone bond flame retarding water deflector film s auto folding system 지능 에너지 저감 연속 이용 기능 환경 수송 기계 내외 장재 개발 환경 난연 소재 개발 인체 무해 수성 점착제 적용 소재 개발 동시 점착제 관련 프린팅 기술 에너지 저감 건조기 개발 지능 자동 시스템 도입 공정 자동 이상 구현 동시 신뢰 이상 만족 에너지 감형 자동 효율 시스템 개발 가 환경 점착제 관련 프린팅 기술 적용 라미 네이션 공정 최적 확립 코팅 방법 코팅 기술 향상 보완 검토 제품 유효 평가 공정 설비 설계 보완 설비 개발 적용 금형 기술 보완 환경 점착제 작업 평활 향상 유효 증대 방안 모색 에너지 저감 건조기 공정 개선 연구 조건 제품 품질 향상 연구 효율 에너지 저감 공정 생산 향상 연구 최적 생산 증대 속도 대비 최적 건조 시간 단축 지능 자동 적층 공정 효율 개선 보완 지능 자동 적층 공정 개선 개발 보완 지능 자동 시스템 적용 공정 신뢰도 향상 연구 지능 자동 시스템 적층 불량 감소 연구 라 공정 자동 연구 신뢰 개선 연구 참여 기관 에너리얼 마 환경 기능 차음성 항균 인장 점착 점착 필름 소재 개발 생산 시제품 적용 난연제 개발 소재 물 저하 배제 연구 차음성 분자 복합체 기초 연구 차음 성능 구현 고감 기능 필름 소재 적용 항균 내균 기능 첨가제 배합 연구 환경 기능 분자 복합체 필름 시제품 제작 물 저하 변수 배제 연구 개질 배합 최적 연구 기능 환경 첨가제 필름 구현 점착제 상용 검토 연구 참여 기관 부림케미칼 환경 수성 난연 점착제 개발 환경 수성 난연 점착제 물 성능 환경 수성 난연 점착제 스케일 업 합성 파이롯트 연구 환경 수성 난연 점착제 작업 평가 개선 연구 환경 수성 난연 점착제 라인 테스트 품질 테스트 제품 기술 검토 평가 현장 라인 기술 수정 보완 참여 기관 자동차 부품 연구원 사 신뢰 평가 향상 방안 연구 단품 신뢰 평가 향상 방안 연구 내환경 내화학 시험 평가 특성 변화 분석 충격 평가 특성 분석 난연 소재 적용 단품 복합 난연 특성 분석 연소 특성 연소 메카니즘 분석 시제품 난연 특성 비교 분석 단품 국제 환경 규제 유해 물질 분석 유해 물질 방출량 분석 환경 개선 효과 분석 지능 에너지 저감 연속 이용 기능 환경 수송 기계 내외 장재 개발 환경 난연 소재 개발 인체 무해 수성 점착제 적용 소재 개발 동시 점착제 관련 프린팅 기술 에너지 저감 건조기 개발 지능 자동 시스템 도입 공정 자동 이상 구현 동시 신뢰 이상 만족 에너지 감형 자동 효율 시스템 개발
#
# 오존 미산성전해수 이용 환경 소독 장치 개발 해수 전기 분해 멸균 수 소독수 탈취 electro - analysis ed water electrolysis sterilized water an antiseptic solution de odori z ation 학교 대형 급식 시설 식중독 사고 발생 식자재 병원 생물 노로바이러스 과 농약 노출 축산 농가 농도 악취 각종 전염병 조류 인플루엔자 구제역 발생 경제 고통 기존 살균 소독 대책 사용 락스 차아염소산나트륨 용액 염소 냄새 유독 가스 발생 피부 접촉 피부 트러블 발생 잔류 주변 시설 부식 대량 사용 어려움 문제점 연구 살균 소독제 문제점 보완 염산 전기 분해 발생 차아염 소산 오존 성분 환경 살균 소독제 생산 복합전 해수 장치 개발 염소 이온 함유 수용액 전기 분해 원리 적용 성분 복합전 해수 장치 개발 복합전 해수 최대 생산량 도출 최적 전압 조건 확립 복합전 해수 소독 효과 탈취 효과 평가 복합전 해수 장치 운영 구축 복합전 해수 장치 설계 기술 확립 기술 파급 효과 환경 살균 소독제 생산 기술 향상 복합전 해수 생산 전기 분해 전극 기술 개발 복합전 해수 생산 시스템 구성 기술 개발 적용 분야 확대 전극 전기 공급 장치 시스템 구성 운영 반 기술 향상 적용 분야 파급 효과 식품 위생 관련 분야 살균 소독 환경 농수산물 가공 세척 살균 소독 분야 병원 소독 의료 기구 환경 소독 병원 환경 개선 분야 축산업 방역 탈취 환경 개선 생산 증대 분야 환경 농산물 생산 농약 대체 분야 규모 식당 가정 살균 소독 분야 공공 복지 관련 분야 수입 대체 효과 해외 선진국 해수 관련 물산업 이상 성장세 국내 증가 추세 기술 취약 해외 기술 유입 기술 상용 수입 대체 효과 기대
#
# 산업 환경 규제 신속 대응 체계 구축 환경 규제 환경 설계 에코디자인 에너지 효율 규제 유해 물질 규제 roh s energy regulation eco design eup we ee 중국 미국 국내 기업 주요 수출 지역 환경 ？ 에너지 규제 대응 사전 신속 대응 체계 구축 중소 중견 기업 사후 대응 지원 사전 신속 대응 체계 구축 해외 규제 제 개정 단계 국내 산업 의견 적극 개진 국내 산업 불리 조항 시행 시기 유예 규제 강도 완화 유도 국내외 환경 규제 시행 이후 유권 해석 지원 배포 이행 가이드 발간 교육 세미나 개최 애로 상담 컨설팅 기업 규제 이행 지원 강화 확대 다양 환경 에너지 규제 조기 대응 체계 기업 지원 시스템 구축 국내 산업 수출 경쟁력 지속 중소 중견 기업 국제 경쟁력 강화 ㅇ 해외 규제 신속 대응 미 신규 품목 대응 전략 수립 현지 대표부 중국 미국 운영 입법 참여 해외 규제 제？ 개정 저지 완화 주요 수출국 환경 규제 정보 모니터링 신속 대응 규제 부담 감소 주요 규제국 현지 진출 기업 유관 기관 협력 조기 대응 기반 조성 해외 규제 유권 해석 과잉 대응 방지 비용 절감 각국 환경 에너지 관련 정보 구축 신규 품목 환경 이슈 모니터링 분석 ㅇ 기업 환경 규제 사후 대응 체계 강화 온라인 통합 검색 시스템 구축 글로벌 환경 규제 원문 분석 글로벌 환경 규제 동향 모니터링 정보 제공 ㅇ 국내 산업 지원 인식 확산 공급망 그룹 공동 대응 전문 컨설팅 제공 품목 이슈 협의체 운영 현안 분석 이슈 발굴 글로벌 환경 규제 동향 모니터링 대응 방안 수립 세미나 교육 유권 해석 자료집 대응 가이드 우수 대응 사례집 발간 배포 파트너십 인증 지원 ㅇ 무역 수지 수출 전체 수출 차지 산업 지속 가능 수출 시장 확대 수출 경쟁력 확 보 기여 ㅇ 사전 대응 채널 확보 기반 구축 산업 부담 가중 예상 조항 예외 규제 완화 ㅇ 기업 대응 비용 절감 제품 개발 투자 수출 시장 확대 매출 증대 규제 완화 유권 해석 기업 대응 비용 절감 예상 ㅇ 기업 매출 증대 일자리 창출 기여 관련 제조업 매출 고용 창출 ㅇ 중소기업 실질 지원 서비스 온라인 애로 지원 현장 애로 해결 맞춤 교육 개도 이전 확산 ㅇ 규제 대응 지원 데이터베이스 매뉴얼 각국 환경 인증 누적 지식 정보 매뉴얼 온라인 공개 중소기업 상시 정보 이용 환경 규제 대응 지원 ㅇ 해외 유관 기관 네트워크 인사 다수 확보 환경 분쟁 협력 사안 발생 활용 고급 정보 수집 현지 동향 모니터링 ㅇ 수출 마찰 국제 분쟁 대응
# 녹색 화학 기술 개발 사업 사전 기획 연구 다부처 공동 녹색 화학 사전 기획 유해 화학 물질 대체 물질 개발 joint planning departments green chemical pre - planning toxic chemicals alternative substances development 유해 화학 물질 인체 환경 영향 최소 지속 가능 화학 산업 발전 환경부 산업 부 상호 협력 공동 추진 녹색 화학 사업 사전 기획 다부처 공동 기획 필요 제시 부처 소관 분야 연계 사업 영역 중복 가능 다부처 참여 시너지 창출 가능 검토 공동 기획 필요 내용 제시 사업 범위 목표 설정 국가 주요 정책 부합 부처 소관 분야 고려 사업 범위 사업 목표 설정 사업 목표 사업 기간 사업 유형 제시 환경부 산업 통상 자원부 추진 중점 추진 분야 도출 중점 분야 부처 참여 범위 역할 분담 안 제시 국내 외 주요 현황 분석 사업 파급 효과 제시 제품 제조 과정 사용 유해 화학 물질 대체 녹색 화학 지원 유해 화학 물질 사용 원천 저감 국민 건강 우려 감소 지속 가능 화학 산업 경쟁력 향상 기여
#
# 환경 내수면 양식업 수생 균 곰팡이 살균기 개선 제품 개발 어류 양어 수생 균 미생물 살균 fish fish culture water fungus microorganism sterilization 양어장 미생물 플라즈마 살균기 개발 플라즈마전 극모듈 전극 적층 구조 양식장 사용 용수 이온 농도 현장 전극 갯수 용량 조절 가감 구조 전극 모듈 일반 사용자 교체 구조 적층 전극 가이드 전극 가이드 적층 전극 음전 극부 양전극부 그룹 전극 봉부 조립체인 전극 모듈 사용자 교환 구조 전력 제어회 메인 컨트롤러 회로 메인 컨트롤러 전력 제어 회로 통신 다수 제어 기능 이온 농도 변화 발생 전류 변화 출력 전압 제어 전극 수명 표시 알고리즘 개발 기능 강제 순환 방식 수중 펌프 물 유입 전극 평면 수직 방향 분출 전극 이물질 전극 오염 방지 마이크로버블 살균 성능 향상 강제 순환 구조 디자인 세계 진출 글로벌 현대 제품 디자인 개발 시제품 개발 압출 성형 시금 제작 아크릴 압출 금형 개발 파이프 형태 절단 길이 조절 압출 방식 금형 개발 아크릴 성형 금형 개발 파이프 양쪽 물고기 유입 차단 망사 형태 구조 인버터 전자 회로 외장 케이스 설계 개발 급 직류 전원 장치 개발 입력 전원 단상 정격 출력 플라즈마 모듈 개발 부착 케이스 구조 설계 시제품 제작 절연 부재 개발 연결 부재 개발 전극봉 연결 단자 개발 전력 제어 드라이버 제어 회 최적 외관 케이스 설계 제작 모니터링 반도체 사용 전압 전류 모니터링 이온 변화 연동 출력 전력 제어 알고리즘 최적 전극 수명 표시 기능 이온 농도 전극 소비 전류 전극 인가 전압 전극 수명 예측 알고리즘 개발 제어 소프트웨어 최적 제어 컨트롤러 최적 외관 케이스 설계 제작 전원 노이즈 발생 전기 에러 개선 제품 신뢰 향상 제어 소프트웨어 최적 함체 외관 케이스 설계 제작 각종 부속품 전기 배선 고려 구조 개발 활용 분야 양식장 미생물 살균기 어병 예방 치료 화학제품 대체 환경 양식 가능 안전 먹거리 확보 공중 보건 위생 기여 어류 양식 분야 적용 어류 부화장 부화 양식 어민 소득 증대 기여 분야 적용 새싹 채소 미생물 살균기 새싹 채소 재배 경우 발생 입고병 미생물 질병 예방 치료 환경 농업 분야 적용 양산 계획 강원도 화천군 양식업자 공급 예정 제품 마케팅 전략 환경 양식 트랜드 부합 자연 친화 살균 기술 부각 판로 확보 방안 강원도 강원도 화천 양식업자 설치 화천군 운영 논미리 산천어 양식장 쏘가리 양식장 적용후 춘천 삼척 강릉 평창 울진 양식업자 공급 예정 국내 전라도 경기도 전국 양식업자 공급 해외 세계 양식 생산량 비중 중국 일본 인도네시아 방글라데시 아프리카 아메리카 유럽 진출
#
# 진공사출 복합 성형 이용 패턴 구현 기술 개발 진공금 다공 금속 엠보싱 가공 필라 트림 썬바 vacuum mold porous metal embossing machining pillar trim sun visor 주관 기관 주 동원테크 진공사출 복합 성형 부품 설계 설계 가이드 설정 다공 금속 이용 진공사 출성 부품 설계 환경 고감 선정 이종 소재 물성 조건 최적 진공사출 복합 성형 프로세스 개발 구축 기존 사출 성형기 활용 진공 사출 성형 모니터링 시스템 구축 감성 표피재 진공사출 복합 형 공정 시스템 개발 진공 사출 성형 장치 이용 자동차 내장 부품 제작 평가 참여 기관 주 창용 금형 다공 금속 이용 개발 부품 금형 제작 진공사출 복합 성형 장치 제작 개발 부품 시제품 제작 성형 조건 평가 엠보 정밀 형상 가공 기술력 확보 참여 기관 자동차 부품 연구원 표피재 분자 성형 수지 변형 해석 다공 금속 소재 특성 분석 기초 물 평가 진공사출 복합 성형 특성 분석 개발 부품 물 신뢰 평가 주관 기관 주 동원테크 진공사출 성형 부품 설계 설계 가이드 설정 엠보싱 형상 구현 진공 사출 성형 장치 개발 다공 금속 이용 진공사 출성 부품 설계 제작 환경 고감 선정 이종 소재 물성 조건 최적 진공사출 복합 성형 프로세스 개발 구축 진공사출 복합 형용 모니터링 시스템 구축 표피재 진공사출 복합 형 공정 시스템 개발 참여 기관 주 창용 금형 다공 금속 이용 개발 부품 금형 제작 진공사출 복합 성형 장치 제작 엠보 정밀 형상 가공 기술력 확보 참여 기관 자동차 부품 연구원 표피재 분자 성형 수지 변형 해석 다공 금속 소재 특성 분석 기초 물 평가 진공사출 복합 성형 특성 분석 개발 부품 물 신뢰 평가 주관 기관 주 동원테크 진공사출 복합 성형 부품 설계 설계 가이드 설정 다공 금속 이용 진공사 출성 부품 설계 환경 고감 선정 이종 소재 물성 조건 최적 진공사출 복합 성형 프로세스 개발 구축 기존 사출 성형기 활용 진공 사출 성형 모니터링 시스템 구축 감성 표피재 진공사출 복합 형 공정 시스템 개발 진공 사출 성형 장치 이용 자동차 내장 부품 제작 평가 참여 기관 주 창용 금형 다공 금속 이용 개발 부품 금형 제작 진공사출 복합 성형 장치 제작 개발 부품 시제품 제작 성형 조건 평가 엠보 정밀 형상 가공 기술력 확보 참여 기관 자동차 부품 연구원 표피재 분자 성형 수지 변형 해석 다공 금속 소재 특성 분석 기초 물 평가 진공사출 복합 성형 특성 분석 개발 부품 물 신뢰 평가
#
# 기업 연계 과정 자원 관리 비즈니스 모델 개발 자원 관리 서비스 자원 관리 전문 기업 물질 흐름 원가 회계 자원 생산 기업 연계 비즈니스 모델 resources management service resources efficiency service company material flow cost account resource productivity enterprises - connected business model 비즈니스 모델 설계 사업 업종 가이드라인 성공 사례집 개발 시범 사업 자원 관리 시범 사업 공정 개선 완료 기업 자원 관리 시범 사업 검증 자원 관리 시범 사업 해당 업종 자원 관리 가이드라인 업종 자원 관리 시범 사업 성공 사례집 개발 자원 관리 시법 사업 기업 공정 개선 완료 기업 시범 사업 공정 진단 개선 점 도출 기업 신규 비즈니스 모델 설계 사업 산업 전반 자원 생산 향상 경쟁력 강화 ㅇ 자원 생산 향상 원자재 사용 운영 코스트 원가 절감 절감 비용 설비 기술 도입 투자 경쟁력 강화 ㅇ 불량 감소 제품 신뢰도 향상 폐기물 저감 환경 부하 저감 달성 환경 기업 이미지 제고 ㅇ 동종 산업 산업 자원 생산 개선 성공 사례 공정 기술 정보 공유 지속 가능 산업 협력 체계 구축 자원 관리 서비스 전문 기업 육성 신규 시장 선점 ㅇ 자원 관리 서비스 전문 기업 육성 국내 기업 환경 규제 대응 전문 강화 촉진 신흥 개발국 해외 수요 비즈니스 모델 성장 기대 ㅇ 해외 유수 전문 기업 신규 국내 시장 잠식 리스크 해소 국내 전문 컨설팅 기업 육성 아시아 신규 시장 선점
#
# 환경 에너지 생산 수 처리 삼투 기술 기반 스마트 분리막 개발 응용 환경 에너지 생산 수 처리 삼투 기술 기반 스마트 분리막 개발 응용  abc 환경 에너지 생산 수 처리 삼투 기술 기반 스마트 분리막 개발 응용 환경 에너지 생산 수 처리 삼투 기술 기반 스마트 분리막 개발 응용 환경 에너지 생산 수 처리 삼투 기술 기반 스마트 분리막 개발 응용
#
# 무창 축사 외부 환기 시스템 개선 공기 정화 기술 개발 환기 시스템 플라즈마 악취 무창 축사 ventilation system plasma pit order enclosed livestock facilities 양성 코로나 방전 화학 활성 반응 이용 가축 생체 무해 공기 정화 적용 기술 연구 배 오존 기술 개발 축사 내부 최대 최소 환기량 공기 정화 순환 시스템 연구 ㆍ 축사 외부 악취 제거 미생물 사멸 정도 시험 시험 농가 공인 성적 광촉매 코팅 기술 개발 창 축사 최소 환기 유지 기간 효율 순환 시스템 적용 축사 내부 구조 바닥 천정 측벽 공기 정화 자동 기술 연구 악취 미생물 창 축사 오염 물질 제거 공기 정화 시스템 설계 제작 시험 농가 설치 공인 성적 시험 농가 공기 정화 시스템 성능 시험 운전 조건 최적 장치 표준 설계 기술 인증 양성 코로나 방전 화학 활성 반응 이용 가축 생체 무해 공기 정화 적용 기술 연구 배 오존 기술 개발 축사 환기 관련 국내외 자료 이론 분석 축사 공기 성상 분석 유해 가스 악취 원인 물질 농도 측정 세부 목표 제시 정량 수치 확인 축사 내부 최소 환기량 공기 정화 순환 시스템 연구 축사 최소 환기량 적용 공기 정화 시스템 최적 운전 조건 기술 개발 ㆍ 축사 온도 습도 공기 유동 측정 온 습도계 풍향 이용 측정 계절 축사 기능 용도 축사 환경 측정 결과 도출 하반기 축사 최소 환기량 악취 농도 환기 자동 조정 기술 개발 기존 환기 시스템 상호 작용 정량 적정 설치 위치 선정 윈치 돈사 통풍 현황 시스템 최적 위치 파악 창 축사 구조 공기 정화 장치 자동 기술 연구 축사 내부 구조 바닥 천정 측벽 연구 분만사자 육돈사임신돈사 부분 목적 기능 특성 적용 기술 개발 공기 정화 장치 기술 신뢰 확보 실증 연구 환경오염 방지 에너지 절감 공기 정화 시스템 설계 시스템 설계 축사 배출 공기 악취 미생물 제거 분석 시험 성적서 제출 제주도 보건 환경 연구원 분석 의뢰 시험 농가 설치 가축 발육 상태 관찰 기록 가축 생체 해 정도 파악 농가 협조 시설 투자비 경제 분석 시험 농가 공기 정화 시스템 성능 시험 운전 조건 최적 표준 공기 정화 장치 표준 설계 용량 적용 실증 설계 축사 내부 환경 최적 유지 상태 측정 공인 성 공정 운전 매뉴얼 개발 최종 평가 기술 이전 공동 인증 추진 적용 설비 경제 확보 무창 축사 부분 목적 기능 특성 적용 공기 정화 자동 기술 확보 악취저감 공기 정화 장치 신뢰 확보 관련 지 재산 확보 기술 우위 확보
#
# 리그닌 기반 나노 구조 소재 표면 미세 구조 제어 촉매 분리막 기능 부여 연구 리그닌 나노 소재 팔라듐무전 카본나노 섬유 수소 수 처리 분리막 lignin nano fiber el p c nf hydrogen water membrane 연구 목표 리그닌 기반 제조 카본 나노 소재 기능 부여 환경 에너지 분야 대기 수질 수소 에너지 핵심 소재 사용 분리막 촉매 응용 다양 창의 접근 제안 선진 기술 융합 기반 각각 소재 특성 부합 최적 조건 제조 방법 획득 향후 관련 소재 연구 접근 기초 연구 결과 제시 기법 이용 최적 결정 공정 개질 연구 형성 금속 산화물 코팅 최적 연구 저온 수소 취성 억제 기공 크기 제어 연구 상온 산화 반응 역할 기반 구조체 촉매 기능 극대 구조체 표면 전자 밀 제어 유기 억제 기공 균일 크기 제어 연구 연구 목표 창의 도전 기존 탈피 리그닌 기반 리그닌 리그닌 나노 소재 기반 전기 방사 무전 이용 분리막 제조 수소 분리막 제조 공정 최소 가능 금속 분자 소재 이용 다기능 수처리 분리막 연구 내용 리그닌 기반 카본 나노 소재 응용 물 최적 결정 카본 나노 소재 다양 응용 기초 물성 기계 강도 기공 분포 균일 최적 분리막 촉매 기능 부여 필수 사용 활성 물질 다양 조건 온도 시간 환원 조사 최적 레시피 결정 수소 분리막 응용 소재 기공 구조 최적 연구 카본 나노 소재 수소 분리막 응용 벌크내 기공 구조 제어 접근 검토 다양 크기 금속 산화물 이용 기공 크기 조절 법 활용 최 적화 방법 제시 수소 분리막 제조 공정 공정 카본 나노 소재 제조 과정 첨가 방법 조사 최적 조건 제시 도출 지지체 조건 바탕 실제 타입 수소 분리막 제조 성 능 평가 수 처리 분리막 환경 촉매 응용 소재 표면 미세 구조 최적 상온 산화 반응 촉매 활성 영향 크기 분산도 제어 촉매 활성 조사 상기 다양 물성 성능 상관관계 제시 바탕 로 소량 금속 산화물 첨가 성능 극대 연구 수행 소재 수 처리 분리막 응용 내구 직결 유기 억제 연구 수행 표 면 전하 특성 제어 원인 물질 흡착 감소 흡착 유기물 산화 소재 표면 개질 기대 효과 수소 분리막 저가 성능 분리막 소재 개발 사업 연계 가능 에너지 핵심 소재 핵심 공정 확보 수소스테이션 환경 시설 매립지 하수 처리장 액체 연료 생산 다양 적용 처 공정 구성 가능 기술 파급 효과 예상 처리 분리막 분리막 기술 시장 최근 속도 성장 성능 소재 수요 증가 정밀 여과 여과 역삼투 분리막 소재 분야 나노 기술 접목 수 처리 기술 산업 추진 향후 시장 성장 전망 응용 분야 활용 범위 환경 시설 전반 활용 동시 전극 재료 가스 흡착제 태양 전지 연료 전지 분야 확장 수소 연료 전지 천연가스 바이오매스석탄 이용 수소 생산 환경 시설 후단 태양 전지 수소 수확 정수 처리 하 폐수 처리 해수 담수화 산업용수 처리
#
# 건조 살균 개발 카트 살균기 이온 발생기 덕트 설계 열유동 형상최적 cart sterilizer spi duct design heat and mass transfer shape optimization 엠닉스테크 개발 방식 카트 살균기 이온 발생기 건조 융합 통합 모듈 개발 건조기 이온 분포 균일 살균 효과 증진 건조 시간 감축 소음저감 모듈 통합 공정 축소 제작 경비 저감 기술 경쟁력 확보 설계 능력 보유 전산 유체 역학 최적 기법 형상 최적 수행 살균액 최단 시간 건조 유로 출구 유속 온도 이온 분포 균질 내부 유동 온도 이온 분포 파악 발생기 특성 연구 설계 방법 확립 실시간 카트 살균 가능 발생기 선정 연구 수행 별개 부품 부품 감축 공정 제작 경비 저감 가격 경쟁력 확보 살균 능력 향상 살균 시간 소음 저감 기술 경쟁력 확보 최적 이용 신규 시장 개척 해외 시장 진출 교두보
#
# 우레탄 유니 소재 활용 환경 타이어 제조 기술 우레탄 전기차 연비 환경 타이어 urethane electro vehicle fuel efficiency environment - friendly tire 소재 실차 적용 신뢰 확보 실차 소음 진동 평가 주행 평가 국내 표준 등록 국제 규격 제안 양산용 소재 타이어 최종 제품 전기 자동차 모니터링 개발 타이어 휠 타이어 장착 전기 차량 후방 충돌 시험 특허 출원 타이어 구조 트레드 소재 휠 구조 논문 투고 접착 활용 우레탄 엘라스토머 가공 생산 최종 물성 평가 프리폴리머 경화제 레진 프리믹 생산 설비 검토 최종 비공 기압식 타이어 제작 소재 품질 산포 제어 기술 흡음 관련 공명기 제작 설계 표준 확보 실란 변성 폴리우레탄 계 반응 접착제 파일 규모 접착 평가 표준 확립 트레드 반복 재생 내구 특성 향상 기술 실차 진행 기존 공기식 타이어 유사 수준 달성 장착 차량 평가 환경 연비 경량 실차 한계 주행 성능 소음 재현 신뢰 검증 양산 검토 국제 표준 시험 평가법 규격 제안 전기차 실증 평가 주행 충돌 소재 실차 적용 신뢰 확보 실차 소음 진동 평가 주행 평가 국내 표준 등록 국제 규격 제안 양산용 소재 타이어 최종 제품 전기 자동차 모니터링 개발 타이어 휠 타이어 장착 전기 차량 후방 충돌 시험 특허 출원 타이어 구조 트레드 소재 휠 구조 논문 투고 접착 활용
#
# 내장재 인출 공정 개선 개발 진공 세퍼레이터 샌드필터 진공 병렬식 공정 개선 vacuum separator s and filter vac cum double type process improve 여과사 수처리 여과 공정 사용 여재 오염 물 여과사 모래 입자 사이 공극 통과 물 정화 사용 재료 불순물 여과재 심층부 혼합 정수 효율 산업 폐기물 처리 국내 철강 산업 석유 화학 산업 경우 장시간 사용 마모 설비 이상 수질 악화 주기 전량 교체 수질 정상 기존 여과사 폐기물 처리 여과사 구입 사용 실정 비용 효율 교체 서비스 기술 개발 필요 최종 목표 내장재 인출 공정 개선 개발 설계 제작 여과사 인출 장치 설계 제작 해석 최적 설계 시퀸스 제어 기반 자동 시스템 여과사 교체 공사 현장 적용 시험 설계 제작 특허 기술 이용 여과사 인출 장치 설계 제작 진공 유지 해석 최적 설계 시스템 유동 해석 시퀸스 제어 기반 자동 시스템 시퀸스 제어 여재 투입 작동 여재 투입 반복 여과사 교체 공사 현장 적용 시험 대상 지역 방식 사용 시설 선정 조건 여과사 흡착 유분 유무 기준 현장 적용 성과 예상 시설 공정 개선 완료 후 사업 가능 다양 현장 특성 시험 개소 시설 형태 인출 방식 차이 사용 규제 물질 폐수 처리 시설 유 무 선정 방법 설비 구매 그룹 지자체 상수도 사업 부서 정수 협조 선정 기술 측면 기술 개발 효과기존 내장재 교체 서비스 작업 방법 준설 수작업 진공 흡입 차량 이동 여과사 투입 과정 작업 공기 작업 인력 과다 투입 서비스 비용 증가 주요 원인 기술 개발 일체 연속 인출 작업 공정 동력 사용 절감 환경오염 방지 작업 공기 단축 서비스 비용 저감 기술 개발 효과 기대 경제 기대 효과 인출 공정 개선 기대 효과 산출 사 연주 공장 기 대상 개선 전 개선 후 작업 물량 범위 폐 내장재 인출 신품 충진 수리 폐기물 처리 운반 작업 공수 절감 개선 작업 공수 개선 후 작업 공수 서비스 비용 절감액 기 비용 절감 효과 노무비 절감액 기타 경비 소모자 재비 연간 작업 공수 서비스 비용 절감액 총액 사 연간 교체 서비스 물량 연주 공장 배 규모 동종 분야 경쟁 업체 영세 규모 회사 대부분 회사 전문 기술 장비 부족 시장 점유 확보 예상 당사 내장재 교체 서비스 전문 작업 효율 연속 공정 장치 비용 저감 용역 서비스 제공 고객 수요 대응 여과사 교체 서비스 분야 시장 점유 판단
#
# 지속 가능 자가 구성 생산 시스템 목적 주도 프로세스 기술 개발 프랙탈 자가 구성 프랙탈 생산 시스템 목적 주도 지속 가능 동적 구성 프로세스 시뮬레이션 멀티에이전트 기술 프 fractal self reconfiguration fractal manufacturing system f rms goal orientation sustainability dynamic restructuring process drp simulation multi agent technology basic fractal unit b fu 연구 지속 가능 프랙탈 기반 자가 구성 생산 시스템 목적 주도 프로세스 기술 개발 국내 제조업 생산 시스템 기반 기술 확보 경쟁력 제고 최종 목표 그간 미국 일본 제조 선진국 위주 개발 생산 시스템 도입 국내 제조업 실정 미래 생산 시스템 기술 확보 향후 관련 연구 분야 선도 역할 수행 연구 자가 구성 생산 시스템 목적 주도 기술 개발 자가 구성 협업 관련 기술 개발 지속 가능 기술 개발 시뮬레이션 내용 구성 자가 구성 생산 시스템 목적 주도 기술 개발 일반 생산 시스템 관련 기술 조사 분석 기반 프랙탈 특성 반영 개발 생성 평가 기술 목적 주도 제조 프로세스 생성 기술 개발 목적 주도 제조 프로세스 생성 기술 관련 특정 산업 대상 제조 프로세스 생성 검증 자가 구성 협업 관련 기술 개발 자가 구성 요소 분석 검토 보완 수행 자가 구성 실현 방법 시스템 대내외 변화 시스템 자율 변화 기술 자가 구성 발전 수행 지원 연구 인공 지능 기법 활용 자가 학습 프랙탈 기술 개발 모델링 수행 프랙탈 협상 협업 제조 프로세스 구성 기술 개발 지속 가능 기술 개발 시뮬레이션 환경 요소 고려 구성 생산 시스템 지속 가능 부여 방안 검토 생산 자원 공정 고려 지속 가능 요소 도출 자가 구성 특성 지속 가능 확보 관리 방안 연구 기반 지속 가능 개념 전략 기술 정의 지속 가능 관련 요소 고려 구성 가능 제조 프로세스 시뮬레이션 수행 결과 분석 연구 개발 제조 프로세스 기술 검증 연구 자가 구성 가능 자율 의사 결정 판단 실행 차세대 지능 생산 시스템 모델 관련 연구 결과 생산 시스템 고지능 효율 지원 자가 구성 생산 시스템 관련 핵심 기술 미래 생산 시스템 실현 중요 역할 담당 연구 결과 국내 제조 기업 실정 생산 시스템 개발 촉진 산업 분야 제품 생산 시스템 구축 기존 시스템 개선 과정 활용 궁극 기업 생산 제조 강국 국가 위상 연구 수행 미래 생산 시스템 기술 전략 이해 국내 제조업 현황 파악 기반 국내 제조 시스템 혁신 일조 핵심 인력 양성 가능 생각 연구 수행 자가 구성 생산 시스템 기술 국제 환경 규제 강화 대응 지속 가능 관련 기술 국제 선도 계기 기대
#
# 광독립 영양 미세 조류 성장 특성 율속 메커니즘 적용 탄산 주입 멤브레인 광생물 반응조 연구 개발 광반 응조 시스템 미세 조류 바이오매스 바이오매스 에너지 멤브레인 탄산 주입 이산화탄소 확산 이동 영양 염류 제거 photo bio reactor system micro algae biomass biomass energy membrane carbonation diff u sive co transfer nutrient removal system optimization mathematical modeling 연구 기체 멤브레인 분리 기술 광합성 생물 반응조 기술 융합 효과 무기 탄소 제공 방법 확립 유용 바이오원료 물질 광합성 미생물 바이오매스 대량 생산 자원 환경오염 물질 제거 동시 효과 수행 가능 연구 개발 최종 목표 극복 핵심 도전 과제 미생물 성장 효과 제어 이산화탄소 영양 염류 전달 이용 메커니즘 규명 기존 광생물 반응조 적용 시스템 연구 개발 최적 연구 생물 환경 공학 생물학 수 처리 설계 제어 기술 수질 화학 생물 공학 재료 공학 화학 공학 과학 지식 융합 원천 기술 확립 궁극 지속 가능 재생 가능 탄소 중립 첨단 생물 환경 공학 기술 확립 기여 과제 미세 조류 성장 특성 종합 평가 바이오매스 구성 탄수화물 단백질 지방질 자원 수질 오염 물질 저감 바이오 에너지 생산 품질 바이오 연료 대량 생산 가능 첨단 생물 환경 공학 시스템 연구 개발 주요 연구 내용 다음 기초 빛 강도 필수 영양 염류 공급 이용 율속인자 변화 광합성 미생물 바이오매스 생산 평가 광반응조 내외부 위치 가능 모듈 이용 농도 구배 현상 규명 공급 예측 손실 최소 가능 평가 개념 도입 미생물 바이오매스 유출 최소 질소 제거 폐수 처리 가능 다목적 시스템 기존 추가 첨단 소재 아이디어 접목 하이브리드 광반응조 시스템 모듈 개량 설계 미세 조류 대량 배양 성능 개선 핵심 유닛 광합성 미생물 광독립 영양 성장 수행 광생물 반응조 시스템 광 생물 반응조 내부 위치 지속 제공 모듈 바이오매스 유출 방지 수질 유출 수확보 조합 기술 융합 시스템 확립 융합 시스템 복합 문제 해결 공학 조절 가능 수학 통계 최적 연구 수행 광생물 반응조 기본 설계 인자 들 영역 도출 해당 분야 학문 발전 기여 효과 원천 기술 선점 지식 재산 창출 해외 유명 저널 게재 국제 연구 경쟁력 확보 태양 에너지 이용 폐수 비용 효과 개념 처리 유용 자원 회수 공정 제시 바이오매스 합성 에너지 자원 회수 연계 선 순환 기술 확립 광합성 미생물 생태학 연구 기술 접목 품질 유출수 확보 학제 물리학 화학 생물학 생물 공학 환경 공학 화학 공학 재료 공학 협업 바탕 첨단 생물 환경 공학 기술 확립 연구 수행 과정 연구 인력 양성 효과 최신 연구 동향 이해 바탕 수질 오염 방지 바이오 에너지 생산 관련 첨단 연구 주제 발굴 첨단 바이오매스 생산 자원 시스템 개발 필요 선도 인력 석박사 인력 양성 양성 석 박사 실용 산업 첨병 역할 수행 사회 유익 가치 창출 인류 발전 공헌 광합성 미생물 이용 첨단 환경 미생물 공학 융합 기술 연구 관심 산업체 고용 연계 효과
# 환경 친화 난삭재 미세 가공 기술 시스템 개발 난삭재 환경 친화 생산 미세 가공 나노 유체 극미량 절삭유 윤활 전기 수력학 하이브리드 윤활 가공 프로세스 모델 difficult to cut materials environment fr end ly manufacturing micro machining nano fluid minimum quantity lubrication electro hydro dynamic hybrid lubrication machining process modeling and analysis machining process optimization machining process monitoring and diagnosis 연구 목표 연구 최근 자동차 조선 우주 항공 기계 에너지 분야 강도 경량 소재 수요 증대 티타늄 니켈합금 난삭재 환경 친화 미세 가공 기술 시스템 개발 수행 연차 연구 목표 유량 냉각 공기 기반 소형 나노 유체 극미량 절삭유 윤활 전기 수력학 분무 기반 하이브리드 윤활 적용 난삭재 환경 친화 미세 가공 프로세스 개발 실험 검증 이론 전산 해석 기반 난삭재 환경 친화 미세 가공 프로세스 메커니즘 가공력 가공 온도 모델링 특성 분석 최적 가공력 표면조 가공 온도 공구 수명 난삭재 환경 친화 미세 가공 프로세스 실시간 모니터링 상태 진단 시스템 개발 난삭재 환경 친화 미세 가공 윤활 냉각 시스템 개발 난삭재 기계 가공 프로세스 공구 전기 수력학 이온 샷 분무 첨단 윤활 특성 연구 난삭재 환경 친화 미세 가공 윤활 냉각 모듈 설계 제작 맞춤 윤활 냉각 모듈 통합 난삭재 환경 친화 미세 가공 프로세스 기계 시스템 개발 난삭재 환경 친화 미세 가공 프로세스 메커니즘 모델링 특성 분석 최적 난삭재 환경 친화 미세 가공 프로세스 파라미터 분석 난삭재 환경 친화 미세 가공 프로세스 최적 난삭재 환경 친화 미세 가공 프로세스 메커니즘 가공력 가공 온도 모델링 분석 난삭재 환경 친화 미세 가공 프로세스 실시간 모니터링 상태 진단 시스템 개발 난삭재 개별 기계 가공 모니터링 센서 선정 하드웨어 구축 난삭재 개별 기계 가공 프로세스 데이터 수집 가공 상태 진단 알고리즘 개발 실험 알고리즘 검증 밀링드릴링연삭 개별 난삭재 기계 가공 프로세스 실시간 모니터링 상태 진단 시스템 구축 국내 초기 단계 난삭재 마이크로급 기계 가공 기술 국제 경쟁력 확보 관련 시장 선도 해외 우수 학술지 급 논문 게재 학술 대회 발표 기술 확산 국제 평판 제고 난삭재 마이크로급 부품 제조 기술 관련 고급 전문 인력 양성 생산 현장 애로 점 해결 산학 협동 연구 과제 발굴 원천 기술 실용 국내외 관련 연구 기관 협력 연구 체계 구축 난삭재 기계 가공 기술 연구 허브 역할
#
# 배관설비용 유체 처리 장치 개발 파울링 스케일 배관 설비 내식 내구 fouling scale piping system corrosion resistance durability 용도 기전 소방 상수도 파울링 저감 배관 설비 장치 개발 파울링 저감 광물질 여재 개발 유체 처리 주파 전자 발생 장치 개발 배관 모니터링 시스템 개발 수처리 장치 정량 비교 시험 성능 평가 용도 기전 소방 상수도 파울링 저감 배관 설비 장치 개발 희생 양극법 이온 결정 부식 스케일 방지 장치 성능 향상 아연 반응기 구조 개선 개발 구조 이용 제작 성능 평가 수 처리 장치 최적 설계 파울링 저감 광물질 여재 개발 환경 유체 흐름 방해 광물질 개발 광물질 이용 방법 연구 개발 광물질 연구 개발 유체 처리 주파 전자 발생 장치 개발 주파 펄스 최적 효율 발생 기법 연구 주파 펄스 악취 입자 물질 효율 제거 장치 구조 연구 주파 발생 장치 내구 향상 습식 적용 방법 연구 주파 발생 장치 이용 연구 개발 배관 모니터링 시스템 개발 배관 부식 상시 모니터링 모니터링 시스템 개발 개발 장치 부착 배관 철 농도 상시 확인 센서 부착 모니터링 시스템 개발 상시 모니터링 개발 장치 교체 시기 시일 안 확인 시스템 개발 수처리 장치 정량 비교 시험 성능 평가 바이오 파울링 저감 효과 고찰 박테리아 제거 효과 조사 생물 공정 음용수 처리 장치 설계 제작 수 처리 촉매 이용 수 처리 장치 스케일 예방 연구 주철관 사용 녹부식 스케일 파울링 억제 기존 제품 개선 필요 외국 기술 국내 시장 기존 제품 고가 시장 일체 교체 어려움 산업 보일러 건물 급탕 설비 건물 냉난방 설비 활용 열원 필요 공장 설치 열 교환기 부식녹 스케일 억제 에너지 효율 증대 배관 파손 현상 예방 소방 스프링클러 녹부식 스케일 억제 상수 관련 시설 활용 마을 상수 간이 상수 연소 효율 탄소 배출 감소 탄소 배출 확보
#
# 인공 지능 혼합 기법 이용 성능 청정소 화약 개발 청정소 화약 할 대체 물질 소화 비예 혼합 화염 열화학 해석 직접 수치 모사 버너 대향 버너 인공 지능 clean extinguishing agent halon alternatives fire extinguish ment non pre mixed flame thermo chemical analysis direct numerical simulation cup b u rner counter flow burner artificial intelligence 청정소 화약 개발 기존 약제 단순 조합 실험 경험 의존 화재 발생 소화 약제 소화 현상 공학 규명 상태 최적 청정소 화약 개발 기법 정립 어려움 과제 실험 전산 해석 기법 이용 청정 소화 약제 화염 소화 원리 규명 인공 지능 혼합 기법 이용 성능 혼합 청정소 화약 개발 다양 화염 조건 소화 약제 대상 기초 검증 실험 열화학 해석 고정밀 직접 수치 해법 이용 기초 실용 연구 수행 가스 소화 약제 열 전달 물 소화 성능 분석 국소 방출 방식 개념 향 버너 활성 기체 소화 특성 실험 전역 방출 방식 개념 버너 활성 기체 소화 특성 실험 대향 화염 수치 해석 수행 순수 활성 기체 소화 성능 효과 검토 전달 물 변화 소화 성능 영향 검토 주요 물성 변화 소화 성능 해석 설계 기법 제시 향 동축 제트 연소장 국소 전역 소염 현상 해석 분산 메모리 개념 코드 병렬 코드 효율 개선 스트레인 열손 실량 활성 기체 국소 소염 특성 규명 비예 혼합화염 활성 기체 화염 안정 규명 주요 물성 변화 국소 전역 소화 특성 현상 규명 인공 지능 혼합 기법 최적 기술 성능 청정소 화약 개발 대표 세대 세대 청정소 화약 전역 국소 소화 성능 실험 대표 세대 세대 청정소 화약 소화 현상 수치 해석 규명 인공 지능 혼합 기법 개발 성능 청정소 화약 설계 최적 기술 확장 검토 연소 화재 소화 메커니즘 이해 규명 학문 발전 기여 다양 화재 발생 조건 차세대 혼합 청정소 화약 개발 설계 기술 확립 국내 청정소 화약 개발 기술력 선진 소방 안전 산업 기술 발전 기여 연소 화재 공학 관련 분야 핵심 전문가 양성
#
# 무창돈사 무창계사 내부 분뇨 유래 가스 제거 환기 시스템 기술 개발 환기 시스템 플라즈마 악취 무창 축사 ventilation system plasma pit order enclosed livestock facilities 분뇨 공기 가축 사육 공간 유입 방지 기술 적용 방법 제시 공기 가축 사육 공간 유입 방지 기술 현장 실증 최대 최소 환기 설정 사육 돼지 방해 최소 무창 돈사 분뇨 환기 장치 제작 무창 돈사 분뇨 환기 장치 보완 분뇨 공기 가축 사육 공간 유입 방지 기술 적용 방법 제시

# %%
for i,word_id in enumerate(important_word):
    if word_id > 10:
        print(feature_names[i])
# Out:
# 개선
# 공정
# 관련
# 국내
# 기존
# 물질
# 제작
# 최적
# 특성
# 환경
